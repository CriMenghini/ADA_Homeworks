# %% [markdown]
# # Homework 5 - Taming text

# %% [markdown]
# ## Introduction

# %% [markdown]
# In this homework, a large corpus of emails released in public during the Hillary Clinton email controversy will be explored. The corpus is stored in `Data` directory. More informtion of the schema is available [here](https://www.kaggle.com/kaggle/hillary-clinton-emails).

# %%
from os import path
import pandas as pd
from wordcloud import WordCloud
import matplotlib.pyplot as plt
import nltk
import string
import re
import pycountry
from functools import partial
from cleaning import *
from nltk.sentiment.vader import SentimentIntensityAnalyzer
# %matplotlib inline

# %% [markdown]
# ## 1. Word clouds
# Generate two word clouds:
# * One based on the raw corpus
# * One based on the corpus pre-processed using the standard text pipeline.
#
# ### a. __Raw text__
#
# The data we are going to use for producing the clouds is taken from the file `Emails.csv` and refers to the column `MetadataSubject, ExtractedSubject, Extractedbody`. Hence, before proceeding to build up a unique cloud, we sould concatenate all the body and subject of the emails. In particular, we do the following:
# * Import the data related to the Emails.

# %%
# Read data
emails = pd.read_csv('Data/Emails.csv', sep = ',')
emails.sample(3)
# Out:
#         Id  DocNumber                              MetadataSubject MetadataTo  \
# 1869  1870  C05762332  I JUST DROPPED BFG BOOK OFF AT YOUR HOUSE.           H
# 4003  4004  C05767230       FEEDBACK ON MIDDLE EAST COMMENTS TODAY          H
# 5004  5005  C05769389                                   NAPOLITANO          H
#
#            MetadataFrom  SenderPersonId           MetadataDateSent  \
# 1869       Abedin, Huma            81.0  2009-06-14T04:00:00+00:00
# 4003  Crowley, Philip J           168.0  2010-02-03T05:00:00+00:00
# 5004       Abedin, Huma            81.0  2010-01-24T05:00:00+00:00
#
#            MetadataDateReleased  \
# 1869  2015-06-30T04:00:00+00:00
# 4003  2015-08-31T04:00:00+00:00
# 5004  2015-08-31T04:00:00+00:00
#
#                                         MetadataPdfLink MetadataCaseNumber  \
# 1869  DOCUMENTS/HRCAll_1_1-29_JuneWEB/AddBacks/DOC_0...       F-2014-20439
# 4003  DOCUMENTS/HRCEmail_August_Web/IPS-0062/DOC_0C0...       F-2014-20439
# 5004  DOCUMENTS/HRCEmail_August_Web/IPS-0060/DOC_0C0...       F-2014-20439
#
#                             ...                          \
# 1869                        ...
# 4003                        ...
# 5004                        ...
#
#                   ExtractedTo                            ExtractedFrom  \
# 1869                      NaN         Abedin, Huma <AbedinH@state.gov>
# 4003                        H  Crowley, Philip J <CrowleyPJ@state.gov>
# 5004  H; 'ValmoroU@state.gov'                            Huma Abedin <
#
#                                             ExtractedCc  \
# 1869                                                NaN
# 4003  Feltman, Jeffrey D; Abedin, Huma; Sullivan, Ja...
# 5004                                                NaN
#
#                          ExtractedDateSent ExtractedCaseNumber  \
# 1869         Sunday, June 14, 2009 9:44 PM        F-2014-20439
# 4003  Wednesday, February 3, 2010 10:50 PM        F-2014-20439
# 5004     Sunday, January 24, 2010 10:27 AM        F-2014-20439
#
#      ExtractedDocNumber ExtractedDateReleased ExtractedReleaseInPartOrFull  \
# 1869          C05762332            06/30/2015              RELEASE IN PART
# 4003          C05767230            08/31/2015              RELEASE IN PART
# 5004          C05769389            08/31/2015              RELEASE IN PART
#
#                                       ExtractedBodyText  \
# 1869  B6\nMy random stuff can wait till the morning:...
# 4003  Madam Secretary, good evening. I just received...
# 5004               Yes ops is reaching out to her soon.
#
#                                                 RawText
# 1869  UNCLASSIFIED U.S. Department of State Case No....
# 4003  UNCLASSIFIED U.S. Department of State Case No....
# 5004  UNCLASSIFIED U.S. Department of State Case No....
#
# [3 rows x 22 columns]

# %% [markdown]
# Due to the presence of missing data for the variable related to the `Subject`:
# * Get the indeces of the email without `MetadataSubject`

# %%
index_null = emails[emails['MetadataSubject'].isnull()].index

# %% [markdown]
# * Get the indeces of the email without `ExtractedSubject`

# %%
index_null_extracted = emails[emails['ExtractedSubject'].isnull()].index

# %% [markdown]
# Then, compute the intersection to see which are the emails that merging the information contained in the two columns will remain unknown.

# %%
# Number that should remain null
print ("Number of email we do not know the subject: ", len(set(index_null).intersection(set(index_null_extracted))))
# Out:
# Number of email we do not know the subject:  250

# %% [markdown]
# We prefer using the `MetadataSubject` since it appears more cleaned, we use the information in `ExtractedSubject` though. Here we replace the null values of the former with those of the latter, whether it has it.

# %%
# For each mail without the subject
for i in index_null:
    emails.loc[i,'MetadataSubject'] = emails.loc[i, 'ExtractedSubject']

# %% [markdown]
# The entries that remain nulls even after these operation are filled in with the expression `No title`. The same is done for the bodies of the emails substituting the empty fields with the expression `No body text`.

# %%
# Get the subject - replacing nans
emails['MetadataSubject'].fillna('No title', inplace = True)

# %%
# Get bodies - replace nans
emails['ExtractedBodyText'].fillna('No body text', inplace = True)

# %% [markdown]
# * Extract the column relates to the corpus.

# %%
# Useful data
email_corpus = emails[['MetadataSubject', 'ExtractedBodyText']]

# %% [markdown]
# * Create a *unique* corpus.

# %% [markdown]
# We choose the columns of the data that provide some useful information - merged columns for subject of the email and also body text.

# %%
# Create a unique string from the list of entries for the subject feature
unique_corpus_1 = ' '.join([email_corpus['MetadataSubject'][i] for i in range(len(email_corpus))])

# Create a unique string from the list of entries for the body feature
unique_corpus_2 = ' '.join([email_corpus['ExtractedBodyText'][i] for i in range(len(email_corpus))])

# %%
# Get the raw corpus
unique_corpus = ' '.join([unique_corpus_1] + [unique_corpus_2])

# %% [markdown]
# At first we remove all the characters that contain punctuation.

# %%
for c in string.punctuation:
    unique_corpus = unique_corpus.replace(c," ")

# %% [markdown]
# Thus, we generate the word cloud. For the moment, in order to indentify the most frequent words, we decide not to fix the maximum font size.

# %%
# Generate the word cloud 
wordcloud = WordCloud().generate(unique_corpus)

# %% [markdown]
# Visualize the output cloud!

# %%
# Display the generated cloud
plt.imshow(wordcloud)
plt.axis("off")
# Out:
# (-0.5, 399.5, 199.5, -0.5)

# %% [markdown]
# ### b. Pre-processed text
#
# To preprocess the text we proceed with these steps ([`clean_entire_corpus`](cleaning.py)):

# %% [markdown]
# * Tokenize the corpus and we receive the list of words to further procedure.
# * Remove meaningless, short tokens and we put the rest of them into lowercase.
# * Get rid of a list of stowords extended by the common words we found in the cloud above (to extend the list of meaningless words we go through the list of the firs words cloud)
# * We considered using stemming techniques but we abandoned this idea while it couldn't give us more descriptive view of the email content. Also we find not stemmed words easier to proceed.

# %%
# Get the list to extend the stopwords list
extra = [line.rstrip('\n').strip() for line in open('extra_stopwords.txt')]

# %% [markdown]
# Thus, we preprocess the code.

# %%
# Obtain the corpus
corpus = clean_entire_corpus(unique_corpus, 3, extra)

# %% [markdown]
# And we proceed generating the cloud of words.

# %%
plt.imshow(WordCloud().generate(corpus))
plt.axis("off")
# Out:
# (-0.5, 399.5, 199.5, -0.5)

# %% [markdown]
# Comparing the two clouds we clearly see how different they are in terms of *"key words"*. The raw corpus contains a lot of meaningless words that occur often in the emails (just because element of the grammar or standard part of a body email), it leads to the lack of information in the cloud. Beside, the second cloud, thanks to the cleaning, seems to be more capable of describing the email contents.

# %% [markdown]
# ## 2.
# Find all the mentions of world countries in the whole corpus, using the pycountry utility (HINT: remember that there will be different surface forms for the same country in the text, e.g., Switzerland, switzerland, CH, etc.) Perform sentiment analysis on every email message using the demo methods in the nltk.sentiment.util module. Aggregate the polarity information of all the emails by country, and plot a histogram (ordered and colored by polarity level) that summarizes the perception of the different countries. Repeat the aggregation + plotting steps using different demo methods from the sentiment analysis module -- can you find substantial differences?

# %%
def clean_body(x):
    
    # IMPORTANT STOPWORD IS A VARIABLE ALREADY DECLEARED OUTSIDE
    
    # Tokenize
    text = nltk.word_tokenize(x)
    
    # Replace the comma adding space and go to lowercase
    replace_comma = [(i.replace(',', ', ')).lower() for i in text]
    #print (replace_comma)
    # Get rid of this list of two letters words
    get_rid = list(stop_words) + ["re", "fm", "tv", "al", "aq", "la", "ben", "no", "pm", 'cc', 'com', 'mr', 'us', 'fw']
    list_words = [i for i in replace_comma if i not in get_rid and len(i) > 1]
       
    # Get back to the string
    join_list = " ".join(list_words)
    
    # Remove all the punctuation
    for c in string.punctuation:
        join_list = join_list.replace(c," ")
    
    text_new = nltk.word_tokenize(join_list)
    get_rid = list(stop_words) + ["re", "fm", "tv", "al", "aq", "la", "ben", "no", "pm", 'cc', 'com', 'mr', 'us', 'fw']
    list_words = [i for i in text_new if i not in get_rid and len(i) > 1]
    
    return list_words

# %%
emails['ExtractedBodyText_2'] = emails['ExtractedBodyText'].apply(clean_body)

# %%
list(pycountry.countries)
# Out:
# [Country(alpha_2='AW', alpha_3='ABW', name='Aruba', numeric='533'),
#  Country(alpha_2='AF', alpha_3='AFG', name='Afghanistan', numeric='004', official_name='Islamic Republic of Afghanistan'),
#  Country(alpha_2='AO', alpha_3='AGO', name='Angola', numeric='024', official_name='Republic of Angola'),
#  Country(alpha_2='AI', alpha_3='AIA', name='Anguilla', numeric='660'),
#  Country(alpha_2='AX', alpha_3='ALA', name='Åland Islands', numeric='248'),
#  Country(alpha_2='AL', alpha_3='ALB', name='Albania', numeric='008', official_name='Republic of Albania'),
#  Country(alpha_2='AD', alpha_3='AND', name='Andorra', numeric='020', official_name='Principality of Andorra'),
#  Country(alpha_2='AE', alpha_3='ARE', name='United Arab Emirates', numeric='784'),
#  Country(alpha_2='AR', alpha_3='ARG', name='Argentina', numeric='032', official_name='Argentine Republic'),
#  Country(alpha_2='AM', alpha_3='ARM', name='Armenia', numeric='051', official_name='Republic of Armenia'),
#  Country(alpha_2='AS', alpha_3='ASM', name='American Samoa', numeric='016'),
#  Country(alpha_2='AQ', alpha_3='ATA', name='Antarctica', numeric='010'),
#  Country(alpha_2='TF', alpha_3='ATF', name='French Southern Territories', numeric='260'),
#  Country(alpha_2='AG', alpha_3='ATG', name='Antigua and Barbuda', numeric='028'),
#  Country(alpha_2='AU', alpha_3='AUS', name='Australia', numeric='036'),
#  Country(alpha_2='AT', alpha_3='AUT', name='Austria', numeric='040', official_name='Republic of Austria'),
#  Country(alpha_2='AZ', alpha_3='AZE', name='Azerbaijan', numeric='031', official_name='Republic of Azerbaijan'),
#  Country(alpha_2='BI', alpha_3='BDI', name='Burundi', numeric='108', official_name='Republic of Burundi'),
#  Country(alpha_2='BE', alpha_3='BEL', name='Belgium', numeric='056', official_name='Kingdom of Belgium'),
#  Country(alpha_2='BJ', alpha_3='BEN', name='Benin', numeric='204', official_name='Republic of Benin'),
#  Country(alpha_2='BQ', alpha_3='BES', name='Bonaire, Sint Eustatius and Saba', numeric='535', official_name='Bonaire, Sint Eustatius and Saba'),
#  Country(alpha_2='BF', alpha_3='BFA', name='Burkina Faso', numeric='854'),
#  Country(alpha_2='BD', alpha_3='BGD', name='Bangladesh', numeric='050', official_name="People's Republic of Bangladesh"),
#  Country(alpha_2='BG', alpha_3='BGR', name='Bulgaria', numeric='100', official_name='Republic of Bulgaria'),
#  Country(alpha_2='BH', alpha_3='BHR', name='Bahrain', numeric='048', official_name='Kingdom of Bahrain'),
#  Country(alpha_2='BS', alpha_3='BHS', name='Bahamas', numeric='044', official_name='Commonwealth of the Bahamas'),
#  Country(alpha_2='BA', alpha_3='BIH', name='Bosnia and Herzegovina', numeric='070', official_name='Republic of Bosnia and Herzegovina'),
#  Country(alpha_2='BL', alpha_3='BLM', name='Saint Barthélemy', numeric='652'),
#  Country(alpha_2='BY', alpha_3='BLR', name='Belarus', numeric='112', official_name='Republic of Belarus'),
#  Country(alpha_2='BZ', alpha_3='BLZ', name='Belize', numeric='084'),
#  Country(alpha_2='BM', alpha_3='BMU', name='Bermuda', numeric='060'),
#  Country(alpha_2='BO', alpha_3='BOL', common_name='Bolivia', name='Bolivia, Plurinational State of', numeric='068', official_name='Plurinational State of Bolivia'),
#  Country(alpha_2='BR', alpha_3='BRA', name='Brazil', numeric='076', official_name='Federative Republic of Brazil'),
#  Country(alpha_2='BB', alpha_3='BRB', name='Barbados', numeric='052'),
#  Country(alpha_2='BN', alpha_3='BRN', name='Brunei Darussalam', numeric='096'),
#  Country(alpha_2='BT', alpha_3='BTN', name='Bhutan', numeric='064', official_name='Kingdom of Bhutan'),
#  Country(alpha_2='BV', alpha_3='BVT', name='Bouvet Island', numeric='074'),
#  Country(alpha_2='BW', alpha_3='BWA', name='Botswana', numeric='072', official_name='Republic of Botswana'),
#  Country(alpha_2='CF', alpha_3='CAF', name='Central African Republic', numeric='140'),
#  Country(alpha_2='CA', alpha_3='CAN', name='Canada', numeric='124'),
#  Country(alpha_2='CC', alpha_3='CCK', name='Cocos (Keeling) Islands', numeric='166'),
#  Country(alpha_2='CH', alpha_3='CHE', name='Switzerland', numeric='756', official_name='Swiss Confederation'),
#  Country(alpha_2='CL', alpha_3='CHL', name='Chile', numeric='152', official_name='Republic of Chile'),
#  Country(alpha_2='CN', alpha_3='CHN', name='China', numeric='156', official_name="People's Republic of China"),
#  Country(alpha_2='CI', alpha_3='CIV', name="Côte d'Ivoire", numeric='384', official_name="Republic of Côte d'Ivoire"),
#  Country(alpha_2='CM', alpha_3='CMR', name='Cameroon', numeric='120', official_name='Republic of Cameroon'),
#  Country(alpha_2='CD', alpha_3='COD', name='Congo, The Democratic Republic of the', numeric='180'),
#  Country(alpha_2='CG', alpha_3='COG', name='Congo', numeric='178', official_name='Republic of the Congo'),
#  Country(alpha_2='CK', alpha_3='COK', name='Cook Islands', numeric='184'),
#  Country(alpha_2='CO', alpha_3='COL', name='Colombia', numeric='170', official_name='Republic of Colombia'),
#  Country(alpha_2='KM', alpha_3='COM', name='Comoros', numeric='174', official_name='Union of the Comoros'),
#  Country(alpha_2='CV', alpha_3='CPV', name='Cabo Verde', numeric='132', official_name='Republic of Cabo Verde'),
#  Country(alpha_2='CR', alpha_3='CRI', name='Costa Rica', numeric='188', official_name='Republic of Costa Rica'),
#  Country(alpha_2='CU', alpha_3='CUB', name='Cuba', numeric='192', official_name='Republic of Cuba'),
#  Country(alpha_2='CW', alpha_3='CUW', name='Curaçao', numeric='531', official_name='Curaçao'),
#  Country(alpha_2='CX', alpha_3='CXR', name='Christmas Island', numeric='162'),
#  Country(alpha_2='KY', alpha_3='CYM', name='Cayman Islands', numeric='136'),
#  Country(alpha_2='CY', alpha_3='CYP', name='Cyprus', numeric='196', official_name='Republic of Cyprus'),
#  Country(alpha_2='CZ', alpha_3='CZE', name='Czechia', numeric='203', official_name='Czech Republic'),
#  Country(alpha_2='DE', alpha_3='DEU', name='Germany', numeric='276', official_name='Federal Republic of Germany'),
#  Country(alpha_2='DJ', alpha_3='DJI', name='Djibouti', numeric='262', official_name='Republic of Djibouti'),
#  Country(alpha_2='DM', alpha_3='DMA', name='Dominica', numeric='212', official_name='Commonwealth of Dominica'),
#  Country(alpha_2='DK', alpha_3='DNK', name='Denmark', numeric='208', official_name='Kingdom of Denmark'),
#  Country(alpha_2='DO', alpha_3='DOM', name='Dominican Republic', numeric='214'),
#  Country(alpha_2='DZ', alpha_3='DZA', name='Algeria', numeric='012', official_name="People's Democratic Republic of Algeria"),
#  Country(alpha_2='EC', alpha_3='ECU', name='Ecuador', numeric='218', official_name='Republic of Ecuador'),
#  Country(alpha_2='EG', alpha_3='EGY', name='Egypt', numeric='818', official_name='Arab Republic of Egypt'),
#  Country(alpha_2='ER', alpha_3='ERI', name='Eritrea', numeric='232', official_name='the State of Eritrea'),
#  Country(alpha_2='EH', alpha_3='ESH', name='Western Sahara', numeric='732'),
#  Country(alpha_2='ES', alpha_3='ESP', name='Spain', numeric='724', official_name='Kingdom of Spain'),
#  Country(alpha_2='EE', alpha_3='EST', name='Estonia', numeric='233', official_name='Republic of Estonia'),
#  Country(alpha_2='ET', alpha_3='ETH', name='Ethiopia', numeric='231', official_name='Federal Democratic Republic of Ethiopia'),
#  Country(alpha_2='FI', alpha_3='FIN', name='Finland', numeric='246', official_name='Republic of Finland'),
#  Country(alpha_2='FJ', alpha_3='FJI', name='Fiji', numeric='242', official_name='Republic of Fiji'),
#  Country(alpha_2='FK', alpha_3='FLK', name='Falkland Islands (Malvinas)', numeric='238'),
#  Country(alpha_2='FR', alpha_3='FRA', name='France', numeric='250', official_name='French Republic'),
#  Country(alpha_2='FO', alpha_3='FRO', name='Faroe Islands', numeric='234'),
#  Country(alpha_2='FM', alpha_3='FSM', name='Micronesia, Federated States of', numeric='583', official_name='Federated States of Micronesia'),
#  Country(alpha_2='GA', alpha_3='GAB', name='Gabon', numeric='266', official_name='Gabonese Republic'),
#  Country(alpha_2='GB', alpha_3='GBR', name='United Kingdom', numeric='826', official_name='United Kingdom of Great Britain and Northern Ireland'),
#  Country(alpha_2='GE', alpha_3='GEO', name='Georgia', numeric='268'),
#  Country(alpha_2='GG', alpha_3='GGY', name='Guernsey', numeric='831'),
#  Country(alpha_2='GH', alpha_3='GHA', name='Ghana', numeric='288', official_name='Republic of Ghana'),
#  Country(alpha_2='GI', alpha_3='GIB', name='Gibraltar', numeric='292'),
#  Country(alpha_2='GN', alpha_3='GIN', name='Guinea', numeric='324', official_name='Republic of Guinea'),
#  Country(alpha_2='GP', alpha_3='GLP', name='Guadeloupe', numeric='312'),
#  Country(alpha_2='GM', alpha_3='GMB', name='Gambia', numeric='270', official_name='Islamic Republic of the Gambia'),
#  Country(alpha_2='GW', alpha_3='GNB', name='Guinea-Bissau', numeric='624', official_name='Republic of Guinea-Bissau'),
#  Country(alpha_2='GQ', alpha_3='GNQ', name='Equatorial Guinea', numeric='226', official_name='Republic of Equatorial Guinea'),
#  Country(alpha_2='GR', alpha_3='GRC', name='Greece', numeric='300', official_name='Hellenic Republic'),
#  Country(alpha_2='GD', alpha_3='GRD', name='Grenada', numeric='308'),
#  Country(alpha_2='GL', alpha_3='GRL', name='Greenland', numeric='304'),
#  Country(alpha_2='GT', alpha_3='GTM', name='Guatemala', numeric='320', official_name='Republic of Guatemala'),
#  Country(alpha_2='GF', alpha_3='GUF', name='French Guiana', numeric='254'),
#  Country(alpha_2='GU', alpha_3='GUM', name='Guam', numeric='316'),
#  Country(alpha_2='GY', alpha_3='GUY', name='Guyana', numeric='328', official_name='Republic of Guyana'),
#  Country(alpha_2='HK', alpha_3='HKG', name='Hong Kong', numeric='344', official_name='Hong Kong Special Administrative Region of China'),
#  Country(alpha_2='HM', alpha_3='HMD', name='Heard Island and McDonald Islands', numeric='334'),
#  Country(alpha_2='HN', alpha_3='HND', name='Honduras', numeric='340', official_name='Republic of Honduras'),
#  Country(alpha_2='HR', alpha_3='HRV', name='Croatia', numeric='191', official_name='Republic of Croatia'),
#  Country(alpha_2='HT', alpha_3='HTI', name='Haiti', numeric='332', official_name='Republic of Haiti'),
#  Country(alpha_2='HU', alpha_3='HUN', name='Hungary', numeric='348', official_name='Hungary'),
#  Country(alpha_2='ID', alpha_3='IDN', name='Indonesia', numeric='360', official_name='Republic of Indonesia'),
#  Country(alpha_2='IM', alpha_3='IMN', name='Isle of Man', numeric='833'),
#  Country(alpha_2='IN', alpha_3='IND', name='India', numeric='356', official_name='Republic of India'),
#  Country(alpha_2='IO', alpha_3='IOT', name='British Indian Ocean Territory', numeric='086'),
#  Country(alpha_2='IE', alpha_3='IRL', name='Ireland', numeric='372'),
#  Country(alpha_2='IR', alpha_3='IRN', name='Iran, Islamic Republic of', numeric='364', official_name='Islamic Republic of Iran'),
#  Country(alpha_2='IQ', alpha_3='IRQ', name='Iraq', numeric='368', official_name='Republic of Iraq'),
#  Country(alpha_2='IS', alpha_3='ISL', name='Iceland', numeric='352', official_name='Republic of Iceland'),
#  Country(alpha_2='IL', alpha_3='ISR', name='Israel', numeric='376', official_name='State of Israel'),
#  Country(alpha_2='IT', alpha_3='ITA', name='Italy', numeric='380', official_name='Italian Republic'),
#  Country(alpha_2='JM', alpha_3='JAM', name='Jamaica', numeric='388'),
#  Country(alpha_2='JE', alpha_3='JEY', name='Jersey', numeric='832'),
#  Country(alpha_2='JO', alpha_3='JOR', name='Jordan', numeric='400', official_name='Hashemite Kingdom of Jordan'),
#  Country(alpha_2='JP', alpha_3='JPN', name='Japan', numeric='392'),
#  Country(alpha_2='KZ', alpha_3='KAZ', name='Kazakhstan', numeric='398', official_name='Republic of Kazakhstan'),
#  Country(alpha_2='KE', alpha_3='KEN', name='Kenya', numeric='404', official_name='Republic of Kenya'),
#  Country(alpha_2='KG', alpha_3='KGZ', name='Kyrgyzstan', numeric='417', official_name='Kyrgyz Republic'),
#  Country(alpha_2='KH', alpha_3='KHM', name='Cambodia', numeric='116', official_name='Kingdom of Cambodia'),
#  Country(alpha_2='KI', alpha_3='KIR', name='Kiribati', numeric='296', official_name='Republic of Kiribati'),
#  Country(alpha_2='KN', alpha_3='KNA', name='Saint Kitts and Nevis', numeric='659'),
#  Country(alpha_2='KR', alpha_3='KOR', name='Korea, Republic of', numeric='410'),
#  Country(alpha_2='KW', alpha_3='KWT', name='Kuwait', numeric='414', official_name='State of Kuwait'),
#  Country(alpha_2='LA', alpha_3='LAO', name="Lao People's Democratic Republic", numeric='418'),
#  Country(alpha_2='LB', alpha_3='LBN', name='Lebanon', numeric='422', official_name='Lebanese Republic'),
#  Country(alpha_2='LR', alpha_3='LBR', name='Liberia', numeric='430', official_name='Republic of Liberia'),
#  Country(alpha_2='LY', alpha_3='LBY', name='Libya', numeric='434', official_name='Libya'),
#  Country(alpha_2='LC', alpha_3='LCA', name='Saint Lucia', numeric='662'),
#  Country(alpha_2='LI', alpha_3='LIE', name='Liechtenstein', numeric='438', official_name='Principality of Liechtenstein'),
#  Country(alpha_2='LK', alpha_3='LKA', name='Sri Lanka', numeric='144', official_name='Democratic Socialist Republic of Sri Lanka'),
#  Country(alpha_2='LS', alpha_3='LSO', name='Lesotho', numeric='426', official_name='Kingdom of Lesotho'),
#  Country(alpha_2='LT', alpha_3='LTU', name='Lithuania', numeric='440', official_name='Republic of Lithuania'),
#  Country(alpha_2='LU', alpha_3='LUX', name='Luxembourg', numeric='442', official_name='Grand Duchy of Luxembourg'),
#  Country(alpha_2='LV', alpha_3='LVA', name='Latvia', numeric='428', official_name='Republic of Latvia'),
#  Country(alpha_2='MO', alpha_3='MAC', name='Macao', numeric='446', official_name='Macao Special Administrative Region of China'),
#  Country(alpha_2='MF', alpha_3='MAF', name='Saint Martin (French part)', numeric='663'),
#  Country(alpha_2='MA', alpha_3='MAR', name='Morocco', numeric='504', official_name='Kingdom of Morocco'),
#  Country(alpha_2='MC', alpha_3='MCO', name='Monaco', numeric='492', official_name='Principality of Monaco'),
#  Country(alpha_2='MD', alpha_3='MDA', common_name='Moldova', name='Moldova, Republic of', numeric='498', official_name='Republic of Moldova'),
#  Country(alpha_2='MG', alpha_3='MDG', name='Madagascar', numeric='450', official_name='Republic of Madagascar'),
#  Country(alpha_2='MV', alpha_3='MDV', name='Maldives', numeric='462', official_name='Republic of Maldives'),
#  Country(alpha_2='MX', alpha_3='MEX', name='Mexico', numeric='484', official_name='United Mexican States'),
#  Country(alpha_2='MH', alpha_3='MHL', name='Marshall Islands', numeric='584', official_name='Republic of the Marshall Islands'),
#  Country(alpha_2='MK', alpha_3='MKD', name='Macedonia, Republic of', numeric='807', official_name='The Former Yugoslav Republic of Macedonia'),
#  Country(alpha_2='ML', alpha_3='MLI', name='Mali', numeric='466', official_name='Republic of Mali'),
#  Country(alpha_2='MT', alpha_3='MLT', name='Malta', numeric='470', official_name='Republic of Malta'),
#  Country(alpha_2='MM', alpha_3='MMR', name='Myanmar', numeric='104', official_name='Republic of Myanmar'),
#  Country(alpha_2='ME', alpha_3='MNE', name='Montenegro', numeric='499', official_name='Montenegro'),
#  Country(alpha_2='MN', alpha_3='MNG', name='Mongolia', numeric='496'),
#  Country(alpha_2='MP', alpha_3='MNP', name='Northern Mariana Islands', numeric='580', official_name='Commonwealth of the Northern Mariana Islands'),
#  Country(alpha_2='MZ', alpha_3='MOZ', name='Mozambique', numeric='508', official_name='Republic of Mozambique'),
#  Country(alpha_2='MR', alpha_3='MRT', name='Mauritania', numeric='478', official_name='Islamic Republic of Mauritania'),
#  Country(alpha_2='MS', alpha_3='MSR', name='Montserrat', numeric='500'),
#  Country(alpha_2='MQ', alpha_3='MTQ', name='Martinique', numeric='474'),
#  Country(alpha_2='MU', alpha_3='MUS', name='Mauritius', numeric='480', official_name='Republic of Mauritius'),
#  Country(alpha_2='MW', alpha_3='MWI', name='Malawi', numeric='454', official_name='Republic of Malawi'),
#  Country(alpha_2='MY', alpha_3='MYS', name='Malaysia', numeric='458'),
#  Country(alpha_2='YT', alpha_3='MYT', name='Mayotte', numeric='175'),
#  Country(alpha_2='NA', alpha_3='NAM', name='Namibia', numeric='516', official_name='Republic of Namibia'),
#  Country(alpha_2='NC', alpha_3='NCL', name='New Caledonia', numeric='540'),
#  Country(alpha_2='NE', alpha_3='NER', name='Niger', numeric='562', official_name='Republic of the Niger'),
#  Country(alpha_2='NF', alpha_3='NFK', name='Norfolk Island', numeric='574'),
#  Country(alpha_2='NG', alpha_3='NGA', name='Nigeria', numeric='566', official_name='Federal Republic of Nigeria'),
#  Country(alpha_2='NI', alpha_3='NIC', name='Nicaragua', numeric='558', official_name='Republic of Nicaragua'),
#  Country(alpha_2='NU', alpha_3='NIU', name='Niue', numeric='570', official_name='Niue'),
#  Country(alpha_2='NL', alpha_3='NLD', name='Netherlands', numeric='528', official_name='Kingdom of the Netherlands'),
#  Country(alpha_2='NO', alpha_3='NOR', name='Norway', numeric='578', official_name='Kingdom of Norway'),
#  Country(alpha_2='NP', alpha_3='NPL', name='Nepal', numeric='524', official_name='Federal Democratic Republic of Nepal'),
#  Country(alpha_2='NR', alpha_3='NRU', name='Nauru', numeric='520', official_name='Republic of Nauru'),
#  Country(alpha_2='NZ', alpha_3='NZL', name='New Zealand', numeric='554'),
#  Country(alpha_2='OM', alpha_3='OMN', name='Oman', numeric='512', official_name='Sultanate of Oman'),
#  Country(alpha_2='PK', alpha_3='PAK', name='Pakistan', numeric='586', official_name='Islamic Republic of Pakistan'),
#  Country(alpha_2='PA', alpha_3='PAN', name='Panama', numeric='591', official_name='Republic of Panama'),
#  Country(alpha_2='PN', alpha_3='PCN', name='Pitcairn', numeric='612'),
#  Country(alpha_2='PE', alpha_3='PER', name='Peru', numeric='604', official_name='Republic of Peru'),
#  Country(alpha_2='PH', alpha_3='PHL', name='Philippines', numeric='608', official_name='Republic of the Philippines'),
#  Country(alpha_2='PW', alpha_3='PLW', name='Palau', numeric='585', official_name='Republic of Palau'),
#  Country(alpha_2='PG', alpha_3='PNG', name='Papua New Guinea', numeric='598', official_name='Independent State of Papua New Guinea'),
#  Country(alpha_2='PL', alpha_3='POL', name='Poland', numeric='616', official_name='Republic of Poland'),
#  Country(alpha_2='PR', alpha_3='PRI', name='Puerto Rico', numeric='630'),
#  Country(alpha_2='KP', alpha_3='PRK', name="Korea, Democratic People's Republic of", numeric='408', official_name="Democratic People's Republic of Korea"),
#  Country(alpha_2='PT', alpha_3='PRT', name='Portugal', numeric='620', official_name='Portuguese Republic'),
#  Country(alpha_2='PY', alpha_3='PRY', name='Paraguay', numeric='600', official_name='Republic of Paraguay'),
#  Country(alpha_2='PS', alpha_3='PSE', name='Palestine, State of', numeric='275', official_name='the State of Palestine'),
#  Country(alpha_2='PF', alpha_3='PYF', name='French Polynesia', numeric='258'),
#  Country(alpha_2='QA', alpha_3='QAT', name='Qatar', numeric='634', official_name='State of Qatar'),
#  Country(alpha_2='RE', alpha_3='REU', name='Réunion', numeric='638'),
#  Country(alpha_2='RO', alpha_3='ROU', name='Romania', numeric='642'),
#  Country(alpha_2='RU', alpha_3='RUS', name='Russian Federation', numeric='643'),
#  Country(alpha_2='RW', alpha_3='RWA', name='Rwanda', numeric='646', official_name='Rwandese Republic'),
#  Country(alpha_2='SA', alpha_3='SAU', name='Saudi Arabia', numeric='682', official_name='Kingdom of Saudi Arabia'),
#  Country(alpha_2='SD', alpha_3='SDN', name='Sudan', numeric='729', official_name='Republic of the Sudan'),
#  Country(alpha_2='SN', alpha_3='SEN', name='Senegal', numeric='686', official_name='Republic of Senegal'),
#  Country(alpha_2='SG', alpha_3='SGP', name='Singapore', numeric='702', official_name='Republic of Singapore'),
#  Country(alpha_2='GS', alpha_3='SGS', name='South Georgia and the South Sandwich Islands', numeric='239'),
#  Country(alpha_2='SH', alpha_3='SHN', name='Saint Helena, Ascension and Tristan da Cunha', numeric='654'),
#  Country(alpha_2='SJ', alpha_3='SJM', name='Svalbard and Jan Mayen', numeric='744'),
#  Country(alpha_2='SB', alpha_3='SLB', name='Solomon Islands', numeric='090'),
#  Country(alpha_2='SL', alpha_3='SLE', name='Sierra Leone', numeric='694', official_name='Republic of Sierra Leone'),
#  Country(alpha_2='SV', alpha_3='SLV', name='El Salvador', numeric='222', official_name='Republic of El Salvador'),
#  Country(alpha_2='SM', alpha_3='SMR', name='San Marino', numeric='674', official_name='Republic of San Marino'),
#  Country(alpha_2='SO', alpha_3='SOM', name='Somalia', numeric='706', official_name='Federal Republic of Somalia'),
#  Country(alpha_2='PM', alpha_3='SPM', name='Saint Pierre and Miquelon', numeric='666'),
#  Country(alpha_2='RS', alpha_3='SRB', name='Serbia', numeric='688', official_name='Republic of Serbia'),
#  Country(alpha_2='SS', alpha_3='SSD', name='South Sudan', numeric='728', official_name='Republic of South Sudan'),
#  Country(alpha_2='ST', alpha_3='STP', name='Sao Tome and Principe', numeric='678', official_name='Democratic Republic of Sao Tome and Principe'),
#  Country(alpha_2='SR', alpha_3='SUR', name='Suriname', numeric='740', official_name='Republic of Suriname'),
#  Country(alpha_2='SK', alpha_3='SVK', name='Slovakia', numeric='703', official_name='Slovak Republic'),
#  Country(alpha_2='SI', alpha_3='SVN', name='Slovenia', numeric='705', official_name='Republic of Slovenia'),
#  Country(alpha_2='SE', alpha_3='SWE', name='Sweden', numeric='752', official_name='Kingdom of Sweden'),
#  Country(alpha_2='SZ', alpha_3='SWZ', name='Swaziland', numeric='748', official_name='Kingdom of Swaziland'),
#  Country(alpha_2='SX', alpha_3='SXM', name='Sint Maarten (Dutch part)', numeric='534', official_name='Sint Maarten (Dutch part)'),
#  Country(alpha_2='SC', alpha_3='SYC', name='Seychelles', numeric='690', official_name='Republic of Seychelles'),
#  Country(alpha_2='SY', alpha_3='SYR', name='Syrian Arab Republic', numeric='760'),
#  Country(alpha_2='TC', alpha_3='TCA', name='Turks and Caicos Islands', numeric='796'),
#  Country(alpha_2='TD', alpha_3='TCD', name='Chad', numeric='148', official_name='Republic of Chad'),
#  Country(alpha_2='TG', alpha_3='TGO', name='Togo', numeric='768', official_name='Togolese Republic'),
#  Country(alpha_2='TH', alpha_3='THA', name='Thailand', numeric='764', official_name='Kingdom of Thailand'),
#  Country(alpha_2='TJ', alpha_3='TJK', name='Tajikistan', numeric='762', official_name='Republic of Tajikistan'),
#  Country(alpha_2='TK', alpha_3='TKL', name='Tokelau', numeric='772'),
#  Country(alpha_2='TM', alpha_3='TKM', name='Turkmenistan', numeric='795'),
#  Country(alpha_2='TL', alpha_3='TLS', name='Timor-Leste', numeric='626', official_name='Democratic Republic of Timor-Leste'),
#  Country(alpha_2='TO', alpha_3='TON', name='Tonga', numeric='776', official_name='Kingdom of Tonga'),
#  Country(alpha_2='TT', alpha_3='TTO', name='Trinidad and Tobago', numeric='780', official_name='Republic of Trinidad and Tobago'),
#  Country(alpha_2='TN', alpha_3='TUN', name='Tunisia', numeric='788', official_name='Republic of Tunisia'),
#  Country(alpha_2='TR', alpha_3='TUR', name='Turkey', numeric='792', official_name='Republic of Turkey'),
#  Country(alpha_2='TV', alpha_3='TUV', name='Tuvalu', numeric='798'),
#  Country(alpha_2='TW', alpha_3='TWN', common_name='Taiwan', name='Taiwan, Province of China', numeric='158', official_name='Taiwan, Province of China'),
#  Country(alpha_2='TZ', alpha_3='TZA', common_name='Tanzania', name='Tanzania, United Republic of', numeric='834', official_name='United Republic of Tanzania'),
#  Country(alpha_2='UG', alpha_3='UGA', name='Uganda', numeric='800', official_name='Republic of Uganda'),
#  Country(alpha_2='UA', alpha_3='UKR', name='Ukraine', numeric='804'),
#  Country(alpha_2='UM', alpha_3='UMI', name='United States Minor Outlying Islands', numeric='581'),
#  Country(alpha_2='UY', alpha_3='URY', name='Uruguay', numeric='858', official_name='Eastern Republic of Uruguay'),
#  Country(alpha_2='US', alpha_3='USA', name='United States', numeric='840', official_name='United States of America'),
#  Country(alpha_2='UZ', alpha_3='UZB', name='Uzbekistan', numeric='860', official_name='Republic of Uzbekistan'),
#  Country(alpha_2='VA', alpha_3='VAT', name='Holy See (Vatican City State)', numeric='336'),
#  Country(alpha_2='VC', alpha_3='VCT', name='Saint Vincent and the Grenadines', numeric='670'),
#  Country(alpha_2='VE', alpha_3='VEN', common_name='Venezuela', name='Venezuela, Bolivarian Republic of', numeric='862', official_name='Bolivarian Republic of Venezuela'),
#  Country(alpha_2='VG', alpha_3='VGB', name='Virgin Islands, British', numeric='092', official_name='British Virgin Islands'),
#  Country(alpha_2='VI', alpha_3='VIR', name='Virgin Islands, U.S.', numeric='850', official_name='Virgin Islands of the United States'),
#  Country(alpha_2='VN', alpha_3='VNM', name='Viet Nam', numeric='704', official_name='Socialist Republic of Viet Nam'),
#  Country(alpha_2='VU', alpha_3='VUT', name='Vanuatu', numeric='548', official_name='Republic of Vanuatu'),
#  Country(alpha_2='WF', alpha_3='WLF', name='Wallis and Futuna', numeric='876'),
#  Country(alpha_2='WS', alpha_3='WSM', name='Samoa', numeric='882', official_name='Independent State of Samoa'),
#  Country(alpha_2='YE', alpha_3='YEM', name='Yemen', numeric='887', official_name='Republic of Yemen'),
#  Country(alpha_2='ZA', alpha_3='ZAF', name='South Africa', numeric='710', official_name='Republic of South Africa'),
#  Country(alpha_2='ZM', alpha_3='ZMB', name='Zambia', numeric='894', official_name='Republic of Zambia'),
#  Country(alpha_2='ZW', alpha_3='ZWE', name='Zimbabwe', numeric='716', official_name='Republic of Zimbabwe')]

# %%
list_country = list(pycountry.countries)
country_dictionary = {}
country_set = []
for country in list_country:
    country_dictionary[(country.name).lower()] = [(country.alpha_2).lower(), (country.alpha_3).lower()]
    
    if (country.name).lower() == 'syrian arab republic':
        country_dictionary[(country.name).lower()] += ['syria']
    elif (country.name).lower() == 'russian federation':
        country_dictionary[(country.name).lower()] += ['russia']
    elif (country.name).lower() == 'united kingdomn':
        country_dictionary[(country.name).lower()] += ['uk', 'great britain']
    
    country_set.append((country.alpha_2).lower())
    country_set.append((country.alpha_3).lower())
    country_set.append((country.name).lower())
    
country_set += ['syria', 'russia', 'uk', 'great britain']
country_set = set(country_set)

# %%
from collections import defaultdict
mentions_dictionary = defaultdict(int)

# %%
keys = list(country_dictionary.keys())

for mail in emails['ExtractedBodyText_2']:
    for i in set(mail):
        if i in country_set:  
            
            # Insert the sentiment analysis add values to dictionary
            
            print (i)
            for k in keys:

                if k == i:
                    print ('if',k)
                    mentions_dictionary[k] += 1


                else:

                    values = country_dictionary[k]

                    for v in values:
                        if v == i:
                            print ('else', k)
                            mentions_dictionary[k] += 1
# Out:
# libya
# if libya
# syria
# else syrian arab republic
# libya
# if libya
# syria
# else syrian arab republic
# libya
# if libya
# syria
# else syrian arab republic
# libya
# if libya
# libya
# if libya
# arm
# else armenia
# col
# else colombia
# iraq
# if iraq
# russia
# else russian federation
# mn
# else mongolia
# libya
# if libya
# china
# if china
# france
# if france
# afghanistan
# if afghanistan
# libya
# if libya
# malta
# if malta
# libya
# if libya
# libya
# if libya
# libya
# if libya
# yemen
# if yemen
# egypt
# if egypt
# libya
# if libya
# yemen
# if yemen
# syria
# else syrian arab republic
# chad
# if chad
# qa
# else qatar
# egypt
# if egypt
# mm
# else myanmar
# libya
# if libya
# israel
# if israel
# na
# else namibia
# france
# if france
# gi
# else gibraltar
# egypt
# if egypt
# libya
# if libya
# tun
# else tunisia
# ws
# else samoa
# libya
# if libya
# cy
# else cyprus
# lie
# else liechtenstein
# ai
# else anguilla
# libya
# if libya
# aia
# else anguilla
# egypt
# if egypt
# libya
# if libya
# iraq
# if iraq
# egypt
# if egypt
# libya
# if libya
# syria
# else syrian arab republic
# israel
# if israel
# egypt
# if egypt
# libya
# if libya
# fin
# else finland
# ago
# else angola
# pg
# else papua new guinea
# pa
# else panama
# libya
# if libya
# uk
# spain
# if spain
# tunisia
# if tunisia
# col
# else colombia
# libya
# if libya
# libya
# if libya
# libya
# if libya
# egypt
# if egypt
# uk
# egypt
# if egypt
# uk
# libya
# if libya
# morocco
# if morocco
# jordan
# if jordan
# uk
# pa
# else panama
# libya
# if libya
# libya
# if libya
# libya
# if libya
# ca
# else canada
# libya
# if libya
# tunisia
# if tunisia
# turkey
# if turkey
# yemen
# if yemen
# ago
# else angola
# egypt
# if egypt
# libya
# if libya
# uk
# uk
# india
# if india
# qatar
# if qatar
# ca
# else canada
# ago
# else angola
# au
# else australia
# egypt
# if egypt
# libya
# if libya
# fro
# else faroe islands
# serbia
# if serbia
# sg
# else singapore
# georgia
# if georgia
# norway
# if norway
# azerbaijan
# if azerbaijan
# afghanistan
# if afghanistan
# libya
# if libya
# mc
# else monaco
# indonesia
# if indonesia
# libya
# if libya
# syria
# else syrian arab republic
# israel
# if israel
# mm
# else myanmar
# iraq
# if iraq
# co
# else colombia
# ago
# else angola
# libya
# if libya
# afghanistan
# if afghanistan
# ar
# else argentina
# et
# else ethiopia
# iraq
# if iraq
# libya
# if libya
# afghanistan
# if afghanistan
# libya
# if libya
# qatar
# if qatar
# est
# else estonia
# sen
# else senegal
# libya
# if libya
# syria
# else syrian arab republic
# th
# else thailand
# yemen
# if yemen
# co
# else colombia
# afghanistan
# if afghanistan
# tunisia
# if tunisia
# libya
# if libya
# morocco
# if morocco
# arm
# else armenia
# pakistan
# if pakistan
# iraq
# if iraq
# mexico
# if mexico
# indonesia
# if indonesia
# ms
# else montserrat
# jordan
# if jordan
# ago
# else angola
# egypt
# if egypt
# china
# if china
# per
# else peru
# libya
# if libya
# ms
# else montserrat
# ms
# else montserrat
# syria
# else syrian arab republic
# france
# if france
# turkey
# if turkey
# pg
# else papua new guinea
# sen
# else senegal
# libya
# if libya
# na
# else namibia
# ca
# else canada
# ht
# else haiti
# libya
# if libya
# ad
# else andorra
# lie
# else liechtenstein
# libya
# if libya
# libya
# if libya
# libya
# if libya
# uk
# libya
# if libya
# france
# if france
# uk
# libya
# if libya
# france
# if france
# jordan
# if jordan
# switzerland
# if switzerland
# qatar
# if qatar
# libya
# if libya
# de
# else germany
# italy
# if italy
# libya
# if libya
# cr
# else costa rica
# arm
# else armenia
# mc
# else monaco
# libya
# if libya
# libya
# if libya
# ck
# else cook islands
# libya
# if libya
# honduras
# if honduras
# ago
# else angola
# libya
# if libya
# morocco
# if morocco
# libya
# if libya
# liberia
# if liberia
# kazakhstan
# if kazakhstan
# india
# if india
# nc
# else new caledonia
# af
# else afghanistan
# iraq
# if iraq
# ken
# else kenya
# angola
# if angola
# indonesia
# if indonesia
# ago
# else angola
# italy
# if italy
# greece
# if greece
# honduras
# if honduras
# israel
# if israel
# ca
# else canada
# ca
# else canada
# morocco
# if morocco
# ireland
# if ireland
# bermuda
# if bermuda
# pt
# else portugal
# ca
# else canada
# haiti
# if haiti
# ca
# else canada
# sudan
# if sudan
# ca
# else canada
# ca
# else canada
# kuwait
# if kuwait
# ca
# else canada
# ca
# else canada
# congo
# if congo
# ca
# else canada
# mar
# else morocco
# se
# else sweden
# col
# else colombia
# cd
# else congo, the democratic republic of the
# ca
# else canada
# id
# else indonesia
# ai
# else anguilla
# ca
# else canada
# sl
# else sierra leone
# ar
# else argentina
# qatar
# if qatar
# india
# if india
# iraq
# if iraq
# singapore
# if singapore
# israel
# if israel
# pa
# else panama
# ago
# else angola
# se
# else sweden
# china
# if china
# cm
# else cameroon
# china
# if china
# af
# else afghanistan
# iraq
# if iraq
# af
# else afghanistan
# af
# else afghanistan
# pak
# else pakistan
# sl
# else sierra leone
# norway
# if norway
# bm
# else bermuda
# pakistan
# if pakistan
# india
# if india
# cyprus
# if cyprus
# turkey
# if turkey
# honduras
# if honduras
# morocco
# if morocco
# somalia
# if somalia
# ca
# else canada
# germany
# if germany
# ca
# else canada
# samoa
# if samoa
# ca
# else canada
# af
# else afghanistan
# pak
# else pakistan
# ca
# else canada
# turkey
# if turkey
# sen
# else senegal
# pakistan
# if pakistan
# iraq
# if iraq
# afghanistan
# if afghanistan
# ca
# else canada
# singapore
# if singapore
# bt
# else bhutan
# sen
# else senegal
# ireland
# if ireland
# cuba
# if cuba
# uk
# afghanistan
# if afghanistan
# ca
# else canada
# uk
# iraq
# if iraq
# co
# else colombia
# afghanistan
# if afghanistan
# ca
# else canada
# ca
# else canada
# per
# else peru
# ca
# else canada
# guatemala
# if guatemala
# et
# else ethiopia
# sen
# else senegal
# mar
# else morocco
# ca
# else canada
# ago
# else angola
# madagascar
# if madagascar
# pa
# else panama
# mexico
# if mexico
# mexico
# if mexico
# mexico
# if mexico
# mexico
# if mexico
# brazil
# if brazil
# mexico
# if mexico
# mexico
# if mexico
# st
# else sao tome and principe
# per
# else peru
# co
# else colombia
# usa
# else united states
# ph
# else philippines
# haiti
# if haiti
# brazil
# if brazil
# eg
# else egypt
# canada
# if canada
# japan
# if japan
# uruguay
# if uruguay
# argentina
# if argentina
# haiti
# if haiti
# ca
# else canada
# ago
# else angola
# au
# else australia
# mexico
# if mexico
# spain
# if spain
# brazil
# if brazil
# ai
# else anguilla
# co
# else colombia
# guy
# else guyana
# ago
# else angola
# mexico
# if mexico
# haiti
# if haiti
# cd
# else congo, the democratic republic of the
# libya
# if libya
# somalia
# if somalia
# st
# else sao tome and principe
# morocco
# if morocco
# guinea
# if guinea
# japan
# if japan
# ca
# else canada
# armenia
# if armenia
# kazakhstan
# if kazakhstan
# india
# if india
# af
# else afghanistan
# pak
# else pakistan
# se
# else sweden
# china
# if china
# afghanistan
# if afghanistan
# afghanistan
# if afghanistan
# per
# else peru
# china
# if china
# brazil
# if brazil
# india
# if india
# russia
# else russian federation
# uk
# germany
# if germany
# russia
# else russian federation
# china
# if china
# france
# if france
# kuwait
# if kuwait
# de
# else germany
# per
# else peru
# et
# else ethiopia
# ireland
# if ireland
# tunisia
# if tunisia
# ago
# else angola
# turkey
# if turkey
# iraq
# if iraq
# iraq
# if iraq
# palau
# if palau
# afghanistan
# if afghanistan
# china
# if china
# guy
# else guyana
# ph
# else philippines
# st
# else sao tome and principe
# mar
# else morocco
# ireland
# if ireland
# ph
# else philippines
# st
# else sao tome and principe
# mar
# else morocco
# ps
# else palestine, state of
# egypt
# if egypt
# japan
# if japan
# cyprus
# if cyprus
# china
# if china
# turkey
# if turkey
# indonesia
# if indonesia
# australia
# if australia
# india
# if india
# russia
# else russian federation
# brazil
# if brazil
# et
# else ethiopia
# se
# else sweden
# de
# else germany
# china
# if china
# hu
# else hungary
# pakistan
# if pakistan
# china
# if china
# afghanistan
# if afghanistan
# ca
# else canada
# jamaica
# if jamaica
# jamaica
# if jamaica
# cuba
# if cuba
# honduras
# if honduras
# ago
# else angola
# cuba
# if cuba
# honduras
# if honduras
# georgia
# if georgia
# brazil
# if brazil
# ca
# else canada
# md
# else moldova, republic of
# sen
# else senegal
# ad
# else andorra
# cuba
# if cuba
# ago
# else angola
# jpn
# else japan
# china
# if china
# kor
# else korea, republic of
# rus
# else russian federation
# chn
# else china
# guy
# else guyana
# hr
# else croatia
# va
# else holy see (vatican city state)
# iraq
# if iraq
# cuba
# if cuba
# afghanistan
# if afghanistan
# pa
# else panama
# uk
# ken
# else kenya
# mo
# else macao
# china
# if china
# mo
# else macao
# mo
# else macao
# ago
# else angola
# somalia
# if somalia
# italy
# if italy
# ethiopia
# if ethiopia
# uk
# bb
# else barbados
# usa
# else united states
# qatar
# if qatar
# ethiopia
# if ethiopia
# lebanon
# if lebanon
# uk
# china
# if china
# indonesia
# if indonesia
# indonesia
# if indonesia
# china
# if china
# se
# else sweden
# che
# else switzerland
# qatar
# if qatar
# ca
# else canada
# cv
# else cabo verde
# italy
# if italy
# india
# if india
# turkey
# if turkey
# israel
# if israel
# guy
# else guyana
# india
# if india
# id
# else indonesia
# ago
# else angola
# china
# if china
# iraq
# if iraq
# ge
# else georgia
# ca
# else canada
# palau
# if palau
# philippines
# if philippines
# per
# else peru
# afghanistan
# if afghanistan
# fro
# else faroe islands
# poland
# if poland
# ca
# else canada
# st
# else sao tome and principe
# co
# else colombia
# ph
# else philippines
# ki
# else kiribati
# uk
# id
# else indonesia
# va
# else holy see (vatican city state)
# ir
# else iran, islamic republic of
# tm
# else turkmenistan
# st
# else sao tome and principe
# cf
# else central african republic
# es
# else spain
# azerbaijan
# if azerbaijan
# ireland
# if ireland
# se
# else sweden
# argentina
# if argentina
# pak
# else pakistan
# ago
# else angola
# ago
# else angola
# ago
# else angola
# guy
# else guyana
# er
# else eritrea
# dk
# else denmark
# lt
# else lithuania
# jersey
# if jersey
# mar
# else morocco
# br
# else brazil
# ph
# else philippines
# ind
# else india
# pe
# else peru
# na
# else namibia
# antarctica
# if antarctica
# angola
# if angola
# cuba
# if cuba
# cambodia
# if cambodia
# china
# if china
# ca
# else canada
# se
# else sweden
# china
# if china
# per
# else peru
# china
# if china
# vi
# else virgin islands, u.s.
# cd
# else congo, the democratic republic of the
# ca
# else canada
# honduras
# if honduras
# co
# else colombia
# brazil
# if brazil
# pakistan
# if pakistan
# japan
# if japan
# myanmar
# if myanmar
# china
# if china
# ago
# else angola
# india
# if india
# palau
# if palau
# pak
# else pakistan
# af
# else afghanistan
# ghana
# if ghana
# ss
# else south sudan
# cv
# else cabo verde
# brazil
# if brazil
# mexico
# if mexico
# per
# else peru
# bb
# else barbados
# china
# if china
# brazil
# if brazil
# mexico
# if mexico
# singapore
# if singapore
# li
# else liechtenstein
# arm
# else armenia
# ps
# else palestine, state of
# hu
# else hungary
# albania
# if albania
# india
# if india
# russia
# else russian federation
# ca
# else canada
# st
# else sao tome and principe
# ago
# else angola
# china
# if china
# greece
# if greece
# france
# if france
# sen
# else senegal
# mongolia
# if mongolia
# cuba
# if cuba
# pol
# else poland
# palau
# if palau
# ca
# else canada
# eg
# else egypt
# china
# if china
# maldives
# if maldives
# cuba
# if cuba
# jam
# else jamaica
# per
# else peru
# cuba
# if cuba
# per
# else peru
# af
# else afghanistan
# pak
# else pakistan
# afghanistan
# if afghanistan
# brazil
# if brazil
# mexico
# if mexico
# ca
# else canada
# uk
# co
# else colombia
# pakistan
# if pakistan
# gf
# else french guiana
# guy
# else guyana
# honduras
# if honduras
# nc
# else new caledonia
# per
# else peru
# ago
# else angola
# kuwait
# if kuwait
# spain
# if spain
# honduras
# if honduras
# cv
# else cabo verde
# et
# else ethiopia
# au
# else australia
# ireland
# if ireland
# co
# else colombia
# ca
# else canada
# australia
# if australia
# nz
# else new zealand
# india
# if india
# vi
# else virgin islands, u.s.
# honduras
# if honduras
# co
# else colombia
# ga
# else gabon
# ga
# else gabon
# colombia
# if colombia
# bahamas
# if bahamas
# nigeria
# if nigeria
# china
# if china
# guy
# else guyana
# congo
# if congo
# liberia
# if liberia
# zimbabwe
# if zimbabwe
# kenya
# if kenya
# angola
# if angola
# per
# else peru
# pt
# else portugal
# sen
# else senegal
# haiti
# if haiti
# egypt
# if egypt
# mexico
# if mexico
# pa
# else panama
# ken
# else kenya
# honduras
# if honduras
# lb
# else lebanon
# china
# if china
# india
# if india
# thailand
# if thailand
# israel
# if israel
# india
# if india
# guam
# if guam
# de
# else germany
# palau
# if palau
# australia
# if australia
# per
# else peru
# japan
# if japan
# pakistan
# if pakistan
# india
# if india
# iraq
# if iraq
# mc
# else monaco
# japan
# if japan
# et
# else ethiopia
# china
# if china
# thailand
# if thailand
# russia
# else russian federation
# honduras
# if honduras
# sudan
# if sudan
# per
# else peru
# ton
# else tonga
# afghanistan
# if afghanistan
# russia
# else russian federation
# china
# if china
# sudan
# if sudan
# ca
# else canada
# ago
# else angola
# per
# else peru
# haiti
# if haiti
# pakistan
# if pakistan
# armenia
# if armenia
# turkey
# if turkey
# russia
# else russian federation
# angola
# if angola
# ago
# else angola
# kenya
# if kenya
# kenya
# if kenya
# russia
# else russian federation
# angola
# if angola
# cambodia
# if cambodia
# china
# if china
# ph
# else philippines
# india
# if india
# bangladesh
# if bangladesh
# per
# else peru
# afghanistan
# if afghanistan
# cg
# else congo
# kw
# else kuwait
# per
# else peru
# sa
# else saudi arabia
# se
# else sweden
# ireland
# if ireland
# sudan
# if sudan
# ps
# else palestine, state of
# sudan
# if sudan
# jo
# else jordan
# af
# else afghanistan
# bangladesh
# if bangladesh
# russia
# else russian federation
# ecuador
# if ecuador
# sl
# else sierra leone
# na
# else namibia
# va
# else holy see (vatican city state)
# norway
# if norway
# mt
# else malta
# iraq
# if iraq
# russia
# else russian federation
# ca
# else canada
# et
# else ethiopia
# ago
# else angola
# germany
# if germany
# pa
# else panama
# mo
# else macao
# afghanistan
# if afghanistan
# lu
# else luxembourg
# fro
# else faroe islands
# nr
# else nauru
# pa
# else panama
# vi
# else virgin islands, u.s.
# cr
# else costa rica
# tn
# else tunisia
# si
# else slovenia
# ge
# else georgia
# nr
# else nauru
# jam
# else jamaica
# ca
# else canada
# pakistan
# if pakistan
# palau
# if palau
# th
# else thailand
# pr
# else puerto rico
# ne
# else niger
# pak
# else pakistan
# spain
# if spain
# pa
# else panama
# chile
# if chile
# de
# else germany
# pakistan
# if pakistan
# india
# if india
# afghanistan
# if afghanistan
# philippines
# if philippines
# indonesia
# if indonesia
# philippines
# if philippines
# sl
# else sierra leone
# pa
# else panama
# indonesia
# if indonesia
# china
# if china
# russia
# else russian federation
# ken
# else kenya
# india
# if india
# chile
# if chile
# liberia
# if liberia
# iraq
# if iraq
# afghanistan
# if afghanistan
# russia
# else russian federation
# gm
# else gambia
# uk
# st
# else sao tome and principe
# ireland
# if ireland
# co
# else colombia
# ago
# else angola
# iraq
# if iraq
# per
# else peru
# afghanistan
# if afghanistan
# germany
# if germany
# egypt
# if egypt
# ago
# else angola
# bt
# else bhutan
# sd
# else sudan
# pakistan
# if pakistan
# nigeria
# if nigeria
# sudan
# if sudan
# syria
# else syrian arab republic
# haiti
# if haiti
# iraq
# if iraq
# uganda
# if uganda
# afghanistan
# if afghanistan
# congo
# if congo
# pakistan
# if pakistan
# turkey
# if turkey
# iraq
# if iraq
# india
# if india
# russia
# else russian federation
# china
# if china
# indonesia
# if indonesia
# cuba
# if cuba
# afghanistan
# if afghanistan
# brazil
# if brazil
# honduras
# if honduras
# per
# else peru
# rs
# else serbia
# bi
# else burundi
# uk
# ireland
# if ireland
# panama
# if panama
# latvia
# if latvia
# poland
# if poland
# ss
# else south sudan
# ca
# else canada
# co
# else colombia
# honduras
# if honduras
# israel
# if israel
# pr
# else puerto rico
# sen
# else senegal
# afghanistan
# if afghanistan
# brazil
# if brazil
# iraq
# if iraq
# afghanistan
# if afghanistan
# honduras
# if honduras
# colombia
# if colombia
# honduras
# if honduras
# colombia
# if colombia
# ad
# else andorra
# afghanistan
# if afghanistan
# ago
# else angola
# st
# else sao tome and principe
# ni
# else nicaragua
# co
# else colombia
# nz
# else new zealand
# ind
# else india
# ie
# else ireland
# afghanistan
# if afghanistan
# sy
# else syrian arab republic
# de
# else germany
# id
# else indonesia
# jp
# else japan
# se
# else sweden
# co
# else colombia
# il
# else israel
# th
# else thailand
# pe
# else peru
# pr
# else puerto rico
# fin
# else finland
# ago
# else angola
# ca
# else canada
# ago
# else angola
# turkey
# if turkey
# poland
# if poland
# russia
# else russian federation
# ca
# else canada
# ago
# else angola
# russia
# else russian federation
# bb
# else barbados
# bb
# else barbados
# bb
# else barbados
# ken
# else kenya
# palau
# if palau
# ca
# else canada
# ca
# else canada
# armenia
# if armenia
# turkey
# if turkey
# greece
# if greece
# ni
# else nicaragua
# israel
# if israel
# ca
# else canada
# ca
# else canada
# ago
# else angola
# honduras
# if honduras
# honduras
# if honduras
# af
# else afghanistan
# iraq
# if iraq
# pak
# else pakistan
# per
# else peru
# iraq
# if iraq
# pakistan
# if pakistan
# hu
# else hungary
# co
# else colombia
# mp
# else northern mariana islands
# libya
# if libya
# na
# else namibia
# pakistan
# if pakistan
# japan
# if japan
# china
# if china
# col
# else colombia
# russia
# else russian federation
# pan
# else panama
# libya
# if libya
# pakistan
# if pakistan
# armenia
# if armenia
# turkey
# if turkey
# slovenia
# if slovenia
# armenia
# if armenia
# turkey
# if turkey
# pakistan
# if pakistan
# china
# if china
# turkey
# if turkey
# af
# else afghanistan
# pak
# else pakistan
# afghanistan
# if afghanistan
# congo
# if congo
# bermuda
# if bermuda
# et
# else ethiopia
# per
# else peru
# et
# else ethiopia
# co
# else colombia
# il
# else israel
# fr
# else france
# japan
# if japan
# india
# if india
# per
# else peru
# bangladesh
# if bangladesh
# ireland
# if ireland
# tn
# else tunisia
# rwanda
# if rwanda
# pakistan
# if pakistan
# iraq
# if iraq
# haiti
# if haiti
# russia
# else russian federation
# jordan
# if jordan
# china
# if china
# israel
# if israel
# norway
# if norway
# norway
# if norway
# co
# else colombia
# sudan
# if sudan
# pr
# else puerto rico
# per
# else peru
# palau
# if palau
# co
# else colombia
# egypt
# if egypt
# ci
# else côte d'ivoire
# bi
# else burundi
# png
# else papua new guinea
# ireland
# if ireland
# usa
# else united states
# haiti
# if haiti
# ca
# else canada
# ind
# else india
# sen
# else senegal
# ala
# else åland islands
# bm
# else bermuda
# morocco
# if morocco
# guy
# else guyana
# honduras
# if honduras
# poland
# if poland
# ss
# else south sudan
# uk
# france
# if france
# russia
# else russian federation
# afghanistan
# if afghanistan
# pakistan
# if pakistan
# haiti
# if haiti
# iraq
# if iraq
# india
# if india
# ca
# else canada
# israel
# if israel
# afghanistan
# if afghanistan
# de
# else germany
# somalia
# if somalia
# af
# else afghanistan
# pakistan
# if pakistan
# iraq
# if iraq
# yemen
# if yemen
# pak
# else pakistan
# ton
# else tonga
# afghanistan
# if afghanistan
# de
# else germany
# ms
# else montserrat
# ms
# else montserrat
# china
# if china
# ms
# else montserrat
# mo
# else macao
# pa
# else panama
# sen
# else senegal
# afghanistan
# if afghanistan
# india
# if india
# jersey
# if jersey
# st
# else sao tome and principe
# georgia
# if georgia
# mexico
# if mexico
# ca
# else canada
# honduras
# if honduras
# pakistan
# if pakistan
# singapore
# if singapore
# il
# else israel
# india
# if india
# afghanistan
# if afghanistan
# slovenia
# if slovenia
# af
# else afghanistan
# pak
# else pakistan
# per
# else peru
# uk
# ago
# else angola
# australia
# if australia
# per
# else peru
# afghanistan
# if afghanistan
# jersey
# if jersey
# ph
# else philippines
# lt
# else lithuania
# pe
# else peru
# sen
# else senegal
# afghanistan
# if afghanistan
# va
# else holy see (vatican city state)
# jersey
# if jersey
# lie
# else liechtenstein
# ca
# else canada
# japan
# if japan
# russia
# else russian federation
# ca
# else canada
# co
# else colombia
# ago
# else angola
# per
# else peru
# uzbekistan
# if uzbekistan
# china
# if china
# afghanistan
# if afghanistan
# china
# if china
# per
# else peru
# bangladesh
# if bangladesh
# japan
# if japan
# china
# if china
# india
# if india
# angola
# if angola
# per
# else peru
# china
# if china
# uk
# lie
# else liechtenstein
# iq
# else iraq
# co
# else colombia
# se
# else sweden
# mu
# else mauritius
# lt
# else lithuania
# iraq
# if iraq
# kazakhstan
# if kazakhstan
# af
# else afghanistan
# mexico
# if mexico
# pak
# else pakistan
# azerbaijan
# if azerbaijan
# uk
# afghanistan
# if afghanistan
# afghanistan
# if afghanistan
# st
# else sao tome and principe
# il
# else israel
# uganda
# if uganda
# ca
# else canada
# ms
# else montserrat
# syria
# else syrian arab republic
# somalia
# if somalia
# pakistan
# if pakistan
# afghanistan
# if afghanistan
# qatar
# if qatar
# brazil
# if brazil
# ago
# else angola
# germany
# if germany
# de
# else germany
# brazil
# if brazil
# honduras
# if honduras
# mexico
# if mexico
# ad
# else andorra
# ago
# else angola
# ca
# else canada
# china
# if china
# guinea
# if guinea
# madagascar
# if madagascar
# zambia
# if zambia
# au
# else australia
# norway
# if norway
# sweden
# if sweden
# japan
# if japan
# ago
# else angola
# germany
# if germany
# france
# if france
# china
# if china
# russia
# else russian federation
# haiti
# if haiti
# haiti
# if haiti
# pakistan
# if pakistan
# peru
# if peru
# uruguay
# if uruguay
# brazil
# if brazil
# argentina
# if argentina
# france
# if france
# chile
# if chile
# haiti
# if haiti
# mexico
# if mexico
# italy
# if italy
# per
# else peru
# st
# else sao tome and principe
# ago
# else angola
# guinea
# if guinea
# singapore
# if singapore
# lt
# else lithuania
# va
# else holy see (vatican city state)
# rwanda
# if rwanda
# af
# else afghanistan
# japan
# if japan
# mar
# else morocco
# nigeria
# if nigeria
# iraq
# if iraq
# kenya
# if kenya
# india
# if india
# vi
# else virgin islands, u.s.
# md
# else moldova, republic of
# pak
# else pakistan
# pa
# else panama
# ethiopia
# if ethiopia
# ga
# else gabon
# china
# if china
# indonesia
# if indonesia
# nga
# else nigeria
# brazil
# if brazil
# nr
# else nauru
# ago
# else angola
# per
# else peru
# israel
# if israel
# ago
# else angola
# israel
# if israel
# ago
# else angola
# pa
# else panama
# italy
# if italy
# australia
# if australia
# spain
# if spain
# japan
# if japan
# denmark
# if denmark
# netherlands
# if netherlands
# norway
# if norway
# romania
# if romania
# france
# if france
# canada
# if canada
# poland
# if poland
# sweden
# if sweden
# af
# else afghanistan
# pak
# else pakistan
# romania
# if romania
# et
# else ethiopia
# pr
# else puerto rico
# mm
# else myanmar
# afghanistan
# if afghanistan
# est
# else estonia
# km
# else comoros
# afghanistan
# if afghanistan
# haiti
# if haiti
# est
# else estonia
# est
# else estonia
# nepal
# if nepal
# afghanistan
# if afghanistan
# japan
# if japan
# china
# if china
# argentina
# if argentina
# argentina
# if argentina
# chile
# if chile
# israel
# if israel
# pakistan
# if pakistan
# albania
# if albania
# palau
# if palau
# bermuda
# if bermuda
# ago
# else angola
# china
# if china
# afghanistan
# if afghanistan
# sr
# else suriname
# hr
# else croatia
# ca
# else canada
# af
# else afghanistan
# iraq
# if iraq
# pak
# else pakistan
# per
# else peru
# io
# else british indian ocean territory
# pa
# else panama
# japan
# if japan
# cn
# else china
# switzerland
# if switzerland
# st
# else sao tome and principe
# china
# if china
# ph
# else philippines
# per
# else peru
# id
# else indonesia
# iraq
# if iraq
# ago
# else angola
# afghanistan
# if afghanistan
# pakistan
# if pakistan
# afghanistan
# if afghanistan
# cg
# else congo
# iraq
# if iraq
# poland
# if poland
# france
# if france
# per
# else peru
# rwanda
# if rwanda
# uganda
# if uganda
# usa
# else united states
# india
# if india
# ago
# else angola
# uk
# ireland
# if ireland
# haiti
# if haiti
# ca
# else canada
# honduras
# if honduras
# brazil
# if brazil
# turkey
# if turkey
# af
# else afghanistan
# egy
# else egypt
# uk
# haiti
# if haiti
# india
# if india
# uk
# india
# if india
# maldives
# if maldives
# ca
# else canada
# sudan
# if sudan
# australia
# if australia
# mexico
# if mexico
# china
# if china
# ki
# else kiribati
# brazil
# if brazil
# jm
# else jamaica
# afghanistan
# if afghanistan
# bb
# else barbados
# af
# else afghanistan
# pak
# else pakistan
# pr
# else puerto rico
# haiti
# if haiti
# honduras
# if honduras
# mexico
# if mexico
# mp
# else northern mariana islands
# uruguay
# if uruguay
# argentina
# if argentina
# honduras
# if honduras
# peru
# if peru
# au
# else australia
# ago
# else angola
# india
# if india
# ms
# else montserrat
# haiti
# if haiti
# im
# else isle of man
# jm
# else jamaica
# pr
# else puerto rico
# haiti
# if haiti
# au
# else australia
# ago
# else angola
# ca
# else canada
# per
# else peru
# co
# else colombia
# sc
# else seychelles
# pa
# else panama
# co
# else colombia
# china
# if china
# pa
# else panama
# india
# if india
# uganda
# if uganda
# pl
# else poland
# lt
# else lithuania
# pakistan
# if pakistan
# iraq
# if iraq
# ai
# else anguilla
# afghanistan
# if afghanistan
# pakistan
# if pakistan
# per
# else peru
# est
# else estonia
# ca
# else canada
# ca
# else canada
# singapore
# if singapore
# mo
# else macao
# id
# else indonesia
# uruguay
# if uruguay
# uruguay
# if uruguay
# egypt
# if egypt
# yemen
# if yemen
# lithuania
# if lithuania
# guy
# else guyana
# israel
# if israel
# chile
# if chile
# ago
# else angola
# ag
# else antigua and barbuda
# haiti
# if haiti
# syria
# else syrian arab republic
# ghana
# if ghana
# lebanon
# if lebanon
# japan
# if japan
# nigeria
# if nigeria
# haiti
# if haiti
# angola
# if angola
# ca
# else canada
# cg
# else congo
# au
# else australia
# jo
# else jordan
# australia
# if australia
# pa
# else panama
# libya
# if libya
# ba
# else bosnia and herzegovina
# indonesia
# if indonesia
# greece
# if greece
# france
# if france
# malaysia
# if malaysia
# senegal
# if senegal
# morocco
# if morocco
# de
# else germany
# co
# else colombia
# china
# if china
# im
# else isle of man
# er
# else eritrea
# canada
# if canada
# tn
# else tunisia
# ad
# else andorra
# jersey
# if jersey
# om
# else oman
# lc
# else saint lucia
# td
# else chad
# ci
# else côte d'ivoire
# sen
# else senegal
# mc
# else monaco
# oman
# if oman
# pt
# else portugal
# iraq
# if iraq
# russia
# else russian federation
# ai
# else anguilla
# china
# if china
# az
# else azerbaijan
# afghanistan
# if afghanistan
# de
# else germany
# haiti
# if haiti
# jm
# else jamaica
# lt
# else lithuania
# myanmar
# if myanmar
# china
# if china
# cuba
# if cuba
# ad
# else andorra
# est
# else estonia
# georgia
# if georgia
# russia
# else russian federation
# jordan
# if jordan
# ago
# else angola
# israel
# if israel
# afghanistan
# if afghanistan
# pse
# else palestine, state of
# ms
# else montserrat
# st
# else sao tome and principe
# russia
# else russian federation
# vi
# else virgin islands, u.s.
# pakistan
# if pakistan
# ca
# else canada
# im
# else isle of man
# st
# else sao tome and principe
# haiti
# if haiti
# jm
# else jamaica
# et
# else ethiopia
# ni
# else nicaragua
# est
# else estonia
# st
# else sao tome and principe
# pr
# else puerto rico
# mm
# else myanmar
# uk
# ireland
# if ireland
# co
# else colombia
# tuv
# else tuvalu
# uk
# ireland
# if ireland
# co
# else colombia
# pa
# else panama
# uk
# haiti
# if haiti
# ie
# else ireland
# ni
# else nicaragua
# ni
# else nicaragua
# ireland
# if ireland
# pakistan
# if pakistan
# st
# else sao tome and principe
# india
# if india
# armenia
# if armenia
# turkey
# if turkey
# ms
# else montserrat
# per
# else peru
# pr
# else puerto rico
# mm
# else myanmar
# haiti
# if haiti
# afghanistan
# if afghanistan
# uk
# ireland
# if ireland
# tuv
# else tuvalu
# sr
# else suriname
# st
# else sao tome and principe
# co
# else colombia
# ago
# else angola
# na
# else namibia
# co
# else colombia
# sen
# else senegal
# ala
# else åland islands
# pakistan
# if pakistan
# co
# else colombia
# canada
# if canada
# ago
# else angola
# angola
# if angola
# luxembourg
# if luxembourg
# cyprus
# if cyprus
# uk
# belgium
# if belgium
# germany
# if germany
# netherlands
# if netherlands
# brazil
# if brazil
# austria
# if austria
# israel
# if israel
# jordan
# if jordan
# israel
# if israel
# egypt
# if egypt
# ecuador
# if ecuador
# bahrain
# if bahrain
# qatar
# if qatar
# honduras
# if honduras
# pakistan
# if pakistan
# afghanistan
# if afghanistan
# gb
# else united kingdom
# usa
# else united states
# china
# if china
# co
# else colombia
# haiti
# if haiti
# ireland
# if ireland
# mp
# else northern mariana islands
# pa
# else panama
# ni
# else nicaragua
# haiti
# if haiti
# pakistan
# if pakistan
# jm
# else jamaica
# uk
# congo
# if congo
# haiti
# if haiti
# co
# else colombia
# au
# else australia
# per
# else peru
# gi
# else gibraltar
# ca
# else canada
# luxembourg
# if luxembourg
# ca
# else canada
# uk
# er
# else eritrea
# et
# else ethiopia
# co
# else colombia
# lt
# else lithuania
# sa
# else saudi arabia
# pf
# else french polynesia
# iraq
# if iraq
# spain
# if spain
# nr
# else nauru
# rs
# else serbia
# pakistan
# if pakistan
# pr
# else puerto rico
# afghanistan
# if afghanistan
# et
# else ethiopia
# cuba
# if cuba
# palau
# if palau
# israel
# if israel
# ago
# else angola
# per
# else peru
# tl
# else timor-leste
# mar
# else morocco
# haiti
# if haiti
# ck
# else cook islands
# ago
# else angola
# gb
# else united kingdom
# ca
# else canada
# st
# else sao tome and principe
# ago
# else angola
# vat
# else holy see (vatican city state)
# pakistan
# if pakistan
# bn
# else brunei darussalam
# argentina
# if argentina
# chile
# if chile
# jersey
# if jersey
# angola
# if angola
# yemen
# if yemen
# brazil
# if brazil
# mexico
# if mexico
# nigeria
# if nigeria
# sudan
# if sudan
# bi
# else burundi
# indonesia
# if indonesia
# tn
# else tunisia
# au
# else australia
# georgia
# if georgia
# china
# if china
# jm
# else jamaica
# jm
# else jamaica
# per
# else peru
# haiti
# if haiti
# iraq
# if iraq
# afghanistan
# if afghanistan
# haiti
# if haiti
# est
# else estonia
# sen
# else senegal
# pakistan
# if pakistan
# mar
# else morocco
# china
# if china
# india
# if india
# ch
# else switzerland
# pakistan
# if pakistan
# jm
# else jamaica
# uk
# brazil
# if brazil
# chile
# if chile
# chile
# if chile
# guinea
# if guinea
# haiti
# if haiti
# haiti
# if haiti
# ms
# else montserrat
# sr
# else suriname
# co
# else colombia
# ago
# else angola
# china
# if china
# haiti
# if haiti
# ken
# else kenya
# ky
# else cayman islands
# st
# else sao tome and principe
# co
# else colombia
# est
# else estonia
# ms
# else montserrat
# th
# else thailand
# cg
# else congo
# haiti
# if haiti
# au
# else australia
# pakistan
# if pakistan
# haiti
# if haiti
# ne
# else niger
# dom
# else dominican republic
# ni
# else nicaragua
# per
# else peru
# ireland
# if ireland
# japan
# if japan
# ca
# else canada
# china
# if china
# germany
# if germany
# pa
# else panama
# per
# else peru
# et
# else ethiopia
# mar
# else morocco
# china
# if china
# som
# else somalia
# canada
# if canada
# haiti
# if haiti
# ec
# else ecuador
# france
# if france
# spain
# if spain
# atf
# else french southern territories
# iraq
# if iraq
# ng
# else nigeria
# israel
# if israel
# ne
# else niger
# bi
# else burundi
# afghanistan
# if afghanistan
# guinea
# if guinea
# afghanistan
# if afghanistan
# id
# else indonesia
# ad
# else andorra
# pakistan
# if pakistan
# japan
# if japan
# mar
# else morocco
# uruguay
# if uruguay
# argentina
# if argentina
# zambia
# if zambia
# ca
# else canada
# mexico
# if mexico
# switzerland
# if switzerland
# indonesia
# if indonesia
# france
# if france
# brazil
# if brazil
# st
# else sao tome and principe
# ni
# else nicaragua
# im
# else isle of man
# uk
# uk
# lbr
# else liberia
# co
# else colombia
# geo
# else georgia
# pakistan
# if pakistan
# haiti
# if haiti
# mexico
# if mexico
# co
# else colombia
# im
# else isle of man
# egypt
# if egypt
# kyrgyzstan
# if kyrgyzstan
# lithuania
# if lithuania
# russia
# else russian federation
# poland
# if poland
# cuba
# if cuba
# poland
# if poland
# de
# else germany
# ireland
# if ireland
# armenia
# if armenia
# co
# else colombia
# algeria
# if algeria
# singapore
# if singapore
# thailand
# if thailand
# turkey
# if turkey
# morocco
# if morocco
# cuba
# if cuba
# usa
# else united states
# pakistan
# if pakistan
# iraq
# if iraq
# yemen
# if yemen
# ago
# else angola
# israel
# if israel
# afghanistan
# if afghanistan
# ni
# else nicaragua
# uk
# gb
# else united kingdom
# st
# else sao tome and principe
# co
# else colombia
# ago
# else angola
# vat
# else holy see (vatican city state)
# per
# else peru
# pakistan
# if pakistan
# iraq
# if iraq
# afghanistan
# if afghanistan
# yemen
# if yemen
# de
# else germany
# indonesia
# if indonesia
# iraq
# if iraq
# haiti
# if haiti
# gs
# else south georgia and the south sandwich islands
# haiti
# if haiti
# uk
# ireland
# if ireland
# co
# else colombia
# ireland
# if ireland
# ago
# else angola
# uk
# ireland
# if ireland
# co
# else colombia
# pa
# else panama
# libya
# if libya
# ireland
# if ireland
# sk
# else slovakia
# ago
# else angola
# fr
# else france
# rs
# else serbia
# israel
# if israel
# uk
# er
# else eritrea
# ireland
# if ireland
# usa
# else united states
# li
# else liechtenstein
# va
# else holy see (vatican city state)
# pt
# else portugal
# ad
# else andorra
# mar
# else morocco
# lie
# else liechtenstein
# sz
# else swaziland
# ca
# else canada
# co
# else colombia
# il
# else israel
# ng
# else nigeria
# ago
# else angola
# gt
# else guatemala
# mp
# else northern mariana islands
# ie
# else ireland
# spain
# if spain
# ga
# else gabon
# uzbekistan
# if uzbekistan
# az
# else azerbaijan
# afghanistan
# if afghanistan
# haiti
# if haiti
# lt
# else lithuania
# ago
# else angola
# afg
# else afghanistan
# iceland
# if iceland
# co
# else colombia
# belgium
# if belgium
# lithuania
# if lithuania
# poland
# if poland
# cd
# else congo, the democratic republic of the
# prt
# else portugal
# afghanistan
# if afghanistan
# ireland
# if ireland
# col
# else colombia
# et
# else ethiopia
# uk
# ireland
# if ireland
# ad
# else andorra
# sz
# else swaziland
# co
# else colombia
# ng
# else nigeria
# ago
# else angola
# gt
# else guatemala
# ie
# else ireland
# py
# else paraguay
# turkey
# if turkey
# panama
# if panama
# paraguay
# if paraguay
# cuba
# if cuba
# honduras
# if honduras
# ecuador
# if ecuador
# guatemala
# if guatemala
# nicaragua
# if nicaragua
# chile
# if chile
# haiti
# if haiti
# poland
# if poland
# estonia
# if estonia
# usa
# else united states
# egypt
# if egypt
# pakistan
# if pakistan
# uk
# co
# else colombia
# afghanistan
# if afghanistan
# pr
# else puerto rico
# sudan
# if sudan
# kenya
# if kenya
# ms
# else montserrat
# ad
# else andorra
# ita
# else italy
# co
# else colombia
# bi
# else burundi
# sen
# else senegal
# sur
# else suriname
# de
# else germany
# ca
# else canada
# gt
# else guatemala
# mexico
# if mexico
# lt
# else lithuania
# ago
# else angola
# es
# else spain
# china
# if china
# china
# if china
# ago
# else angola
# ca
# else canada
# uk
# haiti
# if haiti
# ms
# else montserrat
# ago
# else angola
# germany
# if germany
# switzerland
# if switzerland
# greece
# if greece
# de
# else germany
# iraq
# if iraq
# israel
# if israel
# turkey
# if turkey
# egypt
# if egypt
# russia
# else russian federation
# indonesia
# if indonesia
# ca
# else canada
# uk
# pakistan
# if pakistan
# ca
# else canada
# ad
# else andorra
# sen
# else senegal
# sudan
# if sudan
# sen
# else senegal
# md
# else moldova, republic of
# usa
# else united states
# hk
# else hong kong
# im
# else isle of man
# tt
# else trinidad and tobago
# israel
# if israel
# usa
# else united states
# hu
# else hungary
# cg
# else congo
# china
# if china
# cm
# else cameroon
# nam
# else namibia
# usa
# else united states
# ca
# else canada
# iraq
# if iraq
# afghanistan
# if afghanistan
# ca
# else canada
# jordan
# if jordan
# israel
# if israel
# ago
# else angola
# pakistan
# if pakistan
# jm
# else jamaica
# qatar
# if qatar
# kuwait
# if kuwait
# haiti
# if haiti
# china
# if china
# guy
# else guyana
# haiti
# if haiti
# per
# else peru
# pakistan
# if pakistan
# china
# if china
# india
# if india
# mexico
# if mexico
# se
# else sweden
# co
# else colombia
# ken
# else kenya
# pakistan
# if pakistan
# fo
# else faroe islands
# india
# if india
# pak
# else pakistan
# afghanistan
# if afghanistan
# ca
# else canada
# guy
# else guyana
# mexico
# if mexico
# ireland
# if ireland
# esp
# else spain
# lt
# else lithuania
# pakistan
# if pakistan
# haiti
# if haiti
# iraq
# if iraq
# im
# else isle of man
# israel
# if israel
# afghanistan
# if afghanistan
# tf
# else french southern territories
# palau
# if palau
# bl
# else saint barthélemy
# es
# else spain
# usa
# else united states
# china
# if china
# sc
# else seychelles
# rs
# else serbia
# kyrgyzstan
# if kyrgyzstan
# uk
# gb
# else united kingdom
# st
# else sao tome and principe
# co
# else colombia
# iraq
# if iraq
# ag
# else antigua and barbuda
# vat
# else holy see (vatican city state)
# ms
# else montserrat
# netherlands
# if netherlands
# canada
# if canada
# spain
# if spain
# belgium
# if belgium
# iceland
# if iceland
# mexico
# if mexico
# norway
# if norway
# portugal
# if portugal
# sweden
# if sweden
# israel
# if israel
# egypt
# if egypt
# pa
# else panama
# germany
# if germany
# france
# if france
# afghanistan
# if afghanistan
# jm
# else jamaica
# ago
# else angola
# russia
# else russian federation
# haiti
# if haiti
# china
# if china
# germany
# if germany
# france
# if france
# russia
# else russian federation
# canada
# if canada
# haiti
# if haiti
# id
# else indonesia
# uk
# ireland
# if ireland
# ni
# else nicaragua
# co
# else colombia
# gi
# else gibraltar
# mp
# else northern mariana islands
# haiti
# if haiti
# sudan
# if sudan
# ago
# else angola
# li
# else liechtenstein
# pakistan
# if pakistan
# ms
# else montserrat
# iraq
# if iraq
# india
# if india
# russia
# else russian federation
# co
# else colombia
# guy
# else guyana
# china
# if china
# israel
# if israel
# afghanistan
# if afghanistan
# ecuador
# if ecuador
# pakistan
# if pakistan
# iraq
# if iraq
# ca
# else canada
# ph
# else philippines
# ago
# else angola
# egypt
# if egypt
# afghanistan
# if afghanistan
# civ
# else côte d'ivoire
# ms
# else montserrat
# ms
# else montserrat
# haiti
# if haiti
# uganda
# if uganda
# jm
# else jamaica
# jm
# else jamaica
# pakistan
# if pakistan
# ms
# else montserrat
# japan
# if japan
# tunisia
# if tunisia
# il
# else israel
# ago
# else angola
# egypt
# if egypt
# uzbekistan
# if uzbekistan
# china
# if china
# haiti
# if haiti
# mozambique
# if mozambique
# canada
# if canada
# belgium
# if belgium
# ago
# else angola
# haiti
# if haiti
# germany
# if germany
# france
# if france
# netherlands
# if netherlands
# spain
# if spain
# japan
# if japan
# ph
# else philippines
# haiti
# if haiti
# haiti
# if haiti
# haiti
# if haiti
# ca
# else canada
# china
# if china
# singapore
# if singapore
# az
# else azerbaijan
# de
# else germany
# ad
# else andorra
# cu
# else cuba
# honduras
# if honduras
# ec
# else ecuador
# indonesia
# if indonesia
# haiti
# if haiti
# mu
# else mauritius
# bi
# else burundi
# ms
# else montserrat
# ca
# else canada
# syria
# else syrian arab republic
# israel
# if israel
# israel
# if israel
# lie
# else liechtenstein
# id
# else indonesia
# ms
# else montserrat
# cuba
# if cuba
# israel
# if israel
# haiti
# if haiti
# haiti
# if haiti
# haiti
# if haiti
# sg
# else singapore
# israel
# if israel
# pr
# else puerto rico
# ms
# else montserrat
# ms
# else montserrat
# cn
# else china
# ca
# else canada
# et
# else ethiopia
# td
# else chad
# co
# else colombia
# mexico
# if mexico
# afghanistan
# if afghanistan
# israel
# if israel
# russia
# else russian federation
# india
# if india
# tajikistan
# if tajikistan
# turkmenistan
# if turkmenistan
# afghanistan
# if afghanistan
# india
# if india
# bi
# else burundi
# uk
# turkey
# if turkey
# iraq
# if iraq
# russia
# else russian federation
# co
# else colombia
# egypt
# if egypt
# israel
# if israel
# pr
# else puerto rico
# de
# else germany
# ago
# else angola
# india
# if india
# sm
# else san marino
# ca
# else canada
# st
# else sao tome and principe
# ca
# else canada
# per
# else peru
# lu
# else luxembourg
# israel
# if israel
# turkey
# if turkey
# haiti
# if haiti
# pakistan
# if pakistan
# mp
# else northern mariana islands
# st
# else sao tome and principe
# mp
# else northern mariana islands
# colombia
# if colombia
# iceland
# if iceland
# co
# else colombia
# lithuania
# if lithuania
# cd
# else congo, the democratic republic of the
# afghanistan
# if afghanistan
# pa
# else panama
# romania
# if romania
# germany
# if germany
# ukraine
# if ukraine
# russia
# else russian federation
# de
# else germany
# ukraine
# if ukraine
# belarus
# if belarus
# qatar
# if qatar
# haiti
# if haiti
# france
# if france
# russia
# else russian federation
# brazil
# if brazil
# ca
# else canada
# guy
# else guyana
# ago
# else angola
# brazil
# if brazil
# turkey
# if turkey
# norway
# if norway
# pakistan
# if pakistan
# gb
# else united kingdom
# uruguay
# if uruguay
# argentina
# if argentina
# turkey
# if turkey
# iraq
# if iraq
# russia
# else russian federation
# ca
# else canada
# ao
# else angola
# co
# else colombia
# ago
# else angola
# per
# else peru
# chile
# if chile
# china
# if china
# israel
# if israel
# indonesia
# if indonesia
# afghanistan
# if afghanistan
# brazil
# if brazil
# de
# else germany
# st
# else sao tome and principe
# sc
# else seychelles
# greece
# if greece
# il
# else israel
# russia
# else russian federation
# uk
# pakistan
# if pakistan
# et
# else ethiopia
# ago
# else angola
# afghanistan
# if afghanistan
# co
# else colombia
# guy
# else guyana
# bs
# else bahamas
# israel
# if israel
# sen
# else senegal
# ken
# else kenya
# israel
# if israel
# ca
# else canada
# ro
# else romania
# canada
# if canada
# co
# else colombia
# germany
# if germany
# rs
# else serbia
# france
# if france
# afghanistan
# if afghanistan
# civ
# else côte d'ivoire
# pakistan
# if pakistan
# iraq
# if iraq
# ca
# else canada
# mexico
# if mexico
# netherlands
# if netherlands
# lt
# else lithuania
# algeria
# if algeria
# col
# else colombia
# guy
# else guyana
# ago
# else angola
# israel
# if israel
# mongolia
# if mongolia
# afghanistan
# if afghanistan
# ca
# else canada
# et
# else ethiopia
# usa
# else united states
# algeria
# if algeria
# ca
# else canada
# ago
# else angola
# russia
# else russian federation
# fr
# else france
# civ
# else côte d'ivoire
# singapore
# if singapore
# japan
# if japan
# india
# if india
# russia
# else russian federation
# australia
# if australia
# per
# else peru
# china
# if china
# de
# else germany
# ago
# else angola
# fo
# else faroe islands
# uk
# ca
# else canada
# uk
# qatar
# if qatar
# afghanistan
# if afghanistan
# cuba
# if cuba
# ago
# else angola
# ireland
# if ireland
# belgium
# if belgium
# italy
# if italy
# co
# else colombia
# germany
# if germany
# portugal
# if portugal
# spain
# if spain
# greece
# if greece
# france
# if france
# austria
# if austria
# mp
# else northern mariana islands
# ca
# else canada
# ca
# else canada
# ca
# else canada
# ca
# else canada
# st
# else sao tome and principe
# co
# else colombia
# kr
# else korea, republic of
# uk
# jo
# else jordan
# th
# else thailand
# ecuador
# if ecuador
# pakistan
# if pakistan
# iraq
# if iraq
# ca
# else canada
# ph
# else philippines
# ago
# else angola
# egypt
# if egypt
# afghanistan
# if afghanistan
# civ
# else côte d'ivoire
# israel
# if israel
# pa
# else panama
# st
# else sao tome and principe
# ms
# else montserrat
# st
# else sao tome and principe
# ms
# else montserrat
# jordan
# if jordan
# ata
# else antarctica
# israel
# if israel
# co
# else colombia
# per
# else peru
# mo
# else macao
# de
# else germany
# iraq
# if iraq
# ca
# else canada
# mexico
# if mexico
# jersey
# if jersey
# ms
# else montserrat
# guy
# else guyana
# ago
# else angola
# china
# if china
# ms
# else montserrat
# colombia
# if colombia
# israel
# if israel
# ki
# else kiribati
# turkey
# if turkey
# jm
# else jamaica
# germany
# if germany
# ms
# else montserrat
# sen
# else senegal
# kenya
# if kenya
# philippines
# if philippines
# cameroon
# if cameroon
# jm
# else jamaica
# uk
# iceland
# if iceland
# palau
# if palau
# yemen
# if yemen
# iceland
# if iceland
# cameroon
# if cameroon
# nigeria
# if nigeria
# colombia
# if colombia
# syria
# else syrian arab republic
# congo
# if congo
# gabon
# if gabon
# jamaica
# if jamaica
# zambia
# if zambia
# turkey
# if turkey
# indonesia
# if indonesia
# peru
# if peru
# af
# else afghanistan
# iraq
# if iraq
# greece
# if greece
# malaysia
# if malaysia
# lesotho
# if lesotho
# chile
# if chile
# lebanon
# if lebanon
# niger
# if niger
# bn
# else brunei darussalam
# af
# else afghanistan
# pa
# else panama
# dk
# else denmark
# af
# else afghanistan
# kenya
# if kenya
# mp
# else northern mariana islands
# st
# else sao tome and principe
# st
# else sao tome and principe
# guy
# else guyana
# im
# else isle of man
# bb
# else barbados
# jm
# else jamaica
# ms
# else montserrat
# iraq
# if iraq
# ca
# else canada
# ago
# else angola
# afghanistan
# if afghanistan
# haiti
# if haiti
# co
# else colombia
# ago
# else angola
# iraq
# if iraq
# guy
# else guyana
# israel
# if israel
# philippines
# if philippines
# guyana
# if guyana
# azerbaijan
# if azerbaijan
# turkey
# if turkey
# ca
# else canada
# armenia
# if armenia
# guy
# else guyana
# israel
# if israel
# turkey
# if turkey
# iraq
# if iraq
# afghanistan
# if afghanistan
# bn
# else brunei darussalam
# cuba
# if cuba
# afghanistan
# if afghanistan
# pakistan
# if pakistan
# india
# if india
# russia
# else russian federation
# ph
# else philippines
# ago
# else angola
# china
# if china
# afghanistan
# if afghanistan
# cuba
# if cuba
# jordan
# if jordan
# co
# else colombia
# israel
# if israel
# il
# else israel
# nl
# else netherlands
# de
# else germany
# pakistan
# if pakistan
# civ
# else côte d'ivoire
# gm
# else gambia
# bn
# else brunei darussalam
# afghanistan
# if afghanistan
# civ
# else côte d'ivoire
# de
# else germany
# rwanda
# if rwanda
# afghanistan
# if afghanistan
# de
# else germany
# ca
# else canada
# uk
# co
# else colombia
# ago
# else angola
# afghanistan
# if afghanistan
# pakistan
# if pakistan
# israel
# if israel
# iraq
# if iraq
# india
# if india
# gi
# else gibraltar
# afghanistan
# if afghanistan
# pakistan
# if pakistan
# sen
# else senegal
# afghanistan
# if afghanistan
# libya
# if libya
# kuwait
# if kuwait
# syria
# else syrian arab republic
# et
# else ethiopia
# im
# else isle of man
# lebanon
# if lebanon
# jordan
# if jordan
# egypt
# if egypt
# spain
# if spain
# israel
# if israel
# jordan
# if jordan
# israel
# if israel
# ms
# else montserrat
# pr
# else puerto rico
# jamaica
# if jamaica
# per
# else peru
# india
# if india
# jordan
# if jordan
# ca
# else canada
# malawi
# if malawi
# turkey
# if turkey
# mexico
# if mexico
# jm
# else jamaica
# mexico
# if mexico
# gm
# else gambia
# lie
# else liechtenstein
# ind
# else india
# sen
# else senegal
# pa
# else panama
# ms
# else montserrat
# usa
# else united states
# china
# if china
# azerbaijan
# if azerbaijan
# turkey
# if turkey
# haiti
# if haiti
# afghanistan
# if afghanistan
# fr
# else france
# brazil
# if brazil
# panama
# if panama
# japan
# if japan
# lie
# else liechtenstein
# iraq
# if iraq
# russia
# else russian federation
# colombia
# if colombia
# ago
# else angola
# china
# if china
# afghanistan
# if afghanistan
# brazil
# if brazil
# ukraine
# if ukraine
# fr
# else france
# israel
# if israel
# israel
# if israel
# uganda
# if uganda
# lebanon
# if lebanon
# israel
# if israel
# ago
# else angola
# arm
# else armenia
# ms
# else montserrat
# si
# else slovenia
# guy
# else guyana
# fro
# else faroe islands
# ghana
# if ghana
# mg
# else madagascar
# io
# else british indian ocean territory
# jersey
# if jersey
# jp
# else japan
# ca
# else canada
# canada
# if canada
# arm
# else armenia
# co
# else colombia
# ago
# else angola
# australia
# if australia
# israel
# if israel
# ms
# else montserrat
# er
# else eritrea
# cv
# else cabo verde
# canada
# if canada
# ad
# else andorra
# lie
# else liechtenstein
# ss
# else south sudan
# co
# else colombia
# germany
# if germany
# de
# else germany
# gin
# else guinea
# pol
# else poland
# guy
# else guyana
# ago
# else angola
# israel
# if israel
# ax
# else åland islands
# jm
# else jamaica
# pakistan
# if pakistan
# jm
# else jamaica
# pakistan
# if pakistan
# pakistan
# if pakistan
# sen
# else senegal
# ago
# else angola
# argentina
# if argentina
# jm
# else jamaica
# bb
# else barbados
# turkey
# if turkey
# im
# else isle of man
# ms
# else montserrat
# syria
# else syrian arab republic
# jordan
# if jordan
# egypt
# if egypt
# israel
# if israel
# il
# else israel
# ago
# else angola
# hun
# else hungary
# china
# if china
# ms
# else montserrat
# sen
# else senegal
# cd
# else congo, the democratic republic of the
# per
# else peru
# co
# else colombia
# ago
# else angola
# germany
# if germany
# per
# else peru
# china
# if china
# pakistan
# if pakistan
# ga
# else gabon
# ki
# else kiribati
# geo
# else georgia
# uk
# af
# else afghanistan
# arm
# else armenia
# si
# else slovenia
# pakistan
# if pakistan
# iraq
# if iraq
# india
# if india
# russia
# else russian federation
# pak
# else pakistan
# per
# else peru
# israel
# if israel
# afghanistan
# if afghanistan
# im
# else isle of man
# jersey
# if jersey
# per
# else peru
# th
# else thailand
# sj
# else svalbard and jan mayen
# ca
# else canada
# cr
# else costa rica
# ba
# else bosnia and herzegovina
# im
# else isle of man
# chile
# if chile
# pl
# else poland
# israel
# if israel
# ad
# else andorra
# haiti
# if haiti
# iraq
# if iraq
# ai
# else anguilla
# ca
# else canada
# co
# else colombia
# guy
# else guyana
# ph
# else philippines
# ago
# else angola
# china
# if china
# cri
# else costa rica
# de
# else germany
# pakistan
# if pakistan
# et
# else ethiopia
# china
# if china
# per
# else peru
# ch
# else switzerland
# id
# else indonesia
# suriname
# if suriname
# haiti
# if haiti
# mh
# else marshall islands
# de
# else germany
# yemen
# if yemen
# afghanistan
# if afghanistan
# norway
# if norway
# turkey
# if turkey
# india
# if india
# de
# else germany
# pakistan
# if pakistan
# iraq
# if iraq
# ca
# else canada
# somalia
# if somalia
# russia
# else russian federation
# jordan
# if jordan
# ago
# else angola
# egypt
# if egypt
# china
# if china
# israel
# if israel
# ms
# else montserrat
# israel
# if israel
# qa
# else qatar
# yemen
# if yemen
# oman
# if oman
# ph
# else philippines
# per
# else peru
# pl
# else poland
# ca
# else canada
# jm
# else jamaica
# usa
# else united states
# pr
# else puerto rico
# palau
# if palau
# ago
# else angola
# cd
# else congo, the democratic republic of the
# pa
# else panama
# usa
# else united states
# th
# else thailand
# per
# else peru
# il
# else israel
# co
# else colombia
# de
# else germany
# ca
# else canada
# afghanistan
# if afghanistan
# jm
# else jamaica
# colombia
# if colombia
# panama
# if panama
# indonesia
# if indonesia
# portugal
# if portugal
# china
# if china
# afghanistan
# if afghanistan
# india
# if india
# gb
# else united kingdom
# india
# if india
# jordan
# if jordan
# israel
# if israel
# lie
# else liechtenstein
# italy
# if italy
# india
# if india
# jordan
# if jordan
# ca
# else canada
# guy
# else guyana
# egypt
# if egypt
# spain
# if spain
# honduras
# if honduras
# bo
# else bolivia, plurinational state of
# israel
# if israel
# indonesia
# if indonesia
# netherlands
# if netherlands
# de
# else germany
# ms
# else montserrat
# ago
# else angola
# sen
# else senegal
# esp
# else spain
# russia
# else russian federation
# jordan
# if jordan
# ago
# else angola
# per
# else peru
# vu
# else vanuatu
# china
# if china
# israel
# if israel
# ca
# else canada
# ago
# else angola
# israel
# if israel
# ecuador
# if ecuador
# et
# else ethiopia
# belgium
# if belgium
# sweden
# if sweden
# poland
# if poland
# italy
# if italy
# ago
# else angola
# germany
# if germany
# france
# if france
# netherlands
# if netherlands
# austria
# if austria
# hungary
# if hungary
# usa
# else united states
# pakistan
# if pakistan
# israel
# if israel
# afghanistan
# if afghanistan
# ms
# else montserrat
# ms
# else montserrat
# ecuador
# if ecuador
# dk
# else denmark
# pol
# else poland
# jersey
# if jersey
# mar
# else morocco
# ms
# else montserrat
# ph
# else philippines
# ind
# else india
# pe
# else peru
# na
# else namibia
# sen
# else senegal
# somalia
# if somalia
# cyprus
# if cyprus
# egypt
# if egypt
# brazil
# if brazil
# india
# if india
# turkey
# if turkey
# russia
# else russian federation
# mexico
# if mexico
# indonesia
# if indonesia
# ms
# else montserrat
# israel
# if israel
# per
# else peru
# syria
# else syrian arab republic
# israel
# if israel
# cd
# else congo, the democratic republic of the
# israel
# if israel
# singapore
# if singapore
# id
# else indonesia
# nc
# else new caledonia
# sd
# else sudan
# ky
# else cayman islands
# sc
# else seychelles
# ca
# else canada
# co
# else colombia
# il
# else israel
# ago
# else angola
# pa
# else panama
# cr
# else costa rica
# ck
# else cook islands
# az
# else azerbaijan
# ar
# else argentina
# mo
# else macao
# israel
# if israel
# pakistan
# if pakistan
# ago
# else angola
# st
# else sao tome and principe
# ad
# else andorra
# lie
# else liechtenstein
# georgia
# if georgia
# co
# else colombia
# france
# if france
# per
# else peru
# italy
# if italy
# ca
# else canada
# monaco
# if monaco
# austria
# if austria
# ago
# else angola
# st
# else sao tome and principe
# ga
# else gabon
# sg
# else singapore
# malaysia
# if malaysia
# jm
# else jamaica
# indonesia
# if indonesia
# jm
# else jamaica
# jordan
# if jordan
# israel
# if israel
# turkey
# if turkey
# turkey
# if turkey
# mexico
# if mexico
# se
# else sweden
# ca
# else canada
# vi
# else virgin islands, u.s.
# hu
# else hungary
# china
# if china
# ms
# else montserrat
# china
# if china
# ms
# else montserrat
# ms
# else montserrat
# afghanistan
# if afghanistan
# co
# else colombia
# haiti
# if haiti
# afghanistan
# if afghanistan
# ca
# else canada
# usa
# else united states
# il
# else israel
# cd
# else congo, the democratic republic of the
# id
# else indonesia
# israel
# if israel
# er
# else eritrea
# usa
# else united states
# si
# else slovenia
# ps
# else palestine, state of
# pakistan
# if pakistan
# ms
# else montserrat
# ca
# else canada
# co
# else colombia
# il
# else israel
# mn
# else mongolia
# mexico
# if mexico
# israel
# if israel
# tt
# else trinidad and tobago
# afghanistan
# if afghanistan
# jm
# else jamaica
# ago
# else angola
# ca
# else canada
# china
# if china
# georgia
# if georgia
# russia
# else russian federation
# st
# else sao tome and principe
# co
# else colombia
# china
# if china
# ca
# else canada
# jm
# else jamaica
# st
# else sao tome and principe
# india
# if india
# cz
# else czechia
# afghanistan
# if afghanistan
# per
# else peru
# id
# else indonesia
# sh
# else saint helena, ascension and tristan da cunha
# au
# else australia
# sen
# else senegal
# ai
# else anguilla
# bb
# else barbados
# ukr
# else ukraine
# sg
# else singapore
# india
# if india
# ukraine
# if ukraine
# ukr
# else ukraine
# sg
# else singapore
# india
# if india
# ukraine
# if ukraine
# va
# else holy see (vatican city state)
# arm
# else armenia
# ly
# else libya
# ms
# else montserrat
# ro
# else romania
# ad
# else andorra
# li
# else liechtenstein
# iraq
# if iraq
# ph
# else philippines
# china
# if china
# ai
# else anguilla
# ca
# else canada
# china
# if china
# russia
# else russian federation
# ca
# else canada
# egypt
# if egypt
# st
# else sao tome and principe
# per
# else peru
# cg
# else congo
# israel
# if israel
# ca
# else canada
# israel
# if israel
# pakistan
# if pakistan
# ca
# else canada
# mexico
# if mexico
# ms
# else montserrat
# peru
# if peru
# iraq
# if iraq
# ago
# else angola
# ms
# else montserrat
# libya
# if libya
# ms
# else montserrat
# china
# if china
# finland
# if finland
# norway
# if norway
# poland
# if poland
# russia
# else russian federation
# ss
# else south sudan
# ago
# else angola
# germany
# if germany
# denmark
# if denmark
# israel
# if israel
# austria
# if austria
# per
# else peru
# id
# else indonesia
# ms
# else montserrat
# pakistan
# if pakistan
# china
# if china
# ago
# else angola
# jm
# else jamaica
# guy
# else guyana
# ca
# else canada
# france
# if france
# haiti
# if haiti
# haiti
# if haiti
# af
# else afghanistan
# pak
# else pakistan
# canada
# if canada
# th
# else thailand
# lie
# else liechtenstein
# co
# else colombia
# per
# else peru
# iraq
# if iraq
# mexico
# if mexico
# ye
# else yemen
# russia
# else russian federation
# ago
# else angola
# china
# if china
# ad
# else andorra
# ca
# else canada
# ci
# else côte d'ivoire
# ago
# else angola
# sen
# else senegal
# uk
# ireland
# if ireland
# bi
# else burundi
# uk
# ireland
# if ireland
# bi
# else burundi
# jm
# else jamaica
# usa
# else united states
# china
# if china
# ago
# else angola
# germany
# if germany
# kenya
# if kenya
# india
# if india
# ukraine
# if ukraine
# nz
# else new zealand
# lithuania
# if lithuania
# slovakia
# if slovakia
# au
# else australia
# liberia
# if liberia
# ms
# else montserrat
# jo
# else jordan
# th
# else thailand
# haiti
# if haiti
# haiti
# if haiti
# hr
# else croatia
# pl
# else poland
# md
# else moldova, republic of
# rou
# else romania
# india
# if india
# sen
# else senegal
# ken
# else kenya
# jo
# else jordan
# finland
# if finland
# france
# if france
# norway
# if norway
# afghanistan
# if afghanistan
# afghanistan
# if afghanistan
# ca
# else canada
# uk
# co
# else colombia
# france
# if france
# uruguay
# if uruguay
# poland
# if poland
# canada
# if canada
# ad
# else andorra
# lie
# else liechtenstein
# ss
# else south sudan
# co
# else colombia
# germany
# if germany
# de
# else germany
# bra
# else brazil
# ca
# else canada
# pol
# else poland
# guy
# else guyana
# ago
# else angola
# israel
# if israel
# haiti
# if haiti
# haiti
# if haiti
# sen
# else senegal
# tt
# else trinidad and tobago
# tt
# else trinidad and tobago
# ni
# else nicaragua
# ni
# else nicaragua
# egypt
# if egypt
# israel
# if israel
# bahrain
# if bahrain
# ad
# else andorra
# et
# else ethiopia
# co
# else colombia
# ki
# else kiribati
# pan
# else panama
# iraq
# if iraq
# ca
# else canada
# ci
# else côte d'ivoire
# ye
# else yemen
# jordan
# if jordan
# ago
# else angola
# egypt
# if egypt
# israel
# if israel
# cr
# else costa rica
# ca
# else canada
# usa
# else united states
# haiti
# if haiti
# haiti
# if haiti
# jm
# else jamaica
# pakistan
# if pakistan
# haiti
# if haiti
# ni
# else nicaragua
# pakistan
# if pakistan
# ca
# else canada
# poland
# if poland
# lithuania
# if lithuania
# vu
# else vanuatu
# qatar
# if qatar
# ad
# else andorra
# ms
# else montserrat
# ca
# else canada
# ago
# else angola
# ro
# else romania
# sc
# else seychelles
# iraq
# if iraq
# ca
# else canada
# cv
# else cabo verde
# sen
# else senegal
# afghanistan
# if afghanistan
# bb
# else barbados
# argentina
# if argentina
# ms
# else montserrat
# ca
# else canada
# st
# else sao tome and principe
# ago
# else angola
# russia
# else russian federation
# bn
# else brunei darussalam
# cr
# else costa rica
# syria
# else syrian arab republic
# lt
# else lithuania
# va
# else holy see (vatican city state)
# arm
# else armenia
# turkey
# if turkey
# col
# else colombia
# iraq
# if iraq
# ca
# else canada
# azerbaijan
# if azerbaijan
# israel
# if israel
# iraq
# if iraq
# iraq
# if iraq
# afghanistan
# if afghanistan
# gr
# else greece
# per
# else peru
# lt
# else lithuania
# ad
# else andorra
# haiti
# if haiti
# ca
# else canada
# au
# else australia
# ie
# else ireland
# israel
# if israel
# ad
# else andorra
# haiti
# if haiti
# ca
# else canada
# au
# else australia
# ie
# else ireland
# israel
# if israel
# guatemala
# if guatemala
# fro
# else faroe islands
# haiti
# if haiti
# haiti
# if haiti
# australia
# if australia
# uk
# malawi
# if malawi
# bahrain
# if bahrain
# greenland
# if greenland
# mexico
# if mexico
# libya
# if libya
# haiti
# if haiti
# ca
# else canada
# az
# else azerbaijan
# sen
# else senegal
# de
# else germany
# ukraine
# if ukraine
# ukraine
# if ukraine
# pakistan
# if pakistan
# india
# if india
# pak
# else pakistan
# af
# else afghanistan
# iraq
# if iraq
# israel
# if israel
# colombia
# if colombia
# ca
# else canada
# israel
# if israel
# ca
# else canada
# uk
# nauru
# if nauru
# pa
# else panama
# mexico
# if mexico
# ca
# else canada
# gm
# else gambia
# tn
# else tunisia
# ncl
# else new caledonia
# bb
# else barbados
# bi
# else burundi
# ie
# else ireland
# et
# else ethiopia
# co
# else colombia
# germany
# if germany
# france
# if france
# afghanistan
# if afghanistan
# turkey
# if turkey
# md
# else moldova, republic of
# ireland
# if ireland
# rwanda
# if rwanda
# iraq
# if iraq
# ca
# else canada
# haiti
# if haiti
# russia
# else russian federation
# kuwait
# if kuwait
# colombia
# if colombia
# liberia
# if liberia
# th
# else thailand
# cr
# else costa rica
# vi
# else virgin islands, u.s.
# sr
# else suriname
# pakistan
# if pakistan
# sen
# else senegal
# argentina
# if argentina
# singapore
# if singapore
# qatar
# if qatar
# arm
# else armenia
# pa
# else panama
# israel
# if israel
# canada
# if canada
# canada
# if canada
# israel
# if israel
# ca
# else canada
# bangladesh
# if bangladesh
# hu
# else hungary
# ca
# else canada
# ms
# else montserrat
# sudan
# if sudan
# colombia
# if colombia
# nz
# else new zealand
# denmark
# if denmark
# russia
# else russian federation
# china
# if china
# de
# else germany
# et
# else ethiopia
# guy
# else guyana
# co
# else colombia
# colombia
# if colombia
# ca
# else canada
# cm
# else cameroon
# china
# if china
# im
# else isle of man
# ca
# else canada
# sen
# else senegal
# lie
# else liechtenstein
# italy
# if italy
# yemen
# if yemen
# germany
# if germany
# china
# if china
# afghanistan
# if afghanistan
# bn
# else brunei darussalam
# russia
# else russian federation
# ago
# else angola
# sen
# else senegal
# afghanistan
# if afghanistan
# israel
# if israel
# guy
# else guyana
# gw
# else guinea-bissau
# australia
# if australia
# haiti
# if haiti
# sr
# else suriname
# iraq
# if iraq
# greenland
# if greenland
# esp
# else spain
# cy
# else cyprus
# pt
# else portugal
# est
# else estonia
# br
# else brazil
# ago
# else angola
# bangladesh
# if bangladesh
# cr
# else costa rica
# sg
# else singapore
# ukraine
# if ukraine
# russia
# else russian federation
# ms
# else montserrat
# sen
# else senegal
# russia
# else russian federation
# malaysia
# if malaysia
# jm
# else jamaica
# indonesia
# if indonesia
# sen
# else senegal
# china
# if china
# ca
# else canada
# ago
# else angola
# spain
# if spain
# afghanistan
# if afghanistan
# singapore
# if singapore
# jm
# else jamaica
# jm
# else jamaica
# russia
# else russian federation
# haiti
# if haiti
# est
# else estonia
# ni
# else nicaragua
# pak
# else pakistan
# cr
# else costa rica
# af
# else afghanistan
# ca
# else canada
# ca
# else canada
# ago
# else angola
# pe
# else peru
# arm
# else armenia
# pakistan
# if pakistan
# lb
# else lebanon
# guy
# else guyana
# ago
# else angola
# cd
# else congo, the democratic republic of the
# mexico
# if mexico

# %%
mentions_dictionary
# Out:
# defaultdict(int,
#             {'afghanistan': 130,
#              'albania': 2,
#              'algeria': 3,
#              'andorra': 22,
#              'angola': 127,
#              'anguilla': 9,
#              'antarctica': 2,
#              'antigua and barbuda': 2,
#              'argentina': 15,
#              'armenia': 19,
#              'australia': 25,
#              'austria': 5,
#              'azerbaijan': 11,
#              'bahamas': 2,
#              'bahrain': 3,
#              'bangladesh': 6,
#              'barbados': 11,
#              'belarus': 1,
#              'belgium': 6,
#              'bermuda': 5,
#              'bhutan': 2,
#              'bolivia, plurinational state of': 1,
#              'bosnia and herzegovina': 2,
#              'brazil': 31,
#              'british indian ocean territory': 2,
#              'brunei darussalam': 6,
#              'burundi': 10,
#              'cabo verde': 5,
#              'cambodia': 2,
#              'cameroon': 5,
#              'canada': 157,
#              'cayman islands': 2,
#              'central african republic': 1,
#              'chad': 3,
#              'chile': 12,
#              'china': 95,
#              'colombia': 95,
#              'comoros': 1,
#              'congo': 12,
#              'congo, the democratic republic of the': 10,
#              'cook islands': 3,
#              'costa rica': 10,
#              'croatia': 3,
#              'cuba': 20,
#              'cyprus': 6,
#              'czechia': 1,
#              "côte d'ivoire": 10,
#              'denmark': 6,
#              'dominican republic': 1,
#              'ecuador': 9,
#              'egypt': 36,
#              'eritrea': 6,
#              'estonia': 12,
#              'ethiopia': 27,
#              'faroe islands': 7,
#              'finland': 4,
#              'france': 32,
#              'french guiana': 1,
#              'french polynesia': 1,
#              'french southern territories': 2,
#              'gabon': 7,
#              'gambia': 4,
#              'georgia': 11,
#              'germany': 57,
#              'ghana': 3,
#              'gibraltar': 4,
#              'greece': 9,
#              'greenland': 2,
#              'guam': 1,
#              'guatemala': 6,
#              'guinea': 6,
#              'guinea-bissau': 1,
#              'guyana': 29,
#              'haiti': 84,
#              'holy see (vatican city state)': 11,
#              'honduras': 27,
#              'hong kong': 1,
#              'hungary': 8,
#              'iceland': 5,
#              'india': 59,
#              'indonesia': 37,
#              'iran, islamic republic of': 1,
#              'iraq': 71,
#              'ireland': 39,
#              'isle of man': 13,
#              'israel': 97,
#              'italy': 12,
#              'jamaica': 37,
#              'japan': 25,
#              'jersey': 10,
#              'jordan': 24,
#              'kazakhstan': 3,
#              'kenya': 17,
#              'kiribati': 5,
#              'korea, republic of': 2,
#              'kuwait': 7,
#              'kyrgyzstan': 2,
#              'latvia': 1,
#              'lebanon': 7,
#              'lesotho': 1,
#              'liberia': 6,
#              'libya': 60,
#              'liechtenstein': 18,
#              'lithuania': 19,
#              'luxembourg': 4,
#              'macao': 8,
#              'madagascar': 3,
#              'malawi': 2,
#              'malaysia': 4,
#              'maldives': 2,
#              'malta': 2,
#              'marshall islands': 1,
#              'mauritius': 2,
#              'mexico': 39,
#              'moldova, republic of': 5,
#              'monaco': 5,
#              'mongolia': 4,
#              'montserrat': 55,
#              'morocco': 21,
#              'mozambique': 1,
#              'myanmar': 7,
#              'namibia': 8,
#              'nauru': 5,
#              'nepal': 1,
#              'netherlands': 8,
#              'new caledonia': 4,
#              'new zealand': 4,
#              'nicaragua': 15,
#              'niger': 4,
#              'nigeria': 10,
#              'northern mariana islands': 9,
#              'norway': 12,
#              'oman': 3,
#              'pakistan': 96,
#              'palau': 13,
#              'palestine, state of': 5,
#              'panama': 36,
#              'papua new guinea': 3,
#              'paraguay': 2,
#              'peru': 72,
#              'philippines': 21,
#              'poland': 22,
#              'portugal': 9,
#              'puerto rico': 15,
#              'qatar': 15,
#              'romania': 7,
#              'russian federation': 55,
#              'rwanda': 5,
#              'saint barthélemy': 1,
#              'saint helena, ascension and tristan da cunha': 1,
#              'saint lucia': 1,
#              'samoa': 2,
#              'san marino': 1,
#              'sao tome and principe': 37,
#              'saudi arabia': 2,
#              'senegal': 38,
#              'serbia': 6,
#              'seychelles': 5,
#              'sierra leone': 4,
#              'singapore': 18,
#              'slovakia': 2,
#              'slovenia': 6,
#              'somalia': 8,
#              'south georgia and the south sandwich islands': 1,
#              'south sudan': 6,
#              'spain': 20,
#              'sudan': 15,
#              'suriname': 7,
#              'svalbard and jan mayen': 1,
#              'swaziland': 2,
#              'sweden': 16,
#              'switzerland': 7,
#              'syrian arab republic': 18,
#              'tajikistan': 1,
#              'thailand': 13,
#              'timor-leste': 1,
#              'tonga': 2,
#              'trinidad and tobago': 4,
#              'tunisia': 11,
#              'turkey': 36,
#              'turkmenistan': 2,
#              'tuvalu': 2,
#              'uganda': 6,
#              'ukraine': 11,
#              'united kingdom': 6,
#              'united states': 21,
#              'uruguay': 8,
#              'uzbekistan': 3,
#              'vanuatu': 2,
#              'virgin islands, u.s.': 7,
#              'yemen': 15,
#              'zambia': 3,
#              'zimbabwe': 1,
#              'åland islands': 3})

# %%
# Keep countries with mentions greater than 50
dict_big_mentions = {}
for c in list(mentions_dictionary.keys()):
    if mentions_dictionary[c] > 30:
        dict_big_mentions[c] = mentions_dictionary[c]

# %%
dict_big_mentions
# Out:
# {'afghanistan': 130,
#  'angola': 127,
#  'brazil': 31,
#  'canada': 157,
#  'china': 95,
#  'colombia': 95,
#  'egypt': 36,
#  'france': 32,
#  'germany': 57,
#  'haiti': 84,
#  'india': 59,
#  'indonesia': 37,
#  'iraq': 71,
#  'ireland': 39,
#  'israel': 97,
#  'jamaica': 37,
#  'libya': 60,
#  'mexico': 39,
#  'montserrat': 55,
#  'pakistan': 96,
#  'panama': 36,
#  'peru': 72,
#  'russian federation': 55,
#  'sao tome and principe': 37,
#  'senegal': 38,
#  'turkey': 36}

# %%
import operator

# %%
sorted_dict = sorted(dict_big_mentions.items(), key=operator.itemgetter(1))

# %%
sorted_dict
# Out:
# [('morocco', 64),
#  ('palau', 64),
#  ('colombia', 74),
#  ('india', 81),
#  ('canada', 81),
#  ('ireland', 82),
#  ('peru', 85),
#  ('iraq', 89),
#  ('angola', 93),
#  ('israel', 104),
#  ('pakistan', 132),
#  ('libya', 172),
#  ('haiti', 173),
#  ('afghanistan', 177),
#  ('china', 281)]

# %%
import seaborn as sns

# %%
sorted_dict[0]
# Out:
# ('morocco', 64)

# %%
plt.bar(range(len(dict_big_mentions)), list(dict_big_mentions.values()))
plt.xticks(range(len(dict_big_mentions)), list(dict_big_mentions.keys()))
plt.xticks(rotation=45, ha='right')
plt.show()

# %%
for text in emails['ExtractedBodyText']:
    analyzer = SentimentIntensityAnalyzer()
    c = analyzer.polarity_scores(text)
    print (c)
# Out:
# {'neu': 0.476, 'compound': -0.296, 'pos': 0.0, 'neg': 0.524}
# {'neu': 1.0, 'compound': 0.0, 'pos': 0.0, 'neg': 0.0}
# {'neu': 0.0, 'compound': 0.3612, 'pos': 1.0, 'neg': 0.0}
# {'neu': 0.476, 'compound': -0.296, 'pos': 0.0, 'neg': 0.524}
# {'neu': 1.0, 'compound': 0.0, 'pos': 0.0, 'neg': 0.0}
# {'neu': 0.821, 'compound': -0.8402, 'pos': 0.039, 'neg': 0.14}
# {'neu': 0.476, 'compound': -0.296, 'pos': 0.0, 'neg': 0.524}
# {'neu': 1.0, 'compound': 0.0, 'pos': 0.0, 'neg': 0.0}
# {'neu': 0.0, 'compound': 0.2023, 'pos': 1.0, 'neg': 0.0}
# {'neu': 1.0, 'compound': 0.0, 'pos': 0.0, 'neg': 0.0}
# {'neu': 0.357, 'compound': 0.2023, 'pos': 0.643, 'neg': 0.0}
# {'neu': 1.0, 'compound': 0.0, 'pos': 0.0, 'neg': 0.0}
# {'neu': 0.0, 'compound': 0.2023, 'pos': 1.0, 'neg': 0.0}
# {'neu': 0.8, 'compound': 0.9881, 'pos': 0.111, 'neg': 0.089}
# {'neu': 0.786, 'compound': 0.9259, 'pos': 0.188, 'neg': 0.026}
# {'neu': 0.795, 'compound': 0.8869, 'pos': 0.137, 'neg': 0.069}
# {'neu': 0.633, 'compound': 0.4404, 'pos': 0.367, 'neg': 0.0}
# {'neu': 1.0, 'compound': 0.0, 'pos': 0.0, 'neg': 0.0}
# {'neu': 0.417, 'compound': 0.4215, 'pos': 0.583, 'neg': 0.0}
# {'neu': 0.748, 'compound': -0.2103, 'pos': 0.114, 'neg': 0.139}
# {'neu': 1.0, 'compound': 0.0, 'pos': 0.0, 'neg': 0.0}
# {'neu': 1.0, 'compound': 0.0, 'pos': 0.0, 'neg': 0.0}
# {'neu': 1.0, 'compound': 0.0, 'pos': 0.0, 'neg': 0.0}
# {'neu': 1.0, 'compound': 0.0, 'pos': 0.0, 'neg': 0.0}
# {'neu': 1.0, 'compound': 0.0, 'pos': 0.0, 'neg': 0.0}
# {'neu': 1.0, 'compound': 0.0, 'pos': 0.0, 'neg': 0.0}
# {'neu': 1.0, 'compound': 0.0, 'pos': 0.0, 'neg': 0.0}
# {'neu': 1.0, 'compound': 0.0, 'pos': 0.0, 'neg': 0.0}
# {'neu': 0.739, 'compound': -0.996, 'pos': 0.109, 'neg': 0.152}
# {'neu': 1.0, 'compound': 0.0, 'pos': 0.0, 'neg': 0.0}
# {'neu': 0.0, 'compound': 0.2023, 'pos': 1.0, 'neg': 0.0}
# {'neu': 1.0, 'compound': 0.0, 'pos': 0.0, 'neg': 0.0}
# {'neu': 0.814, 'compound': -0.9936, 'pos': 0.063, 'neg': 0.122}
# {'neu': 0.917, 'compound': 0.368, 'pos': 0.083, 'neg': 0.0}
# {'neu': 0.0, 'compound': 0.2023, 'pos': 1.0, 'neg': 0.0}
# {'neu': 0.476, 'compound': -0.296, 'pos': 0.0, 'neg': 0.524}
# {'neu': 0.87, 'compound': 0.7865, 'pos': 0.068, 'neg': 0.061}
# {'neu': 0.476, 'compound': -0.296, 'pos': 0.0, 'neg': 0.524}
# {'neu': 0.34, 'compound': 0.7096, 'pos': 0.531, 'neg': 0.129}
# {'neu': 0.706, 'compound': -0.34, 'pos': 0.103, 'neg': 0.192}
# {'neu': 0.357, 'compound': 0.2023, 'pos': 0.643, 'neg': 0.0}
# {'neu': 0.32, 'compound': 0.8588, 'pos': 0.68, 'neg': 0.0}
# {'neu': 1.0, 'compound': 0.0, 'pos': 0.0, 'neg': 0.0}
# {'neu': 1.0, 'compound': 0.0, 'pos': 0.0, 'neg': 0.0}
# {'neu': 0.0, 'compound': 0.2023, 'pos': 1.0, 'neg': 0.0}
# {'neu': 0.805, 'compound': -0.1779, 'pos': 0.074, 'neg': 0.121}
# {'neu': 0.794, 'compound': -0.9958, 'pos': 0.081, 'neg': 0.125}
# {'neu': 0.783, 'compound': 0.3612, 'pos': 0.217, 'neg': 0.0}
# {'neu': 1.0, 'compound': 0.0, 'pos': 0.0, 'neg': 0.0}
# {'neu': 0.683, 'compound': 0.7879, 'pos': 0.317, 'neg': 0.0}
# {'neu': 1.0, 'compound': 0.0, 'pos': 0.0, 'neg': 0.0}
# {'neu': 0.657, 'compound': -0.1346, 'pos': 0.156, 'neg': 0.188}
# {'neu': 0.853, 'compound': -0.434, 'pos': 0.065, 'neg': 0.082}
# {'neu': 1.0, 'compound': 0.0, 'pos': 0.0, 'neg': 0.0}
# {'neu': 0.735, 'compound': 0.6486, 'pos': 0.151, 'neg': 0.114}
# {'neu': 0.88, 'compound': -0.434, 'pos': 0.053, 'neg': 0.067}
# {'neu': 0.476, 'compound': -0.296, 'pos': 0.0, 'neg': 0.524}
# {'neu': 0.678, 'compound': 0.9967, 'pos': 0.189, 'neg': 0.133}
# {'neu': 0.83, 'compound': 0.694, 'pos': 0.17, 'neg': 0.0}
# {'neu': 0.476, 'compound': -0.296, 'pos': 0.0, 'neg': 0.524}
# {'neu': 0.783, 'compound': -0.9593, 'pos': 0.063, 'neg': 0.154}
# {'neu': 1.0, 'compound': 0.0, 'pos': 0.0, 'neg': 0.0}
# {'neu': 0.476, 'compound': -0.296, 'pos': 0.0, 'neg': 0.524}
# {'neu': 0.476, 'compound': -0.296, 'pos': 0.0, 'neg': 0.524}
# {'neu': 0.834, 'compound': 0.2432, 'pos': 0.08, 'neg': 0.086}
# {'neu': 1.0, 'compound': 0.0, 'pos': 0.0, 'neg': 0.0}
# {'neu': 1.0, 'compound': 0.0, 'pos': 0.0, 'neg': 0.0}
# {'neu': 1.0, 'compound': 0.0, 'pos': 0.0, 'neg': 0.0}
# {'neu': 0.0, 'compound': 0.2023, 'pos': 1.0, 'neg': 0.0}
# {'neu': 1.0, 'compound': 0.0, 'pos': 0.0, 'neg': 0.0}
# {'neu': 1.0, 'compound': 0.0, 'pos': 0.0, 'neg': 0.0}
# {'neu': 0.945, 'compound': -0.0772, 'pos': 0.03, 'neg': 0.025}
# {'neu': 0.776, 'compound': -0.198, 'pos': 0.107, 'neg': 0.117}
# {'neu': 0.323, 'compound': 0.4939, 'pos': 0.677, 'neg': 0.0}
# {'neu': 1.0, 'compound': 0.0, 'pos': 0.0, 'neg': 0.0}
# {'neu': 0.859, 'compound': 0.9502, 'pos': 0.112, 'neg': 0.029}
# {'neu': 0.884, 'compound': 0.3612, 'pos': 0.116, 'neg': 0.0}
# {'neu': 0.772, 'compound': 0.4588, 'pos': 0.151, 'neg': 0.077}
# {'neu': 0.408, 'compound': 0.4404, 'pos': 0.592, 'neg': 0.0}
# {'neu': 0.0, 'compound': 0.0, 'pos': 0.0, 'neg': 0.0}
# {'neu': 0.845, 'compound': -0.25, 'pos': 0.042, 'neg': 0.113}
# {'neu': 0.797, 'compound': 0.4939, 'pos': 0.111, 'neg': 0.093}
# {'neu': 1.0, 'compound': 0.0, 'pos': 0.0, 'neg': 0.0}
# {'neu': 0.476, 'compound': -0.296, 'pos': 0.0, 'neg': 0.524}
# {'neu': 0.476, 'compound': -0.296, 'pos': 0.0, 'neg': 0.524}
# {'neu': 0.805, 'compound': 0.1027, 'pos': 0.103, 'neg': 0.092}
# {'neu': 0.657, 'compound': -0.9965, 'pos': 0.129, 'neg': 0.214}
# {'neu': 0.802, 'compound': -0.3939, 'pos': 0.082, 'neg': 0.116}
# {'neu': 0.85, 'compound': -0.1511, 'pos': 0.0, 'neg': 0.15}
# {'neu': 0.834, 'compound': 0.6767, 'pos': 0.166, 'neg': 0.0}
# {'neu': 1.0, 'compound': 0.0, 'pos': 0.0, 'neg': 0.0}
# {'neu': 0.837, 'compound': 0.1901, 'pos': 0.163, 'neg': 0.0}
# {'neu': 0.809, 'compound': 0.4696, 'pos': 0.191, 'neg': 0.0}
# {'neu': 0.856, 'compound': 0.4019, 'pos': 0.144, 'neg': 0.0}
# {'neu': 0.476, 'compound': -0.296, 'pos': 0.0, 'neg': 0.524}
# {'neu': 0.476, 'compound': -0.296, 'pos': 0.0, 'neg': 0.524}
# {'neu': 0.874, 'compound': 0.4939, 'pos': 0.126, 'neg': 0.0}
# {'neu': 0.811, 'compound': 0.9808, 'pos': 0.172, 'neg': 0.016}
# {'neu': 0.893, 'compound': 0.34, 'pos': 0.107, 'neg': 0.0}
# {'neu': 1.0, 'compound': 0.0, 'pos': 0.0, 'neg': 0.0}
# {'neu': 0.713, 'compound': -0.34, 'pos': 0.1, 'neg': 0.187}
# {'neu': 1.0, 'compound': 0.0, 'pos': 0.0, 'neg': 0.0}
# {'neu': 1.0, 'compound': 0.0, 'pos': 0.0, 'neg': 0.0}
# {'neu': 0.561, 'compound': 0.5719, 'pos': 0.439, 'neg': 0.0}
# {'neu': 1.0, 'compound': 0.0, 'pos': 0.0, 'neg': 0.0}
# {'neu': 0.833, 'compound': 0.296, 'pos': 0.167, 'neg': 0.0}
# {'neu': 1.0, 'compound': 0.0, 'pos': 0.0, 'neg': 0.0}
# {'neu': 0.863, 'compound': -0.9488, 'pos': 0.035, 'neg': 0.103}
# {'neu': 1.0, 'compound': 0.0, 'pos': 0.0, 'neg': 0.0}
# {'neu': 0.72, 'compound': -0.3612, 'pos': 0.0, 'neg': 0.28}
# {'neu': 0.721, 'compound': -0.4767, 'pos': 0.0, 'neg': 0.279}
# {'neu': 0.312, 'compound': 0.296, 'pos': 0.688, 'neg': 0.0}
# {'neu': 1.0, 'compound': 0.0, 'pos': 0.0, 'neg': 0.0}
# {'neu': 1.0, 'compound': 0.0, 'pos': 0.0, 'neg': 0.0}
# {'neu': 0.933, 'compound': 0.0772, 'pos': 0.067, 'neg': 0.0}
# {'neu': 1.0, 'compound': 0.0, 'pos': 0.0, 'neg': 0.0}
# {'neu': 0.476, 'compound': -0.296, 'pos': 0.0, 'neg': 0.524}
# {'neu': 1.0, 'compound': 0.0, 'pos': 0.0, 'neg': 0.0}
# {'neu': 1.0, 'compound': 0.0, 'pos': 0.0, 'neg': 0.0}
# {'neu': 0.0, 'compound': 0.2023, 'pos': 1.0, 'neg': 0.0}
# {'neu': 1.0, 'compound': 0.0, 'pos': 0.0, 'neg': 0.0}
# {'neu': 0.941, 'compound': 0.4215, 'pos': 0.059, 'neg': 0.0}
# {'neu': 0.636, 'compound': 0.8988, 'pos': 0.231, 'neg': 0.133}
# {'neu': 1.0, 'compound': 0.0, 'pos': 0.0, 'neg': 0.0}
# {'neu': 0.823, 'compound': -0.3336, 'pos': 0.071, 'neg': 0.106}
# {'neu': 0.476, 'compound': -0.296, 'pos': 0.0, 'neg': 0.524}
# {'neu': 0.789, 'compound': 0.5322, 'pos': 0.108, 'neg': 0.103}
# {'neu': 1.0, 'compound': 0.0, 'pos': 0.0, 'neg': 0.0}
# {'neu': 1.0, 'compound': 0.0, 'pos': 0.0, 'neg': 0.0}
# {'neu': 1.0, 'compound': 0.0, 'pos': 0.0, 'neg': 0.0}
# {'neu': 0.792, 'compound': -0.5859, 'pos': 0.072, 'neg': 0.135}
# {'neu': 0.564, 'compound': 0.4754, 'pos': 0.436, 'neg': 0.0}
# {'neu': 1.0, 'compound': 0.0, 'pos': 0.0, 'neg': 0.0}
# {'neu': 1.0, 'compound': 0.0, 'pos': 0.0, 'neg': 0.0}
# {'neu': 0.0, 'compound': 0.4404, 'pos': 1.0, 'neg': 0.0}
# {'neu': 1.0, 'compound': 0.0, 'pos': 0.0, 'neg': 0.0}
# {'neu': 1.0, 'compound': 0.0, 'pos': 0.0, 'neg': 0.0}
# {'neu': 0.476, 'compound': -0.296, 'pos': 0.0, 'neg': 0.524}
# {'neu': 0.0, 'compound': 0.4019, 'pos': 1.0, 'neg': 0.0}
# {'neu': 1.0, 'compound': 0.0, 'pos': 0.0, 'neg': 0.0}
# {'neu': 0.785, 'compound': -0.8316, 'pos': 0.057, 'neg': 0.157}
# {'neu': 0.675, 'compound': -0.9382, 'pos': 0.0, 'neg': 0.325}
# {'neu': 0.891, 'compound': 0.4215, 'pos': 0.109, 'neg': 0.0}
# {'neu': 0.848, 'compound': -0.5574, 'pos': 0.038, 'neg': 0.114}
# {'neu': 1.0, 'compound': 0.0, 'pos': 0.0, 'neg': 0.0}
# {'neu': 0.476, 'compound': -0.296, 'pos': 0.0, 'neg': 0.524}
# {'neu': 0.761, 'compound': 0.5902, 'pos': 0.121, 'neg': 0.117}
# {'neu': 0.851, 'compound': -0.0516, 'pos': 0.082, 'neg': 0.068}
# {'neu': 1.0, 'compound': 0.0, 'pos': 0.0, 'neg': 0.0}
# {'neu': 0.476, 'compound': -0.296, 'pos': 0.0, 'neg': 0.524}
# {'neu': 0.476, 'compound': -0.296, 'pos': 0.0, 'neg': 0.524}
# {'neu': 0.734, 'compound': 0.0124, 'pos': 0.135, 'neg': 0.131}
# {'neu': 0.792, 'compound': 0.9923, 'pos': 0.154, 'neg': 0.054}
# {'neu': 1.0, 'compound': 0.0, 'pos': 0.0, 'neg': 0.0}
# {'neu': 1.0, 'compound': 0.0, 'pos': 0.0, 'neg': 0.0}
# {'neu': 0.476, 'compound': -0.296, 'pos': 0.0, 'neg': 0.524}
# {'neu': 0.357, 'compound': 0.2023, 'pos': 0.643, 'neg': 0.0}
# {'neu': 1.0, 'compound': 0.0, 'pos': 0.0, 'neg': 0.0}
# {'neu': 0.792, 'compound': 0.6369, 'pos': 0.208, 'neg': 0.0}
# {'neu': 1.0, 'compound': 0.0, 'pos': 0.0, 'neg': 0.0}
# {'neu': 0.848, 'compound': -0.5574, 'pos': 0.038, 'neg': 0.114}
# {'neu': 1.0, 'compound': 0.0, 'pos': 0.0, 'neg': 0.0}
# {'neu': 0.915, 'compound': -0.8567, 'pos': 0.027, 'neg': 0.058}
# {'neu': 1.0, 'compound': 0.0, 'pos': 0.0, 'neg': 0.0}
# {'neu': 1.0, 'compound': 0.0, 'pos': 0.0, 'neg': 0.0}
# {'neu': 0.476, 'compound': -0.296, 'pos': 0.0, 'neg': 0.524}
# {'neu': 0.476, 'compound': -0.296, 'pos': 0.0, 'neg': 0.524}
# {'neu': 1.0, 'compound': 0.0, 'pos': 0.0, 'neg': 0.0}
# {'neu': 0.756, 'compound': -0.34, 'pos': 0.085, 'neg': 0.158}
# {'neu': 0.863, 'compound': 0.9184, 'pos': 0.089, 'neg': 0.048}
# {'neu': 0.476, 'compound': -0.296, 'pos': 0.0, 'neg': 0.524}
# {'neu': 0.797, 'compound': -0.5574, 'pos': 0.059, 'neg': 0.143}
# {'neu': 0.476, 'compound': -0.296, 'pos': 0.0, 'neg': 0.524}
# {'neu': 1.0, 'compound': 0.0, 'pos': 0.0, 'neg': 0.0}
# {'neu': 0.746, 'compound': -0.9996, 'pos': 0.074, 'neg': 0.18}
# {'neu': 0.653, 'compound': -0.9978, 'pos': 0.127, 'neg': 0.22}
# {'neu': 1.0, 'compound': 0.0, 'pos': 0.0, 'neg': 0.0}
# {'neu': 1.0, 'compound': 0.0, 'pos': 0.0, 'neg': 0.0}
# {'neu': 0.769, 'compound': 0.2023, 'pos': 0.231, 'neg': 0.0}
# {'neu': 1.0, 'compound': 0.0, 'pos': 0.0, 'neg': 0.0}
# {'neu': 0.476, 'compound': -0.296, 'pos': 0.0, 'neg': 0.524}
# {'neu': 1.0, 'compound': 0.0, 'pos': 0.0, 'neg': 0.0}
# {'neu': 0.801, 'compound': 0.9612, 'pos': 0.131, 'neg': 0.068}
# {'neu': 0.435, 'compound': 0.0772, 'pos': 0.565, 'neg': 0.0}
# {'neu': 1.0, 'compound': 0.0, 'pos': 0.0, 'neg': 0.0}
# {'neu': 1.0, 'compound': 0.0, 'pos': 0.0, 'neg': 0.0}
# {'neu': 1.0, 'compound': 0.0, 'pos': 0.0, 'neg': 0.0}
# {'neu': 0.838, 'compound': 0.5319, 'pos': 0.162, 'neg': 0.0}
# {'neu': 0.476, 'compound': -0.296, 'pos': 0.0, 'neg': 0.524}
# {'neu': 1.0, 'compound': 0.0, 'pos': 0.0, 'neg': 0.0}
# {'neu': 0.84, 'compound': 0.6908, 'pos': 0.16, 'neg': 0.0}
# {'neu': 0.0, 'compound': 0.2023, 'pos': 1.0, 'neg': 0.0}
# {'neu': 0.606, 'compound': 0.0772, 'pos': 0.394, 'neg': 0.0}
# {'neu': 0.885, 'compound': -0.3818, 'pos': 0.0, 'neg': 0.115}
# {'neu': 0.791, 'compound': 0.4404, 'pos': 0.209, 'neg': 0.0}
# {'neu': 0.805, 'compound': 0.4404, 'pos': 0.195, 'neg': 0.0}
# {'neu': 0.885, 'compound': 0.3818, 'pos': 0.115, 'neg': 0.0}
# {'neu': 1.0, 'compound': 0.0, 'pos': 0.0, 'neg': 0.0}
# {'neu': 0.709, 'compound': -0.2732, 'pos': 0.102, 'neg': 0.189}
# {'neu': 0.476, 'compound': -0.296, 'pos': 0.0, 'neg': 0.524}
# {'neu': 0.678, 'compound': 0.6476, 'pos': 0.234, 'neg': 0.088}
# {'neu': 1.0, 'compound': 0.0, 'pos': 0.0, 'neg': 0.0}
# {'neu': 1.0, 'compound': 0.0, 'pos': 0.0, 'neg': 0.0}
# {'neu': 0.476, 'compound': -0.296, 'pos': 0.0, 'neg': 0.524}
# {'neu': 0.667, 'compound': 0.6114, 'pos': 0.333, 'neg': 0.0}
# {'neu': 1.0, 'compound': 0.0, 'pos': 0.0, 'neg': 0.0}
# {'neu': 0.772, 'compound': -0.9894, 'pos': 0.101, 'neg': 0.126}
# {'neu': 1.0, 'compound': 0.0, 'pos': 0.0, 'neg': 0.0}
# {'neu': 0.476, 'compound': -0.296, 'pos': 0.0, 'neg': 0.524}
# {'neu': 1.0, 'compound': 0.0, 'pos': 0.0, 'neg': 0.0}
# {'neu': 0.0, 'compound': 0.2023, 'pos': 1.0, 'neg': 0.0}
# {'neu': 0.836, 'compound': 0.2502, 'pos': 0.085, 'neg': 0.079}
# {'neu': 0.677, 'compound': 0.694, 'pos': 0.323, 'neg': 0.0}
# {'neu': 0.729, 'compound': -0.9961, 'pos': 0.078, 'neg': 0.192}
# {'neu': 0.7, 'compound': 1.0, 'pos': 0.191, 'neg': 0.109}
# {'neu': 0.435, 'compound': 0.0772, 'pos': 0.565, 'neg': 0.0}
# {'neu': 0.901, 'compound': -0.2716, 'pos': 0.045, 'neg': 0.054}
# {'neu': 0.0, 'compound': 0.2023, 'pos': 1.0, 'neg': 0.0}
# {'neu': 0.476, 'compound': -0.296, 'pos': 0.0, 'neg': 0.524}
# {'neu': 0.727, 'compound': -0.34, 'pos': 0.095, 'neg': 0.178}
# {'neu': 0.599, 'compound': -0.7096, 'pos': 0.088, 'neg': 0.313}
# {'neu': 0.196, 'compound': 0.6249, 'pos': 0.804, 'neg': 0.0}
# {'neu': 0.737, 'compound': -0.5904, 'pos': 0.074, 'neg': 0.19}
# {'neu': 0.84, 'compound': -0.34, 'pos': 0.056, 'neg': 0.104}
# {'neu': 0.727, 'compound': -0.34, 'pos': 0.095, 'neg': 0.178}
# {'neu': 0.847, 'compound': 0.5719, 'pos': 0.153, 'neg': 0.0}
# {'neu': 0.408, 'compound': 0.4404, 'pos': 0.592, 'neg': 0.0}
# {'neu': 1.0, 'compound': 0.0, 'pos': 0.0, 'neg': 0.0}
# {'neu': 1.0, 'compound': 0.0, 'pos': 0.0, 'neg': 0.0}
# {'neu': 0.919, 'compound': -0.4404, 'pos': 0.0, 'neg': 0.081}
# {'neu': 0.882, 'compound': 0.6808, 'pos': 0.062, 'neg': 0.056}
# {'neu': 0.0, 'compound': 0.2023, 'pos': 1.0, 'neg': 0.0}
# {'neu': 1.0, 'compound': 0.0, 'pos': 0.0, 'neg': 0.0}
# {'neu': 0.435, 'compound': 0.0772, 'pos': 0.565, 'neg': 0.0}
# {'neu': 0.886, 'compound': 0.7964, 'pos': 0.063, 'neg': 0.051}
# {'neu': 0.918, 'compound': 0.5904, 'pos': 0.046, 'neg': 0.036}
# {'neu': 0.74, 'compound': -0.34, 'pos': 0.091, 'neg': 0.169}
# {'neu': 0.283, 'compound': 0.368, 'pos': 0.717, 'neg': 0.0}
# {'neu': 0.476, 'compound': -0.296, 'pos': 0.0, 'neg': 0.524}
# {'neu': 0.847, 'compound': -0.9891, 'pos': 0.055, 'neg': 0.098}
# {'neu': 1.0, 'compound': 0.0, 'pos': 0.0, 'neg': 0.0}
# {'neu': 0.588, 'compound': 0.1027, 'pos': 0.412, 'neg': 0.0}
# {'neu': 0.476, 'compound': -0.296, 'pos': 0.0, 'neg': 0.524}
# {'neu': 0.754, 'compound': -0.9986, 'pos': 0.08, 'neg': 0.166}
# {'neu': 0.654, 'compound': 0.9651, 'pos': 0.25, 'neg': 0.095}
# {'neu': 0.715, 'compound': 0.6801, 'pos': 0.285, 'neg': 0.0}
# {'neu': 0.461, 'compound': 0.9565, 'pos': 0.539, 'neg': 0.0}
# {'neu': 0.786, 'compound': 0.4753, 'pos': 0.214, 'neg': 0.0}
# {'neu': 0.588, 'compound': 0.8986, 'pos': 0.412, 'neg': 0.0}
# {'neu': 0.858, 'compound': -0.3156, 'pos': 0.062, 'neg': 0.08}
# {'neu': 0.872, 'compound': 0.3612, 'pos': 0.128, 'neg': 0.0}
# {'neu': 1.0, 'compound': 0.0, 'pos': 0.0, 'neg': 0.0}
# {'neu': 1.0, 'compound': 0.0, 'pos': 0.0, 'neg': 0.0}
# {'neu': 0.0, 'compound': 0.2023, 'pos': 1.0, 'neg': 0.0}
# {'neu': 0.0, 'compound': 0.2023, 'pos': 1.0, 'neg': 0.0}
# {'neu': 0.884, 'compound': 0.4404, 'pos': 0.116, 'neg': 0.0}
# {'neu': 0.846, 'compound': 0.775, 'pos': 0.154, 'neg': 0.0}
# {'neu': 1.0, 'compound': 0.0, 'pos': 0.0, 'neg': 0.0}
# {'neu': 1.0, 'compound': 0.0, 'pos': 0.0, 'neg': 0.0}
# {'neu': 0.9, 'compound': -0.5106, 'pos': 0.022, 'neg': 0.078}
# {'neu': 0.476, 'compound': -0.296, 'pos': 0.0, 'neg': 0.524}
# {'neu': 1.0, 'compound': 0.0, 'pos': 0.0, 'neg': 0.0}
# {'neu': 0.606, 'compound': 0.0772, 'pos': 0.394, 'neg': 0.0}
# {'neu': 0.932, 'compound': -0.296, 'pos': 0.0, 'neg': 0.068}
# {'neu': 0.7, 'compound': -0.2382, 'pos': 0.16, 'neg': 0.14}
# {'neu': 0.0, 'compound': 0.2023, 'pos': 1.0, 'neg': 0.0}
# {'neu': 1.0, 'compound': 0.0, 'pos': 0.0, 'neg': 0.0}
# {'neu': 0.848, 'compound': 0.9882, 'pos': 0.099, 'neg': 0.053}
# {'neu': 0.283, 'compound': 0.368, 'pos': 0.717, 'neg': 0.0}
# {'neu': 0.801, 'compound': 0.981, 'pos': 0.107, 'neg': 0.092}
# {'neu': 0.837, 'compound': 0.368, 'pos': 0.163, 'neg': 0.0}
# {'neu': 1.0, 'compound': 0.0, 'pos': 0.0, 'neg': 0.0}
# {'neu': 0.83, 'compound': -0.928, 'pos': 0.078, 'neg': 0.092}
# {'neu': 1.0, 'compound': 0.0, 'pos': 0.0, 'neg': 0.0}
# {'neu': 0.0, 'compound': 0.2023, 'pos': 1.0, 'neg': 0.0}
# {'neu': 0.733, 'compound': -0.34, 'pos': 0.093, 'neg': 0.173}
# {'neu': 1.0, 'compound': 0.0, 'pos': 0.0, 'neg': 0.0}
# {'neu': 0.25, 'compound': 0.4576, 'pos': 0.75, 'neg': 0.0}
# {'neu': 0.282, 'compound': 0.0772, 'pos': 0.38, 'neg': 0.338}
# {'neu': 1.0, 'compound': 0.0, 'pos': 0.0, 'neg': 0.0}
# {'neu': 0.435, 'compound': 0.0772, 'pos': 0.565, 'neg': 0.0}
# {'neu': 0.563, 'compound': 0.7351, 'pos': 0.437, 'neg': 0.0}
# {'neu': 0.842, 'compound': -0.34, 'pos': 0.055, 'neg': 0.103}
# {'neu': 0.764, 'compound': 0.34, 'pos': 0.156, 'neg': 0.08}
# {'neu': 0.735, 'compound': -0.743, 'pos': 0.069, 'neg': 0.196}
# {'neu': 1.0, 'compound': 0.0, 'pos': 0.0, 'neg': 0.0}
# {'neu': 0.0, 'compound': 0.296, 'pos': 1.0, 'neg': 0.0}
# {'neu': 0.805, 'compound': 0.1613, 'pos': 0.114, 'neg': 0.081}
# {'neu': 0.476, 'compound': -0.296, 'pos': 0.0, 'neg': 0.524}
# {'neu': 1.0, 'compound': 0.0, 'pos': 0.0, 'neg': 0.0}
# {'neu': 0.706, 'compound': -0.34, 'pos': 0.103, 'neg': 0.192}
# {'neu': 0.666, 'compound': -0.8318, 'pos': 0.1, 'neg': 0.234}
# {'neu': 0.744, 'compound': 0.1091, 'pos': 0.131, 'neg': 0.125}
# {'neu': 0.854, 'compound': 0.34, 'pos': 0.146, 'neg': 0.0}
# {'neu': 0.723, 'compound': -0.4757, 'pos': 0.114, 'neg': 0.163}
# {'neu': 0.747, 'compound': 0.5719, 'pos': 0.135, 'neg': 0.118}
# {'neu': 0.615, 'compound': 0.3612, 'pos': 0.385, 'neg': 0.0}
# {'neu': 0.256, 'compound': 0.4404, 'pos': 0.744, 'neg': 0.0}
# {'neu': 0.476, 'compound': -0.296, 'pos': 0.0, 'neg': 0.524}
# {'neu': 0.86, 'compound': 0.0772, 'pos': 0.14, 'neg': 0.0}
# {'neu': 0.762, 'compound': 0.3612, 'pos': 0.238, 'neg': 0.0}
# {'neu': 1.0, 'compound': 0.0, 'pos': 0.0, 'neg': 0.0}
# {'neu': 0.545, 'compound': 0.3612, 'pos': 0.455, 'neg': 0.0}
# {'neu': 1.0, 'compound': 0.0, 'pos': 0.0, 'neg': 0.0}
# {'neu': 1.0, 'compound': 0.0, 'pos': 0.0, 'neg': 0.0}
# {'neu': 0.872, 'compound': 0.3612, 'pos': 0.128, 'neg': 0.0}
# {'neu': 0.843, 'compound': 0.0772, 'pos': 0.157, 'neg': 0.0}
# {'neu': 0.476, 'compound': 0.296, 'pos': 0.524, 'neg': 0.0}
# {'neu': 0.59, 'compound': 0.4184, 'pos': 0.41, 'neg': 0.0}
# {'neu': 0.682, 'compound': 0.4199, 'pos': 0.318, 'neg': 0.0}
# {'neu': 0.93, 'compound': 0.3612, 'pos': 0.07, 'neg': 0.0}
# {'neu': 1.0, 'compound': 0.0, 'pos': 0.0, 'neg': 0.0}
# {'neu': 1.0, 'compound': 0.0, 'pos': 0.0, 'neg': 0.0}
# {'neu': 0.476, 'compound': -0.296, 'pos': 0.0, 'neg': 0.524}
# {'neu': 1.0, 'compound': 0.0, 'pos': 0.0, 'neg': 0.0}
# {'neu': 1.0, 'compound': 0.0, 'pos': 0.0, 'neg': 0.0}
# {'neu': 0.853, 'compound': 0.4215, 'pos': 0.147, 'neg': 0.0}
# {'neu': 0.704, 'compound': 0.8126, 'pos': 0.296, 'neg': 0.0}
# {'neu': 0.66, 'compound': 0.3818, 'pos': 0.34, 'neg': 0.0}
# {'neu': 1.0, 'compound': 0.0, 'pos': 0.0, 'neg': 0.0}
# {'neu': 1.0, 'compound': 0.0, 'pos': 0.0, 'neg': 0.0}
# {'neu': 0.476, 'compound': -0.296, 'pos': 0.0, 'neg': 0.524}
# {'neu': 0.27, 'compound': 0.4019, 'pos': 0.73, 'neg': 0.0}
# {'neu': 0.825, 'compound': 0.4902, 'pos': 0.175, 'neg': 0.0}
# {'neu': 1.0, 'compound': 0.0, 'pos': 0.0, 'neg': 0.0}
# {'neu': 0.185, 'compound': 0.6588, 'pos': 0.815, 'neg': 0.0}
# {'neu': 1.0, 'compound': 0.0, 'pos': 0.0, 'neg': 0.0}
# {'neu': 0.84, 'compound': 0.4215, 'pos': 0.16, 'neg': 0.0}
# {'neu': 0.912, 'compound': 0.3612, 'pos': 0.088, 'neg': 0.0}
# {'neu': 0.739, 'compound': 0.8248, 'pos': 0.23, 'neg': 0.031}
# {'neu': 0.812, 'compound': 0.5267, 'pos': 0.188, 'neg': 0.0}
# {'neu': 0.579, 'compound': -0.9118, 'pos': 0.139, 'neg': 0.281}
# {'neu': 1.0, 'compound': 0.0, 'pos': 0.0, 'neg': 0.0}
# {'neu': 1.0, 'compound': 0.0, 'pos': 0.0, 'neg': 0.0}
# {'neu': 0.799, 'compound': 0.4137, 'pos': 0.201, 'neg': 0.0}
# {'neu': 0.896, 'compound': 0.296, 'pos': 0.104, 'neg': 0.0}
# {'neu': 0.392, 'compound': -0.4767, 'pos': 0.0, 'neg': 0.608}
# {'neu': 0.828, 'compound': 0.1779, 'pos': 0.091, 'neg': 0.081}
# {'neu': 0.476, 'compound': -0.296, 'pos': 0.0, 'neg': 0.524}
# {'neu': 1.0, 'compound': 0.0, 'pos': 0.0, 'neg': 0.0}
# {'neu': 1.0, 'compound': 0.0, 'pos': 0.0, 'neg': 0.0}
# {'neu': 1.0, 'compound': 0.0, 'pos': 0.0, 'neg': 0.0}
# {'neu': 0.0, 'compound': 0.296, 'pos': 1.0, 'neg': 0.0}
# {'neu': 0.72, 'compound': 0.7184, 'pos': 0.28, 'neg': 0.0}
# {'neu': 0.827, 'compound': 0.8555, 'pos': 0.122, 'neg': 0.051}
# {'neu': 0.476, 'compound': -0.296, 'pos': 0.0, 'neg': 0.524}
# {'neu': 1.0, 'compound': 0.0, 'pos': 0.0, 'neg': 0.0}
# {'neu': 1.0, 'compound': 0.0, 'pos': 0.0, 'neg': 0.0}
# {'neu': 1.0, 'compound': 0.0, 'pos': 0.0, 'neg': 0.0}
# {'neu': 1.0, 'compound': 0.0, 'pos': 0.0, 'neg': 0.0}
# {'neu': 0.649, 'compound': 0.6705, 'pos': 0.351, 'neg': 0.0}
# {'neu': 0.82, 'compound': -0.296, 'pos': 0.0, 'neg': 0.18}
# {'neu': 1.0, 'compound': 0.0, 'pos': 0.0, 'neg': 0.0}
# {'neu': 1.0, 'compound': 0.0, 'pos': 0.0, 'neg': 0.0}
# {'neu': 1.0, 'compound': 0.0, 'pos': 0.0, 'neg': 0.0}
# {'neu': 0.87, 'compound': -0.0516, 'pos': 0.0, 'neg': 0.13}
# {'neu': 1.0, 'compound': 0.0, 'pos': 0.0, 'neg': 0.0}
# {'neu': 1.0, 'compound': 0.0, 'pos': 0.0, 'neg': 0.0}
# {'neu': 0.0, 'compound': 0.296, 'pos': 1.0, 'neg': 0.0}
# {'neu': 0.495, 'compound': -0.0772, 'pos': 0.287, 'neg': 0.218}
# {'neu': 0.71, 'compound': 0.4329, 'pos': 0.29, 'neg': 0.0}
# {'neu': 0.476, 'compound': -0.296, 'pos': 0.0, 'neg': 0.524}
# {'neu': 0.476, 'compound': -0.296, 'pos': 0.0, 'neg': 0.524}
# {'neu': 0.476, 'compound': -0.296, 'pos': 0.0, 'neg': 0.524}
# {'neu': 0.476, 'compound': -0.296, 'pos': 0.0, 'neg': 0.524}
# {'neu': 1.0, 'compound': 0.0, 'pos': 0.0, 'neg': 0.0}
# {'neu': 0.435, 'compound': 0.0772, 'pos': 0.565, 'neg': 0.0}
# {'neu': 0.476, 'compound': -0.296, 'pos': 0.0, 'neg': 0.524}
# {'neu': 1.0, 'compound': 0.0, 'pos': 0.0, 'neg': 0.0}
# {'neu': 0.733, 'compound': -0.128, 'pos': 0.12, 'neg': 0.147}
# {'neu': 0.8, 'compound': 0.3612, 'pos': 0.2, 'neg': 0.0}
# {'neu': 1.0, 'compound': 0.0, 'pos': 0.0, 'neg': 0.0}
# {'neu': 0.885, 'compound': 0.5023, 'pos': 0.115, 'neg': 0.0}
# {'neu': 0.441, 'compound': 0.4215, 'pos': 0.559, 'neg': 0.0}
# {'neu': 0.615, 'compound': 0.3612, 'pos': 0.385, 'neg': 0.0}
# {'neu': 0.86, 'compound': 0.0772, 'pos': 0.14, 'neg': 0.0}
# {'neu': 0.726, 'compound': 0.1027, 'pos': 0.169, 'neg': 0.105}
# {'neu': 1.0, 'compound': 0.0, 'pos': 0.0, 'neg': 0.0}
# {'neu': 1.0, 'compound': 0.0, 'pos': 0.0, 'neg': 0.0}
# {'neu': 0.837, 'compound': 0.0444, 'pos': 0.096, 'neg': 0.067}
# {'neu': 1.0, 'compound': 0.0, 'pos': 0.0, 'neg': 0.0}
# {'neu': 1.0, 'compound': 0.0, 'pos': 0.0, 'neg': 0.0}
# {'neu': 0.835, 'compound': 0.3736, 'pos': 0.165, 'neg': 0.0}
# {'neu': 0.915, 'compound': -0.0772, 'pos': 0.0, 'neg': 0.085}
# {'neu': 0.714, 'compound': -0.3818, 'pos': 0.0, 'neg': 0.286}
# {'neu': 1.0, 'compound': 0.0, 'pos': 0.0, 'neg': 0.0}
# {'neu': 0.577, 'compound': 0.296, 'pos': 0.423, 'neg': 0.0}
# {'neu': 0.345, 'compound': 0.2263, 'pos': 0.655, 'neg': 0.0}
# {'neu': 1.0, 'compound': 0.0, 'pos': 0.0, 'neg': 0.0}
# {'neu': 0.794, 'compound': 0.0772, 'pos': 0.206, 'neg': 0.0}
# {'neu': 0.915, 'compound': 0.0772, 'pos': 0.085, 'neg': 0.0}
# {'neu': 0.921, 'compound': -0.2263, 'pos': 0.0, 'neg': 0.079}
# {'neu': 0.818, 'compound': 0.4817, 'pos': 0.142, 'neg': 0.04}
# {'neu': 1.0, 'compound': 0.0, 'pos': 0.0, 'neg': 0.0}
# {'neu': 0.0, 'compound': 0.3595, 'pos': 1.0, 'neg': 0.0}
# {'neu': 0.435, 'compound': 0.0772, 'pos': 0.565, 'neg': 0.0}
# {'neu': 0.476, 'compound': -0.296, 'pos': 0.0, 'neg': 0.524}
# {'neu': 0.635, 'compound': 0.3182, 'pos': 0.365, 'neg': 0.0}
# {'neu': 0.256, 'compound': 0.4404, 'pos': 0.744, 'neg': 0.0}
# {'neu': 0.966, 'compound': 0.0772, 'pos': 0.034, 'neg': 0.0}
# {'neu': 0.767, 'compound': 0.9481, 'pos': 0.215, 'neg': 0.019}
# {'neu': 1.0, 'compound': 0.0, 'pos': 0.0, 'neg': 0.0}
# {'neu': 1.0, 'compound': 0.0, 'pos': 0.0, 'neg': 0.0}
# {'neu': 1.0, 'compound': 0.0, 'pos': 0.0, 'neg': 0.0}
# {'neu': 1.0, 'compound': 0.0, 'pos': 0.0, 'neg': 0.0}
# {'neu': 0.815, 'compound': 0.3612, 'pos': 0.185, 'neg': 0.0}
# {'neu': 0.785, 'compound': 0.6486, 'pos': 0.215, 'neg': 0.0}
# {'neu': 1.0, 'compound': 0.0, 'pos': 0.0, 'neg': 0.0}
# {'neu': 0.533, 'compound': -0.5423, 'pos': 0.0, 'neg': 0.467}
# {'neu': 0.808, 'compound': 0.6753, 'pos': 0.138, 'neg': 0.055}
# {'neu': 0.772, 'compound': 0.807, 'pos': 0.228, 'neg': 0.0}
# {'neu': 1.0, 'compound': 0.0, 'pos': 0.0, 'neg': 0.0}
# {'neu': 0.0, 'compound': 0.296, 'pos': 1.0, 'neg': 0.0}
# {'neu': 0.75, 'compound': -0.395, 'pos': 0.0, 'neg': 0.25}
# {'neu': 1.0, 'compound': 0.0, 'pos': 0.0, 'neg': 0.0}
# {'neu': 1.0, 'compound': 0.0, 'pos': 0.0, 'neg': 0.0}
# {'neu': 1.0, 'compound': 0.0, 'pos': 0.0, 'neg': 0.0}
# {'neu': 0.669, 'compound': 0.872, 'pos': 0.331, 'neg': 0.0}
# {'neu': 1.0, 'compound': 0.0, 'pos': 0.0, 'neg': 0.0}
# {'neu': 0.775, 'compound': 0.4939, 'pos': 0.225, 'neg': 0.0}
# {'neu': 0.812, 'compound': 0.8957, 'pos': 0.188, 'neg': 0.0}
# {'neu': 0.752, 'compound': -0.0531, 'pos': 0.118, 'neg': 0.129}
# {'neu': 0.755, 'compound': 0.0772, 'pos': 0.245, 'neg': 0.0}
# {'neu': 0.476, 'compound': -0.296, 'pos': 0.0, 'neg': 0.524}
# {'neu': 0.476, 'compound': -0.296, 'pos': 0.0, 'neg': 0.524}
# {'neu': 1.0, 'compound': 0.0, 'pos': 0.0, 'neg': 0.0}
# {'neu': 1.0, 'compound': 0.0, 'pos': 0.0, 'neg': 0.0}
# {'neu': 1.0, 'compound': 0.0, 'pos': 0.0, 'neg': 0.0}
# {'neu': 1.0, 'compound': 0.0, 'pos': 0.0, 'neg': 0.0}
# {'neu': 0.435, 'compound': 0.0772, 'pos': 0.565, 'neg': 0.0}
# {'neu': 0.476, 'compound': -0.296, 'pos': 0.0, 'neg': 0.524}
# {'neu': 1.0, 'compound': 0.0, 'pos': 0.0, 'neg': 0.0}
# {'neu': 0.822, 'compound': 0.0772, 'pos': 0.178, 'neg': 0.0}
# {'neu': 1.0, 'compound': 0.0, 'pos': 0.0, 'neg': 0.0}
# {'neu': 1.0, 'compound': 0.0, 'pos': 0.0, 'neg': 0.0}
# {'neu': 0.476, 'compound': -0.296, 'pos': 0.0, 'neg': 0.524}
# {'neu': 0.865, 'compound': 0.3612, 'pos': 0.135, 'neg': 0.0}
# {'neu': 0.69, 'compound': 0.6597, 'pos': 0.31, 'neg': 0.0}
# {'neu': 0.0, 'compound': 0.4926, 'pos': 1.0, 'neg': 0.0}
# {'neu': 1.0, 'compound': 0.0, 'pos': 0.0, 'neg': 0.0}
# {'neu': 0.945, 'compound': 0.1531, 'pos': 0.055, 'neg': 0.0}
# {'neu': 0.781, 'compound': 0.9316, 'pos': 0.205, 'neg': 0.014}
# {'neu': 0.927, 'compound': 0.5023, 'pos': 0.073, 'neg': 0.0}
# {'neu': 0.857, 'compound': 0.3612, 'pos': 0.143, 'neg': 0.0}
# {'neu': 0.929, 'compound': 0.0772, 'pos': 0.071, 'neg': 0.0}
# {'neu': 0.806, 'compound': 0.6705, 'pos': 0.194, 'neg': 0.0}
# {'neu': 0.939, 'compound': 0.0258, 'pos': 0.061, 'neg': 0.0}
# {'neu': 1.0, 'compound': 0.0, 'pos': 0.0, 'neg': 0.0}
# {'neu': 0.86, 'compound': 0.4144, 'pos': 0.14, 'neg': 0.0}
# {'neu': 0.765, 'compound': 0.5574, 'pos': 0.235, 'neg': 0.0}
# {'neu': 0.909, 'compound': -0.296, 'pos': 0.0, 'neg': 0.091}
# {'neu': 0.821, 'compound': 0.4019, 'pos': 0.179, 'neg': 0.0}
# {'neu': 0.741, 'compound': 0.5994, 'pos': 0.259, 'neg': 0.0}
# {'neu': 0.0, 'compound': 0.296, 'pos': 1.0, 'neg': 0.0}
# {'neu': 0.863, 'compound': 0.1901, 'pos': 0.137, 'neg': 0.0}
# {'neu': 0.894, 'compound': 0.0772, 'pos': 0.106, 'neg': 0.0}
# {'neu': 0.685, 'compound': 0.3182, 'pos': 0.315, 'neg': 0.0}
# {'neu': 0.51, 'compound': 0.5859, 'pos': 0.49, 'neg': 0.0}
# {'neu': 0.859, 'compound': 0.0382, 'pos': 0.141, 'neg': 0.0}
# {'neu': 0.771, 'compound': 0.7635, 'pos': 0.194, 'neg': 0.035}
# {'neu': 1.0, 'compound': 0.0, 'pos': 0.0, 'neg': 0.0}
# {'neu': 0.705, 'compound': 0.9426, 'pos': 0.295, 'neg': 0.0}
# {'neu': 1.0, 'compound': 0.0, 'pos': 0.0, 'neg': 0.0}
# {'neu': 0.805, 'compound': 0.4404, 'pos': 0.195, 'neg': 0.0}
# {'neu': 0.854, 'compound': 0.3736, 'pos': 0.146, 'neg': 0.0}
# {'neu': 0.66, 'compound': 0.3818, 'pos': 0.34, 'neg': 0.0}
# {'neu': 0.749, 'compound': 0.6486, 'pos': 0.187, 'neg': 0.063}
# {'neu': 1.0, 'compound': 0.0, 'pos': 0.0, 'neg': 0.0}
# {'neu': 1.0, 'compound': 0.0, 'pos': 0.0, 'neg': 0.0}
# {'neu': 1.0, 'compound': 0.0, 'pos': 0.0, 'neg': 0.0}
# {'neu': 0.963, 'compound': 0.0772, 'pos': 0.037, 'neg': 0.0}
# {'neu': 0.357, 'compound': 0.3818, 'pos': 0.643, 'neg': 0.0}
# {'neu': 0.0, 'compound': 0.2023, 'pos': 1.0, 'neg': 0.0}
# {'neu': 0.66, 'compound': 0.4588, 'pos': 0.241, 'neg': 0.099}
# {'neu': 0.695, 'compound': 0.9215, 'pos': 0.305, 'neg': 0.0}
# {'neu': 0.828, 'compound': 0.3612, 'pos': 0.172, 'neg': 0.0}
# {'neu': 0.0, 'compound': 0.296, 'pos': 1.0, 'neg': 0.0}
# {'neu': 0.843, 'compound': 0.0772, 'pos': 0.157, 'neg': 0.0}
# {'neu': 0.909, 'compound': 0.0772, 'pos': 0.091, 'neg': 0.0}
# {'neu': 0.476, 'compound': -0.296, 'pos': 0.0, 'neg': 0.524}
# {'neu': 0.783, 'compound': 0.3612, 'pos': 0.217, 'neg': 0.0}
# {'neu': 0.769, 'compound': 0.5106, 'pos': 0.231, 'neg': 0.0}
# {'neu': 0.911, 'compound': -0.4098, 'pos': 0.0, 'neg': 0.089}
# {'neu': 0.803, 'compound': 0.4019, 'pos': 0.197, 'neg': 0.0}
# {'neu': 0.476, 'compound': -0.296, 'pos': 0.0, 'neg': 0.524}
# {'neu': 1.0, 'compound': 0.0, 'pos': 0.0, 'neg': 0.0}
# {'neu': 0.0, 'compound': 0.4019, 'pos': 1.0, 'neg': 0.0}
# {'neu': 1.0, 'compound': 0.0, 'pos': 0.0, 'neg': 0.0}
# {'neu': 0.551, 'compound': 0.6908, 'pos': 0.449, 'neg': 0.0}
# {'neu': 0.912, 'compound': 0.6705, 'pos': 0.088, 'neg': 0.0}
# {'neu': 0.543, 'compound': 0.0772, 'pos': 0.24, 'neg': 0.217}
# {'neu': 1.0, 'compound': 0.0, 'pos': 0.0, 'neg': 0.0}
# {'neu': 0.805, 'compound': 0.6249, 'pos': 0.195, 'neg': 0.0}
# {'neu': 0.0, 'compound': 0.296, 'pos': 1.0, 'neg': 0.0}
# {'neu': 1.0, 'compound': 0.0, 'pos': 0.0, 'neg': 0.0}
# {'neu': 1.0, 'compound': 0.0, 'pos': 0.0, 'neg': 0.0}
# {'neu': 0.791, 'compound': 0.5423, 'pos': 0.209, 'neg': 0.0}
# {'neu': 1.0, 'compound': 0.0, 'pos': 0.0, 'neg': 0.0}
# {'neu': 0.843, 'compound': 0.0772, 'pos': 0.157, 'neg': 0.0}
# {'neu': 0.914, 'compound': 0.6124, 'pos': 0.086, 'neg': 0.0}
# {'neu': 1.0, 'compound': 0.0, 'pos': 0.0, 'neg': 0.0}
# {'neu': 0.813, 'compound': -0.264, 'pos': 0.083, 'neg': 0.103}
# {'neu': 0.0, 'compound': 0.296, 'pos': 1.0, 'neg': 0.0}
# {'neu': 1.0, 'compound': 0.0, 'pos': 0.0, 'neg': 0.0}
# {'neu': 1.0, 'compound': 0.0, 'pos': 0.0, 'neg': 0.0}
# {'neu': 0.476, 'compound': -0.296, 'pos': 0.0, 'neg': 0.524}
# {'neu': 0.901, 'compound': 0.0258, 'pos': 0.099, 'neg': 0.0}
# {'neu': 0.794, 'compound': 0.8632, 'pos': 0.206, 'neg': 0.0}
# {'neu': 0.674, 'compound': 0.4404, 'pos': 0.326, 'neg': 0.0}
# {'neu': 0.813, 'compound': 0.3182, 'pos': 0.187, 'neg': 0.0}
# {'neu': 0.739, 'compound': 0.964, 'pos': 0.242, 'neg': 0.019}
# {'neu': 1.0, 'compound': 0.0, 'pos': 0.0, 'neg': 0.0}
# {'neu': 0.915, 'compound': 0.0772, 'pos': 0.085, 'neg': 0.0}
# {'neu': 0.819, 'compound': 0.5487, 'pos': 0.181, 'neg': 0.0}
# {'neu': 1.0, 'compound': 0.0, 'pos': 0.0, 'neg': 0.0}
# {'neu': 0.625, 'compound': 0.2023, 'pos': 0.375, 'neg': 0.0}
# {'neu': 0.79, 'compound': 0.3786, 'pos': 0.147, 'neg': 0.063}
# {'neu': 1.0, 'compound': 0.0, 'pos': 0.0, 'neg': 0.0}
# {'neu': 0.784, 'compound': 0.296, 'pos': 0.216, 'neg': 0.0}
# {'neu': 0.795, 'compound': 0.3818, 'pos': 0.205, 'neg': 0.0}
# {'neu': 1.0, 'compound': 0.0, 'pos': 0.0, 'neg': 0.0}
# {'neu': 0.615, 'compound': 0.3612, 'pos': 0.385, 'neg': 0.0}
# {'neu': 0.526, 'compound': 0.2023, 'pos': 0.474, 'neg': 0.0}
# {'neu': 0.0, 'compound': 0.296, 'pos': 1.0, 'neg': 0.0}
# {'neu': 0.476, 'compound': -0.296, 'pos': 0.0, 'neg': 0.524}
# {'neu': 1.0, 'compound': 0.0, 'pos': 0.0, 'neg': 0.0}
# {'neu': 0.476, 'compound': -0.296, 'pos': 0.0, 'neg': 0.524}
# {'neu': 0.0, 'compound': 0.3612, 'pos': 1.0, 'neg': 0.0}
# {'neu': 0.657, 'compound': 0.953, 'pos': 0.317, 'neg': 0.026}
# {'neu': 0.555, 'compound': 0.9551, 'pos': 0.417, 'neg': 0.029}
# {'neu': 1.0, 'compound': 0.0, 'pos': 0.0, 'neg': 0.0}
# {'neu': 1.0, 'compound': 0.0, 'pos': 0.0, 'neg': 0.0}
# {'neu': 0.655, 'compound': 0.7845, 'pos': 0.345, 'neg': 0.0}
# {'neu': 0.0, 'compound': 0.296, 'pos': 1.0, 'neg': 0.0}
# {'neu': 0.792, 'compound': 0.2263, 'pos': 0.135, 'neg': 0.073}
# {'neu': 0.0, 'compound': 0.296, 'pos': 1.0, 'neg': 0.0}
# {'neu': 0.65, 'compound': -0.431, 'pos': 0.098, 'neg': 0.252}
# {'neu': 0.583, 'compound': 0.5106, 'pos': 0.417, 'neg': 0.0}
# {'neu': 1.0, 'compound': 0.0, 'pos': 0.0, 'neg': 0.0}
# {'neu': 1.0, 'compound': 0.0, 'pos': 0.0, 'neg': 0.0}
# {'neu': 0.444, 'compound': 0.3612, 'pos': 0.556, 'neg': 0.0}
# {'neu': 1.0, 'compound': 0.0, 'pos': 0.0, 'neg': 0.0}
# {'neu': 0.732, 'compound': 0.296, 'pos': 0.268, 'neg': 0.0}
# {'neu': 1.0, 'compound': 0.0, 'pos': 0.0, 'neg': 0.0}
# {'neu': 0.878, 'compound': 0.3612, 'pos': 0.122, 'neg': 0.0}
# {'neu': 0.476, 'compound': -0.296, 'pos': 0.0, 'neg': 0.524}
# {'neu': 1.0, 'compound': 0.0, 'pos': 0.0, 'neg': 0.0}
# {'neu': 0.568, 'compound': 0.6767, 'pos': 0.432, 'neg': 0.0}
# {'neu': 0.922, 'compound': 0.4019, 'pos': 0.078, 'neg': 0.0}
# {'neu': 0.872, 'compound': 0.296, 'pos': 0.128, 'neg': 0.0}
# {'neu': 1.0, 'compound': 0.0, 'pos': 0.0, 'neg': 0.0}
# {'neu': 0.903, 'compound': -0.7755, 'pos': 0.0, 'neg': 0.097}
# {'neu': 0.476, 'compound': -0.296, 'pos': 0.0, 'neg': 0.524}
# {'neu': 0.0, 'compound': 0.3612, 'pos': 1.0, 'neg': 0.0}
# {'neu': 0.956, 'compound': -0.1474, 'pos': 0.0, 'neg': 0.044}
# {'neu': 1.0, 'compound': 0.0, 'pos': 0.0, 'neg': 0.0}
# {'neu': 0.476, 'compound': 0.296, 'pos': 0.524, 'neg': 0.0}
# {'neu': 0.898, 'compound': 0.3612, 'pos': 0.102, 'neg': 0.0}
# {'neu': 1.0, 'compound': 0.0, 'pos': 0.0, 'neg': 0.0}
# {'neu': 0.476, 'compound': -0.296, 'pos': 0.0, 'neg': 0.524}
# {'neu': 0.476, 'compound': -0.296, 'pos': 0.0, 'neg': 0.524}
# {'neu': 1.0, 'compound': 0.0, 'pos': 0.0, 'neg': 0.0}
# {'neu': 1.0, 'compound': 0.0, 'pos': 0.0, 'neg': 0.0}
# {'neu': 0.847, 'compound': 0.2023, 'pos': 0.153, 'neg': 0.0}
# {'neu': 0.933, 'compound': 0.0772, 'pos': 0.067, 'neg': 0.0}
# {'neu': 0.724, 'compound': 0.8126, 'pos': 0.276, 'neg': 0.0}
# {'neu': 0.739, 'compound': 0.5574, 'pos': 0.261, 'neg': 0.0}
# {'neu': 0.785, 'compound': 0.6786, 'pos': 0.215, 'neg': 0.0}
# {'neu': 0.698, 'compound': 0.0772, 'pos': 0.302, 'neg': 0.0}
# {'neu': 1.0, 'compound': 0.0, 'pos': 0.0, 'neg': 0.0}
# {'neu': 1.0, 'compound': 0.0, 'pos': 0.0, 'neg': 0.0}
# {'neu': 0.786, 'compound': 0.7845, 'pos': 0.214, 'neg': 0.0}
# {'neu': 1.0, 'compound': 0.0, 'pos': 0.0, 'neg': 0.0}
# {'neu': 1.0, 'compound': 0.0, 'pos': 0.0, 'neg': 0.0}
# {'neu': 0.0, 'compound': 0.296, 'pos': 1.0, 'neg': 0.0}
# {'neu': 0.86, 'compound': 0.0772, 'pos': 0.14, 'neg': 0.0}
# {'neu': 0.476, 'compound': -0.296, 'pos': 0.0, 'neg': 0.524}
# {'neu': 1.0, 'compound': 0.0, 'pos': 0.0, 'neg': 0.0}
# {'neu': 0.802, 'compound': 0.3612, 'pos': 0.143, 'neg': 0.055}
# {'neu': 1.0, 'compound': 0.0, 'pos': 0.0, 'neg': 0.0}
# {'neu': 1.0, 'compound': 0.0, 'pos': 0.0, 'neg': 0.0}
# {'neu': 0.769, 'compound': -0.4019, 'pos': 0.0, 'neg': 0.231}
# {'neu': 1.0, 'compound': 0.0, 'pos': 0.0, 'neg': 0.0}
# {'neu': 0.685, 'compound': 0.4144, 'pos': 0.315, 'neg': 0.0}
# {'neu': 0.772, 'compound': -0.2244, 'pos': 0.097, 'neg': 0.131}
# {'neu': 0.783, 'compound': 0.6124, 'pos': 0.217, 'neg': 0.0}
# {'neu': 0.366, 'compound': 0.6369, 'pos': 0.634, 'neg': 0.0}
# {'neu': 0.871, 'compound': -0.3313, 'pos': 0.0, 'neg': 0.129}
# {'neu': 1.0, 'compound': 0.0, 'pos': 0.0, 'neg': 0.0}
# {'neu': 0.68, 'compound': 0.8957, 'pos': 0.32, 'neg': 0.0}
# {'neu': 1.0, 'compound': 0.0, 'pos': 0.0, 'neg': 0.0}
# {'neu': 0.864, 'compound': 0.6705, 'pos': 0.136, 'neg': 0.0}
# {'neu': 0.856, 'compound': 0.7227, 'pos': 0.144, 'neg': 0.0}
# {'neu': 1.0, 'compound': 0.0, 'pos': 0.0, 'neg': 0.0}
# {'neu': 0.839, 'compound': 0.3612, 'pos': 0.161, 'neg': 0.0}
# {'neu': 0.872, 'compound': 0.296, 'pos': 0.128, 'neg': 0.0}
# {'neu': 0.694, 'compound': 0.296, 'pos': 0.306, 'neg': 0.0}
# {'neu': 0.0, 'compound': 0.296, 'pos': 1.0, 'neg': 0.0}
# {'neu': 1.0, 'compound': 0.0, 'pos': 0.0, 'neg': 0.0}
# {'neu': 1.0, 'compound': 0.0, 'pos': 0.0, 'neg': 0.0}
# {'neu': 1.0, 'compound': 0.0, 'pos': 0.0, 'neg': 0.0}
# {'neu': 0.796, 'compound': 0.3736, 'pos': 0.204, 'neg': 0.0}
# {'neu': 1.0, 'compound': 0.0, 'pos': 0.0, 'neg': 0.0}
# {'neu': 0.0, 'compound': 0.2023, 'pos': 1.0, 'neg': 0.0}
# {'neu': 0.0, 'compound': 0.5719, 'pos': 1.0, 'neg': 0.0}
# {'neu': 0.902, 'compound': 0.0772, 'pos': 0.098, 'neg': 0.0}
# {'neu': 0.0, 'compound': 0.3612, 'pos': 1.0, 'neg': 0.0}
# {'neu': 0.879, 'compound': -0.782, 'pos': 0.027, 'neg': 0.094}
# {'neu': 0.833, 'compound': 0.34, 'pos': 0.167, 'neg': 0.0}
# {'neu': 0.902, 'compound': 0.3612, 'pos': 0.098, 'neg': 0.0}
# {'neu': 1.0, 'compound': 0.0, 'pos': 0.0, 'neg': 0.0}
# {'neu': 0.634, 'compound': 0.6981, 'pos': 0.366, 'neg': 0.0}
# {'neu': 0.743, 'compound': 0.6369, 'pos': 0.257, 'neg': 0.0}
# {'neu': 0.698, 'compound': 0.6369, 'pos': 0.302, 'neg': 0.0}
# {'neu': 0.536, 'compound': 0.6369, 'pos': 0.464, 'neg': 0.0}
# {'neu': 0.644, 'compound': 0.8555, 'pos': 0.356, 'neg': 0.0}
# {'neu': 0.435, 'compound': 0.6369, 'pos': 0.565, 'neg': 0.0}
# {'neu': 0.828, 'compound': 0.3612, 'pos': 0.172, 'neg': 0.0}
# {'neu': 1.0, 'compound': 0.0, 'pos': 0.0, 'neg': 0.0}
# {'neu': 0.715, 'compound': -0.1511, 'pos': 0.0, 'neg': 0.285}
# {'neu': 1.0, 'compound': 0.0, 'pos': 0.0, 'neg': 0.0}
# {'neu': 0.836, 'compound': 0.5106, 'pos': 0.164, 'neg': 0.0}
# {'neu': 1.0, 'compound': 0.0, 'pos': 0.0, 'neg': 0.0}
# {'neu': 0.478, 'compound': 0.8516, 'pos': 0.426, 'neg': 0.096}
# {'neu': 0.614, 'compound': 0.9337, 'pos': 0.386, 'neg': 0.0}
# {'neu': 1.0, 'compound': 0.0, 'pos': 0.0, 'neg': 0.0}
# {'neu': 1.0, 'compound': 0.0, 'pos': 0.0, 'neg': 0.0}
# {'neu': 0.732, 'compound': 0.296, 'pos': 0.268, 'neg': 0.0}
# {'neu': 0.164, 'compound': 0.1779, 'pos': 0.475, 'neg': 0.361}
# {'neu': 1.0, 'compound': 0.0, 'pos': 0.0, 'neg': 0.0}
# {'neu': 0.715, 'compound': -0.1511, 'pos': 0.0, 'neg': 0.285}
# {'neu': 1.0, 'compound': 0.0, 'pos': 0.0, 'neg': 0.0}
# {'neu': 0.598, 'compound': 0.296, 'pos': 0.288, 'neg': 0.114}
# {'neu': 0.476, 'compound': -0.296, 'pos': 0.0, 'neg': 0.524}
# {'neu': 1.0, 'compound': 0.0, 'pos': 0.0, 'neg': 0.0}
# {'neu': 0.614, 'compound': 0.9337, 'pos': 0.386, 'neg': 0.0}
# {'neu': 1.0, 'compound': 0.0, 'pos': 0.0, 'neg': 0.0}
# {'neu': 1.0, 'compound': 0.0, 'pos': 0.0, 'neg': 0.0}
# {'neu': 0.732, 'compound': 0.296, 'pos': 0.268, 'neg': 0.0}
# {'neu': 0.164, 'compound': 0.1779, 'pos': 0.475, 'neg': 0.361}
# {'neu': 0.761, 'compound': -0.296, 'pos': 0.0, 'neg': 0.239}
# {'neu': 1.0, 'compound': 0.0, 'pos': 0.0, 'neg': 0.0}
# {'neu': 0.0, 'compound': 0.296, 'pos': 1.0, 'neg': 0.0}
# {'neu': 0.0, 'compound': 0.296, 'pos': 1.0, 'neg': 0.0}
# {'neu': 1.0, 'compound': 0.0, 'pos': 0.0, 'neg': 0.0}
# {'neu': 0.0, 'compound': 0.296, 'pos': 1.0, 'neg': 0.0}
# {'neu': 0.913, 'compound': 0.3182, 'pos': 0.087, 'neg': 0.0}
# {'neu': 0.853, 'compound': -0.2263, 'pos': 0.0, 'neg': 0.147}
# {'neu': 1.0, 'compound': 0.0, 'pos': 0.0, 'neg': 0.0}
# {'neu': 0.865, 'compound': 0.3612, 'pos': 0.135, 'neg': 0.0}
# {'neu': 1.0, 'compound': 0.0, 'pos': 0.0, 'neg': 0.0}
# {'neu': 0.905, 'compound': 0.296, 'pos': 0.095, 'neg': 0.0}
# {'neu': 0.476, 'compound': -0.296, 'pos': 0.0, 'neg': 0.524}
# {'neu': 1.0, 'compound': 0.0, 'pos': 0.0, 'neg': 0.0}
# {'neu': 1.0, 'compound': 0.0, 'pos': 0.0, 'neg': 0.0}
# {'neu': 1.0, 'compound': 0.0, 'pos': 0.0, 'neg': 0.0}
# {'neu': 0.476, 'compound': -0.296, 'pos': 0.0, 'neg': 0.524}
# {'neu': 0.476, 'compound': -0.296, 'pos': 0.0, 'neg': 0.524}
# {'neu': 0.476, 'compound': -0.296, 'pos': 0.0, 'neg': 0.524}
# {'neu': 0.476, 'compound': -0.296, 'pos': 0.0, 'neg': 0.524}
# {'neu': 0.476, 'compound': -0.296, 'pos': 0.0, 'neg': 0.524}
# {'neu': 0.476, 'compound': -0.296, 'pos': 0.0, 'neg': 0.524}
# {'neu': 0.476, 'compound': -0.296, 'pos': 0.0, 'neg': 0.524}
# {'neu': 1.0, 'compound': 0.0, 'pos': 0.0, 'neg': 0.0}
# {'neu': 0.901, 'compound': -0.3182, 'pos': 0.0, 'neg': 0.099}
# {'neu': 1.0, 'compound': 0.0, 'pos': 0.0, 'neg': 0.0}
# {'neu': 1.0, 'compound': 0.0, 'pos': 0.0, 'neg': 0.0}
# {'neu': 0.957, 'compound': 0.2824, 'pos': 0.043, 'neg': 0.0}
# {'neu': 0.759, 'compound': 0.4019, 'pos': 0.156, 'neg': 0.084}
# {'neu': 0.715, 'compound': 0.6775, 'pos': 0.208, 'neg': 0.077}
# {'neu': 0.476, 'compound': -0.296, 'pos': 0.0, 'neg': 0.524}
# {'neu': 1.0, 'compound': 0.0, 'pos': 0.0, 'neg': 0.0}
# {'neu': 0.737, 'compound': 0.3612, 'pos': 0.263, 'neg': 0.0}
# {'neu': 0.847, 'compound': 0.4404, 'pos': 0.153, 'neg': 0.0}
# {'neu': 1.0, 'compound': 0.0, 'pos': 0.0, 'neg': 0.0}
# {'neu': 0.881, 'compound': 0.5023, 'pos': 0.119, 'neg': 0.0}
# {'neu': 1.0, 'compound': 0.0, 'pos': 0.0, 'neg': 0.0}
# {'neu': 1.0, 'compound': 0.0, 'pos': 0.0, 'neg': 0.0}
# {'neu': 0.784, 'compound': 0.1531, 'pos': 0.123, 'neg': 0.093}
# {'neu': 0.936, 'compound': 0.296, 'pos': 0.064, 'neg': 0.0}
# {'neu': 0.435, 'compound': 0.0772, 'pos': 0.565, 'neg': 0.0}
# {'neu': 1.0, 'compound': 0.0, 'pos': 0.0, 'neg': 0.0}
# {'neu': 1.0, 'compound': 0.0, 'pos': 0.0, 'neg': 0.0}
# {'neu': 0.92, 'compound': 0.0772, 'pos': 0.08, 'neg': 0.0}
# {'neu': 1.0, 'compound': 0.0, 'pos': 0.0, 'neg': 0.0}
# {'neu': 1.0, 'compound': 0.0, 'pos': 0.0, 'neg': 0.0}
# {'neu': 0.46, 'compound': 0.5719, 'pos': 0.54, 'neg': 0.0}
# {'neu': 0.432, 'compound': 0.7845, 'pos': 0.568, 'neg': 0.0}
# {'neu': 1.0, 'compound': 0.0, 'pos': 0.0, 'neg': 0.0}
# {'neu': 1.0, 'compound': 0.0, 'pos': 0.0, 'neg': 0.0}
# {'neu': 0.476, 'compound': -0.296, 'pos': 0.0, 'neg': 0.524}
# {'neu': 1.0, 'compound': 0.0, 'pos': 0.0, 'neg': 0.0}
# {'neu': 0.863, 'compound': 0.5661, 'pos': 0.137, 'neg': 0.0}
# {'neu': 1.0, 'compound': 0.0, 'pos': 0.0, 'neg': 0.0}
# {'neu': 1.0, 'compound': 0.0, 'pos': 0.0, 'neg': 0.0}
# {'neu': 0.83, 'compound': 0.2732, 'pos': 0.105, 'neg': 0.065}
# {'neu': 0.689, 'compound': -0.6486, 'pos': 0.105, 'neg': 0.207}
# {'neu': 0.549, 'compound': 0.6249, 'pos': 0.451, 'neg': 0.0}
# {'neu': 0.883, 'compound': 0.5423, 'pos': 0.117, 'neg': 0.0}
# {'neu': 1.0, 'compound': 0.0, 'pos': 0.0, 'neg': 0.0}
# {'neu': 1.0, 'compound': 0.0, 'pos': 0.0, 'neg': 0.0}
# {'neu': 0.518, 'compound': 0.4199, 'pos': 0.482, 'neg': 0.0}
# {'neu': 1.0, 'compound': 0.0, 'pos': 0.0, 'neg': 0.0}
# {'neu': 1.0, 'compound': 0.0, 'pos': 0.0, 'neg': 0.0}
# {'neu': 1.0, 'compound': 0.0, 'pos': 0.0, 'neg': 0.0}
# {'neu': 0.645, 'compound': 0.296, 'pos': 0.355, 'neg': 0.0}
# {'neu': 1.0, 'compound': 0.0, 'pos': 0.0, 'neg': 0.0}
# {'neu': 0.822, 'compound': 0.2382, 'pos': 0.178, 'neg': 0.0}
# {'neu': 0.649, 'compound': 0.4019, 'pos': 0.351, 'neg': 0.0}
# {'neu': 0.92, 'compound': 0.2732, 'pos': 0.08, 'neg': 0.0}
# {'neu': 0.0, 'compound': 0.4019, 'pos': 1.0, 'neg': 0.0}
# {'neu': 0.0, 'compound': 0.4019, 'pos': 1.0, 'neg': 0.0}
# {'neu': 0.831, 'compound': 0.7096, 'pos': 0.169, 'neg': 0.0}
# {'neu': 0.744, 'compound': 0.8834, 'pos': 0.185, 'neg': 0.071}
# {'neu': 0.656, 'compound': 0.4939, 'pos': 0.344, 'neg': 0.0}
# {'neu': 0.928, 'compound': 0.3071, 'pos': 0.043, 'neg': 0.029}
# {'neu': 1.0, 'compound': 0.0, 'pos': 0.0, 'neg': 0.0}
# {'neu': 0.939, 'compound': 0.296, 'pos': 0.061, 'neg': 0.0}
# {'neu': 0.794, 'compound': 0.0772, 'pos': 0.206, 'neg': 0.0}
# {'neu': 1.0, 'compound': 0.0, 'pos': 0.0, 'neg': 0.0}
# {'neu': 0.828, 'compound': 0.3612, 'pos': 0.172, 'neg': 0.0}
# {'neu': 0.729, 'compound': 0.6369, 'pos': 0.271, 'neg': 0.0}
# {'neu': 0.905, 'compound': 0.2732, 'pos': 0.095, 'neg': 0.0}
# {'neu': 0.791, 'compound': 0.4404, 'pos': 0.209, 'neg': 0.0}
# {'neu': 0.829, 'compound': -0.4767, 'pos': 0.0, 'neg': 0.171}
# {'neu': 0.0, 'compound': 0.3612, 'pos': 1.0, 'neg': 0.0}
# {'neu': 1.0, 'compound': 0.0, 'pos': 0.0, 'neg': 0.0}
# {'neu': 1.0, 'compound': 0.0, 'pos': 0.0, 'neg': 0.0}
# {'neu': 1.0, 'compound': 0.0, 'pos': 0.0, 'neg': 0.0}
# {'neu': 0.698, 'compound': 0.0772, 'pos': 0.302, 'neg': 0.0}
# {'neu': 0.526, 'compound': 0.3818, 'pos': 0.474, 'neg': 0.0}
# {'neu': 0.419, 'compound': 0.632, 'pos': 0.581, 'neg': 0.0}
# {'neu': 0.867, 'compound': 0.1531, 'pos': 0.133, 'neg': 0.0}
# {'neu': 0.286, 'compound': 0.3612, 'pos': 0.714, 'neg': 0.0}
# {'neu': 0.772, 'compound': 0.6808, 'pos': 0.228, 'neg': 0.0}
# {'neu': 0.92, 'compound': 0.0772, 'pos': 0.08, 'neg': 0.0}
# {'neu': 0.673, 'compound': 0.5209, 'pos': 0.327, 'neg': 0.0}
# {'neu': 1.0, 'compound': 0.0, 'pos': 0.0, 'neg': 0.0}
# {'neu': 0.435, 'compound': 0.0772, 'pos': 0.565, 'neg': 0.0}
# {'neu': 0.435, 'compound': 0.0772, 'pos': 0.565, 'neg': 0.0}
# {'neu': 0.435, 'compound': 0.0772, 'pos': 0.565, 'neg': 0.0}
# {'neu': 0.645, 'compound': 0.296, 'pos': 0.355, 'neg': 0.0}
# {'neu': 0.0, 'compound': 0.5719, 'pos': 1.0, 'neg': 0.0}
# {'neu': 0.585, 'compound': 0.8313, 'pos': 0.415, 'neg': 0.0}
# {'neu': 1.0, 'compound': 0.0, 'pos': 0.0, 'neg': 0.0}
# {'neu': 0.41, 'compound': 0.7351, 'pos': 0.59, 'neg': 0.0}
# {'neu': 0.476, 'compound': -0.296, 'pos': 0.0, 'neg': 0.524}
# {'neu': 0.893, 'compound': -0.0516, 'pos': 0.0, 'neg': 0.107}
# {'neu': 0.671, 'compound': -0.128, 'pos': 0.148, 'neg': 0.181}
# {'neu': 0.745, 'compound': 0.5883, 'pos': 0.255, 'neg': 0.0}
# {'neu': 1.0, 'compound': 0.0, 'pos': 0.0, 'neg': 0.0}
# {'neu': 0.73, 'compound': 0.7506, 'pos': 0.27, 'neg': 0.0}
# {'neu': 0.884, 'compound': 0.3612, 'pos': 0.116, 'neg': 0.0}
# {'neu': 0.9, 'compound': 0.168, 'pos': 0.1, 'neg': 0.0}
# {'neu': 1.0, 'compound': 0.0, 'pos': 0.0, 'neg': 0.0}
# {'neu': 0.5, 'compound': 0.6124, 'pos': 0.5, 'neg': 0.0}
# {'neu': 0.0, 'compound': 0.4019, 'pos': 1.0, 'neg': 0.0}
# {'neu': 0.924, 'compound': -0.467, 'pos': 0.0, 'neg': 0.076}
# {'neu': 0.676, 'compound': 0.34, 'pos': 0.324, 'neg': 0.0}
# {'neu': 0.732, 'compound': 0.3736, 'pos': 0.268, 'neg': 0.0}
# {'neu': 0.8, 'compound': 0.3612, 'pos': 0.2, 'neg': 0.0}
# {'neu': 0.877, 'compound': -0.4215, 'pos': 0.0, 'neg': 0.123}
# {'neu': 0.0, 'compound': 0.296, 'pos': 1.0, 'neg': 0.0}
# {'neu': 0.783, 'compound': 0.3612, 'pos': 0.217, 'neg': 0.0}
# {'neu': 1.0, 'compound': 0.0, 'pos': 0.0, 'neg': 0.0}
# {'neu': 0.866, 'compound': 0.8491, 'pos': 0.079, 'neg': 0.056}
# {'neu': 1.0, 'compound': 0.0, 'pos': 0.0, 'neg': 0.0}
# {'neu': 0.885, 'compound': 0.0772, 'pos': 0.115, 'neg': 0.0}
# {'neu': 0.794, 'compound': 0.0772, 'pos': 0.206, 'neg': 0.0}
# {'neu': 1.0, 'compound': 0.0, 'pos': 0.0, 'neg': 0.0}
# {'neu': 1.0, 'compound': 0.0, 'pos': 0.0, 'neg': 0.0}
# {'neu': 0.695, 'compound': 0.8198, 'pos': 0.247, 'neg': 0.058}
# {'neu': 0.649, 'compound': 0.8481, 'pos': 0.351, 'neg': 0.0}
# {'neu': 1.0, 'compound': 0.0, 'pos': 0.0, 'neg': 0.0}
# {'neu': 0.256, 'compound': 0.4404, 'pos': 0.744, 'neg': 0.0}
# {'neu': 0.685, 'compound': 0.4144, 'pos': 0.315, 'neg': 0.0}
# {'neu': 0.843, 'compound': 0.0772, 'pos': 0.157, 'neg': 0.0}
# {'neu': 0.755, 'compound': 0.0772, 'pos': 0.245, 'neg': 0.0}
# {'neu': 1.0, 'compound': 0.0, 'pos': 0.0, 'neg': 0.0}
# {'neu': 1.0, 'compound': 0.0, 'pos': 0.0, 'neg': 0.0}
# {'neu': 0.576, 'compound': 0.7088, 'pos': 0.424, 'neg': 0.0}
# {'neu': 0.577, 'compound': 0.296, 'pos': 0.423, 'neg': 0.0}
# {'neu': 0.902, 'compound': -0.0516, 'pos': 0.0, 'neg': 0.098}
# {'neu': 0.789, 'compound': 0.6808, 'pos': 0.211, 'neg': 0.0}
# {'neu': 1.0, 'compound': 0.0, 'pos': 0.0, 'neg': 0.0}
# {'neu': 1.0, 'compound': 0.0, 'pos': 0.0, 'neg': 0.0}
# {'neu': 1.0, 'compound': 0.0, 'pos': 0.0, 'neg': 0.0}
# {'neu': 1.0, 'compound': 0.0, 'pos': 0.0, 'neg': 0.0}
# {'neu': 1.0, 'compound': 0.0, 'pos': 0.0, 'neg': 0.0}
# {'neu': 0.748, 'compound': 0.4019, 'pos': 0.252, 'neg': 0.0}
# {'neu': 1.0, 'compound': 0.0, 'pos': 0.0, 'neg': 0.0}
# {'neu': 0.0, 'compound': 0.296, 'pos': 1.0, 'neg': 0.0}
# {'neu': 0.476, 'compound': -0.296, 'pos': 0.0, 'neg': 0.524}
# {'neu': 0.947, 'compound': 0.0772, 'pos': 0.053, 'neg': 0.0}
# {'neu': 1.0, 'compound': 0.0, 'pos': 0.0, 'neg': 0.0}
# {'neu': 0.476, 'compound': -0.296, 'pos': 0.0, 'neg': 0.524}
# {'neu': 1.0, 'compound': 0.0, 'pos': 0.0, 'neg': 0.0}
# {'neu': 1.0, 'compound': 0.0, 'pos': 0.0, 'neg': 0.0}
# {'neu': 1.0, 'compound': 0.0, 'pos': 0.0, 'neg': 0.0}
# {'neu': 0.941, 'compound': 0.1154, 'pos': 0.059, 'neg': 0.0}
# {'neu': 1.0, 'compound': 0.0, 'pos': 0.0, 'neg': 0.0}
# {'neu': 0.952, 'compound': 0.0772, 'pos': 0.048, 'neg': 0.0}
# {'neu': 0.828, 'compound': 0.4404, 'pos': 0.172, 'neg': 0.0}
# {'neu': 1.0, 'compound': 0.0, 'pos': 0.0, 'neg': 0.0}
# {'neu': 0.684, 'compound': 0.6808, 'pos': 0.256, 'neg': 0.06}
# {'neu': 0.0, 'compound': 0.296, 'pos': 1.0, 'neg': 0.0}
# {'neu': 0.659, 'compound': 0.8519, 'pos': 0.341, 'neg': 0.0}
# {'neu': 0.909, 'compound': 0.4404, 'pos': 0.091, 'neg': 0.0}
# {'neu': 0.918, 'compound': 0.627, 'pos': 0.062, 'neg': 0.02}
# {'neu': 1.0, 'compound': 0.0, 'pos': 0.0, 'neg': 0.0}
# {'neu': 0.94, 'compound': 0.644, 'pos': 0.046, 'neg': 0.015}
# {'neu': 1.0, 'compound': 0.0, 'pos': 0.0, 'neg': 0.0}
# {'neu': 0.577, 'compound': 0.296, 'pos': 0.423, 'neg': 0.0}
# {'neu': 0.898, 'compound': 0.2675, 'pos': 0.063, 'neg': 0.039}
# {'neu': 0.812, 'compound': -0.0271, 'pos': 0.091, 'neg': 0.097}
# {'neu': 1.0, 'compound': 0.0, 'pos': 0.0, 'neg': 0.0}
# {'neu': 0.813, 'compound': 0.3182, 'pos': 0.187, 'neg': 0.0}
# {'neu': 0.537, 'compound': 0.902, 'pos': 0.463, 'neg': 0.0}
# ...
# {'neu': 0.763, 'compound': 0.7908, 'pos': 0.121, 'neg': 0.116}
# {'neu': 0.878, 'compound': 0.2714, 'pos': 0.122, 'neg': 0.0}
# {'neu': 0.649, 'compound': 0.4019, 'pos': 0.351, 'neg': 0.0}
# {'neu': 1.0, 'compound': 0.0, 'pos': 0.0, 'neg': 0.0}
# {'neu': 0.492, 'compound': 0.4767, 'pos': 0.508, 'neg': 0.0}
# {'neu': 1.0, 'compound': 0.0, 'pos': 0.0, 'neg': 0.0}
# {'neu': 0.887, 'compound': 0.9246, 'pos': 0.065, 'neg': 0.047}
# {'neu': 0.802, 'compound': -0.9573, 'pos': 0.093, 'neg': 0.105}
# {'neu': 1.0, 'compound': 0.0, 'pos': 0.0, 'neg': 0.0}
# {'neu': 0.476, 'compound': -0.296, 'pos': 0.0, 'neg': 0.524}
# {'neu': 0.787, 'compound': 0.6597, 'pos': 0.213, 'neg': 0.0}
# {'neu': 0.694, 'compound': -0.2263, 'pos': 0.127, 'neg': 0.179}
# {'neu': 0.65, 'compound': 0.6486, 'pos': 0.35, 'neg': 0.0}
# {'neu': 0.928, 'compound': 0.3612, 'pos': 0.072, 'neg': 0.0}
# {'neu': 0.812, 'compound': 0.9565, 'pos': 0.188, 'neg': 0.0}
# {'neu': 0.747, 'compound': 0.4632, 'pos': 0.129, 'neg': 0.124}
# {'neu': 0.93, 'compound': 0.4278, 'pos': 0.07, 'neg': 0.0}
# {'neu': 0.825, 'compound': 0.3798, 'pos': 0.121, 'neg': 0.054}
# {'neu': 0.918, 'compound': 0.34, 'pos': 0.082, 'neg': 0.0}
# {'neu': 0.476, 'compound': -0.296, 'pos': 0.0, 'neg': 0.524}
# {'neu': 0.798, 'compound': -0.6878, 'pos': 0.093, 'neg': 0.109}
# {'neu': 0.96, 'compound': 0.0772, 'pos': 0.04, 'neg': 0.0}
# {'neu': 1.0, 'compound': 0.0, 'pos': 0.0, 'neg': 0.0}
# {'neu': 0.476, 'compound': -0.296, 'pos': 0.0, 'neg': 0.524}
# {'neu': 0.0, 'compound': 0.2023, 'pos': 1.0, 'neg': 0.0}
# {'neu': 1.0, 'compound': 0.0, 'pos': 0.0, 'neg': 0.0}
# {'neu': 0.476, 'compound': -0.296, 'pos': 0.0, 'neg': 0.524}
# {'neu': 0.476, 'compound': -0.296, 'pos': 0.0, 'neg': 0.524}
# {'neu': 0.885, 'compound': 0.0772, 'pos': 0.115, 'neg': 0.0}
# {'neu': 1.0, 'compound': 0.0, 'pos': 0.0, 'neg': 0.0}
# {'neu': 0.476, 'compound': -0.296, 'pos': 0.0, 'neg': 0.524}
# {'neu': 0.811, 'compound': 0.8555, 'pos': 0.189, 'neg': 0.0}
# {'neu': 0.811, 'compound': 0.8233, 'pos': 0.122, 'neg': 0.067}
# {'neu': 0.874, 'compound': 0.6361, 'pos': 0.126, 'neg': 0.0}
# {'neu': 0.408, 'compound': 0.4404, 'pos': 0.592, 'neg': 0.0}
# {'neu': 0.833, 'compound': 0.34, 'pos': 0.167, 'neg': 0.0}
# {'neu': 0.786, 'compound': 0.4574, 'pos': 0.214, 'neg': 0.0}
# {'neu': 1.0, 'compound': 0.0, 'pos': 0.0, 'neg': 0.0}
# {'neu': 0.915, 'compound': 0.1027, 'pos': 0.085, 'neg': 0.0}
# {'neu': 0.843, 'compound': 0.0772, 'pos': 0.157, 'neg': 0.0}
# {'neu': 0.854, 'compound': 0.9274, 'pos': 0.146, 'neg': 0.0}
# {'neu': 0.791, 'compound': 0.4404, 'pos': 0.209, 'neg': 0.0}
# {'neu': 1.0, 'compound': 0.0, 'pos': 0.0, 'neg': 0.0}
# {'neu': 0.476, 'compound': -0.296, 'pos': 0.0, 'neg': 0.524}
# {'neu': 1.0, 'compound': 0.0, 'pos': 0.0, 'neg': 0.0}
# {'neu': 0.87, 'compound': -0.5975, 'pos': 0.0, 'neg': 0.13}
# {'neu': 1.0, 'compound': 0.0, 'pos': 0.0, 'neg': 0.0}
# {'neu': 0.843, 'compound': 0.9926, 'pos': 0.102, 'neg': 0.055}
# {'neu': 0.588, 'compound': 0.128, 'pos': 0.227, 'neg': 0.185}
# {'neu': 0.0, 'compound': 0.2023, 'pos': 1.0, 'neg': 0.0}
# {'neu': 0.892, 'compound': 0.368, 'pos': 0.108, 'neg': 0.0}
# {'neu': 1.0, 'compound': 0.0, 'pos': 0.0, 'neg': 0.0}
# {'neu': 1.0, 'compound': 0.0, 'pos': 0.0, 'neg': 0.0}
# {'neu': 0.925, 'compound': 0.9329, 'pos': 0.075, 'neg': 0.0}
# {'neu': 0.779, 'compound': 0.9578, 'pos': 0.209, 'neg': 0.012}
# {'neu': 0.912, 'compound': 0.3612, 'pos': 0.088, 'neg': 0.0}
# {'neu': 0.0, 'compound': 0.2023, 'pos': 1.0, 'neg': 0.0}
# {'neu': 0.476, 'compound': -0.296, 'pos': 0.0, 'neg': 0.524}
# {'neu': 0.838, 'compound': 0.9985, 'pos': 0.107, 'neg': 0.055}
# {'neu': 0.842, 'compound': 0.96, 'pos': 0.136, 'neg': 0.021}
# {'neu': 0.754, 'compound': 0.6739, 'pos': 0.246, 'neg': 0.0}
# {'neu': 0.476, 'compound': -0.296, 'pos': 0.0, 'neg': 0.524}
# {'neu': 1.0, 'compound': 0.0, 'pos': 0.0, 'neg': 0.0}
# {'neu': 1.0, 'compound': 0.0, 'pos': 0.0, 'neg': 0.0}
# {'neu': 0.476, 'compound': -0.296, 'pos': 0.0, 'neg': 0.524}
# {'neu': 0.847, 'compound': 0.368, 'pos': 0.153, 'neg': 0.0}
# {'neu': 0.826, 'compound': -0.4252, 'pos': 0.084, 'neg': 0.091}
# {'neu': 0.0, 'compound': 0.2023, 'pos': 1.0, 'neg': 0.0}
# {'neu': 1.0, 'compound': 0.0, 'pos': 0.0, 'neg': 0.0}
# {'neu': 0.0, 'compound': 0.2023, 'pos': 1.0, 'neg': 0.0}
# {'neu': 0.752, 'compound': 0.5719, 'pos': 0.194, 'neg': 0.054}
# {'neu': 0.826, 'compound': 0.8837, 'pos': 0.148, 'neg': 0.026}
# {'neu': 0.0, 'compound': 0.2023, 'pos': 1.0, 'neg': 0.0}
# {'neu': 0.665, 'compound': 0.6166, 'pos': 0.335, 'neg': 0.0}
# {'neu': 0.89, 'compound': 0.4019, 'pos': 0.11, 'neg': 0.0}
# {'neu': 0.914, 'compound': 0.4939, 'pos': 0.086, 'neg': 0.0}
# {'neu': 1.0, 'compound': 0.0, 'pos': 0.0, 'neg': 0.0}
# {'neu': 1.0, 'compound': 0.0, 'pos': 0.0, 'neg': 0.0}
# {'neu': 1.0, 'compound': 0.0, 'pos': 0.0, 'neg': 0.0}
# {'neu': 0.834, 'compound': 0.9348, 'pos': 0.112, 'neg': 0.054}
# {'neu': 0.476, 'compound': -0.296, 'pos': 0.0, 'neg': 0.524}
# {'neu': 0.833, 'compound': 0.9945, 'pos': 0.107, 'neg': 0.059}
# {'neu': 1.0, 'compound': 0.0, 'pos': 0.0, 'neg': 0.0}
# {'neu': 0.836, 'compound': 0.5759, 'pos': 0.118, 'neg': 0.046}
# {'neu': 0.658, 'compound': -0.5399, 'pos': 0.093, 'neg': 0.249}
# {'neu': 0.0, 'compound': 0.6249, 'pos': 1.0, 'neg': 0.0}
# {'neu': 1.0, 'compound': 0.0, 'pos': 0.0, 'neg': 0.0}
# {'neu': 1.0, 'compound': 0.0, 'pos': 0.0, 'neg': 0.0}
# {'neu': 0.0, 'compound': 0.2023, 'pos': 1.0, 'neg': 0.0}
# {'neu': 0.0, 'compound': 0.2023, 'pos': 1.0, 'neg': 0.0}
# {'neu': 0.835, 'compound': 0.9931, 'pos': 0.123, 'neg': 0.041}
# {'neu': 1.0, 'compound': 0.0, 'pos': 0.0, 'neg': 0.0}
# {'neu': 0.0, 'compound': 0.2023, 'pos': 1.0, 'neg': 0.0}
# {'neu': 0.0, 'compound': 0.2023, 'pos': 1.0, 'neg': 0.0}
# {'neu': 0.8, 'compound': 0.9834, 'pos': 0.117, 'neg': 0.083}
# {'neu': 0.0, 'compound': 0.2023, 'pos': 1.0, 'neg': 0.0}
# {'neu': 0.904, 'compound': -0.1531, 'pos': 0.0, 'neg': 0.096}
# {'neu': 0.93, 'compound': -0.2411, 'pos': 0.0, 'neg': 0.07}
# {'neu': 0.0, 'compound': 0.2023, 'pos': 1.0, 'neg': 0.0}
# {'neu': 0.476, 'compound': -0.296, 'pos': 0.0, 'neg': 0.524}
# {'neu': 0.476, 'compound': -0.296, 'pos': 0.0, 'neg': 0.524}
# {'neu': 0.763, 'compound': 0.3919, 'pos': 0.179, 'neg': 0.058}
# {'neu': 0.838, 'compound': -0.9864, 'pos': 0.054, 'neg': 0.108}
# {'neu': 1.0, 'compound': 0.0, 'pos': 0.0, 'neg': 0.0}
# {'neu': 0.804, 'compound': -0.9577, 'pos': 0.098, 'neg': 0.098}
# {'neu': 0.84, 'compound': -0.9746, 'pos': 0.064, 'neg': 0.096}
# {'neu': 1.0, 'compound': 0.0, 'pos': 0.0, 'neg': 0.0}
# {'neu': 0.476, 'compound': -0.296, 'pos': 0.0, 'neg': 0.524}
# {'neu': 0.898, 'compound': 0.81, 'pos': 0.102, 'neg': 0.0}
# {'neu': 1.0, 'compound': 0.0, 'pos': 0.0, 'neg': 0.0}
# {'neu': 0.476, 'compound': -0.296, 'pos': 0.0, 'neg': 0.524}
# {'neu': 1.0, 'compound': 0.0, 'pos': 0.0, 'neg': 0.0}
# {'neu': 0.904, 'compound': 0.2023, 'pos': 0.096, 'neg': 0.0}
# {'neu': 1.0, 'compound': 0.0, 'pos': 0.0, 'neg': 0.0}
# {'neu': 0.945, 'compound': 0.859, 'pos': 0.055, 'neg': 0.0}
# {'neu': 0.0, 'compound': 0.2023, 'pos': 1.0, 'neg': 0.0}
# {'neu': 0.476, 'compound': -0.296, 'pos': 0.0, 'neg': 0.524}
# {'neu': 0.808, 'compound': 0.9875, 'pos': 0.181, 'neg': 0.011}
# {'neu': 0.804, 'compound': 0.7946, 'pos': 0.164, 'neg': 0.032}
# {'neu': 0.866, 'compound': 0.5719, 'pos': 0.134, 'neg': 0.0}
# {'neu': 1.0, 'compound': 0.0, 'pos': 0.0, 'neg': 0.0}
# {'neu': 0.819, 'compound': 0.7141, 'pos': 0.122, 'neg': 0.059}
# {'neu': 0.69, 'compound': 0.2023, 'pos': 0.31, 'neg': 0.0}
# {'neu': 0.476, 'compound': -0.296, 'pos': 0.0, 'neg': 0.524}
# {'neu': 0.476, 'compound': -0.296, 'pos': 0.0, 'neg': 0.524}
# {'neu': 0.476, 'compound': -0.296, 'pos': 0.0, 'neg': 0.524}
# {'neu': 0.476, 'compound': -0.296, 'pos': 0.0, 'neg': 0.524}
# {'neu': 0.476, 'compound': -0.296, 'pos': 0.0, 'neg': 0.524}
# {'neu': 0.728, 'compound': -0.5371, 'pos': 0.105, 'neg': 0.167}
# {'neu': 1.0, 'compound': 0.0, 'pos': 0.0, 'neg': 0.0}
# {'neu': 0.923, 'compound': 0.2732, 'pos': 0.077, 'neg': 0.0}
# {'neu': 0.476, 'compound': -0.296, 'pos': 0.0, 'neg': 0.524}
# {'neu': 0.476, 'compound': -0.296, 'pos': 0.0, 'neg': 0.524}
# {'neu': 0.244, 'compound': 0.4754, 'pos': 0.756, 'neg': 0.0}
# {'neu': 0.579, 'compound': 0.6249, 'pos': 0.421, 'neg': 0.0}
# {'neu': 0.476, 'compound': -0.296, 'pos': 0.0, 'neg': 0.524}
# {'neu': 0.476, 'compound': -0.296, 'pos': 0.0, 'neg': 0.524}
# {'neu': 0.958, 'compound': 0.3182, 'pos': 0.042, 'neg': 0.0}
# {'neu': 0.908, 'compound': 0.3612, 'pos': 0.061, 'neg': 0.031}
# {'neu': 1.0, 'compound': 0.0, 'pos': 0.0, 'neg': 0.0}
# {'neu': 0.916, 'compound': 0.3182, 'pos': 0.084, 'neg': 0.0}
# {'neu': 0.815, 'compound': 0.3612, 'pos': 0.185, 'neg': 0.0}
# {'neu': 0.69, 'compound': 0.4019, 'pos': 0.31, 'neg': 0.0}
# {'neu': 1.0, 'compound': 0.0, 'pos': 0.0, 'neg': 0.0}
# {'neu': 0.597, 'compound': 0.4019, 'pos': 0.403, 'neg': 0.0}
# {'neu': 1.0, 'compound': 0.0, 'pos': 0.0, 'neg': 0.0}
# {'neu': 1.0, 'compound': 0.0, 'pos': 0.0, 'neg': 0.0}
# {'neu': 0.476, 'compound': -0.296, 'pos': 0.0, 'neg': 0.524}
# {'neu': 0.871, 'compound': 0.5574, 'pos': 0.129, 'neg': 0.0}
# {'neu': 0.94, 'compound': 0.1531, 'pos': 0.06, 'neg': 0.0}
# {'neu': 0.785, 'compound': 0.9577, 'pos': 0.215, 'neg': 0.0}
# {'neu': 0.88, 'compound': 0.659, 'pos': 0.096, 'neg': 0.024}
# {'neu': 0.952, 'compound': 0.2023, 'pos': 0.048, 'neg': 0.0}
# {'neu': 0.782, 'compound': 0.8834, 'pos': 0.178, 'neg': 0.04}
# {'neu': 0.476, 'compound': -0.296, 'pos': 0.0, 'neg': 0.524}
# {'neu': 0.909, 'compound': 0.34, 'pos': 0.091, 'neg': 0.0}
# {'neu': 0.189, 'compound': 0.5106, 'pos': 0.811, 'neg': 0.0}
# {'neu': 0.733, 'compound': 0.7925, 'pos': 0.267, 'neg': 0.0}
# {'neu': 0.933, 'compound': 0.2023, 'pos': 0.067, 'neg': 0.0}
# {'neu': 0.923, 'compound': -0.1725, 'pos': 0.0, 'neg': 0.077}
# {'neu': 0.556, 'compound': 0.34, 'pos': 0.444, 'neg': 0.0}
# {'neu': 1.0, 'compound': 0.0, 'pos': 0.0, 'neg': 0.0}
# {'neu': 0.799, 'compound': 0.9726, 'pos': 0.184, 'neg': 0.017}
# {'neu': 0.8, 'compound': 0.9768, 'pos': 0.135, 'neg': 0.065}
# {'neu': 0.476, 'compound': -0.296, 'pos': 0.0, 'neg': 0.524}
# {'neu': 0.855, 'compound': -0.296, 'pos': 0.0, 'neg': 0.145}
# {'neu': 0.476, 'compound': -0.296, 'pos': 0.0, 'neg': 0.524}
# {'neu': 0.0, 'compound': 0.2023, 'pos': 1.0, 'neg': 0.0}
# {'neu': 0.571, 'compound': -0.1027, 'pos': 0.164, 'neg': 0.264}
# {'neu': 0.476, 'compound': -0.296, 'pos': 0.0, 'neg': 0.524}
# {'neu': 0.476, 'compound': -0.296, 'pos': 0.0, 'neg': 0.524}
# {'neu': 0.784, 'compound': 0.296, 'pos': 0.216, 'neg': 0.0}
# {'neu': 0.476, 'compound': -0.296, 'pos': 0.0, 'neg': 0.524}
# {'neu': 1.0, 'compound': 0.0, 'pos': 0.0, 'neg': 0.0}
# {'neu': 1.0, 'compound': 0.0, 'pos': 0.0, 'neg': 0.0}
# {'neu': 0.811, 'compound': 0.8807, 'pos': 0.189, 'neg': 0.0}
# {'neu': 1.0, 'compound': 0.0, 'pos': 0.0, 'neg': 0.0}
# {'neu': 0.854, 'compound': 0.9988, 'pos': 0.132, 'neg': 0.014}
# {'neu': 0.813, 'compound': 0.9922, 'pos': 0.167, 'neg': 0.019}
# {'neu': 0.794, 'compound': -0.4996, 'pos': 0.089, 'neg': 0.117}
# {'neu': 0.476, 'compound': -0.296, 'pos': 0.0, 'neg': 0.524}
# {'neu': 0.753, 'compound': 0.919, 'pos': 0.216, 'neg': 0.031}
# {'neu': 0.735, 'compound': 0.8873, 'pos': 0.242, 'neg': 0.023}
# {'neu': 0.927, 'compound': -0.1027, 'pos': 0.033, 'neg': 0.04}
# {'neu': 0.0, 'compound': 0.2023, 'pos': 1.0, 'neg': 0.0}
# {'neu': 0.708, 'compound': 0.9156, 'pos': 0.268, 'neg': 0.024}
# {'neu': 0.476, 'compound': -0.296, 'pos': 0.0, 'neg': 0.524}
# {'neu': 1.0, 'compound': 0.0, 'pos': 0.0, 'neg': 0.0}
# {'neu': 0.602, 'compound': 0.6808, 'pos': 0.398, 'neg': 0.0}
# {'neu': 0.843, 'compound': -0.0772, 'pos': 0.0, 'neg': 0.157}
# {'neu': 0.476, 'compound': -0.296, 'pos': 0.0, 'neg': 0.524}
# {'neu': 0.888, 'compound': 0.8847, 'pos': 0.097, 'neg': 0.014}
# {'neu': 1.0, 'compound': 0.0, 'pos': 0.0, 'neg': 0.0}
# {'neu': 0.476, 'compound': -0.296, 'pos': 0.0, 'neg': 0.524}
# {'neu': 0.685, 'compound': 0.3182, 'pos': 0.315, 'neg': 0.0}
# {'neu': 0.796, 'compound': 0.7783, 'pos': 0.114, 'neg': 0.09}
# {'neu': 0.848, 'compound': 0.3612, 'pos': 0.152, 'neg': 0.0}
# {'neu': 1.0, 'compound': 0.0, 'pos': 0.0, 'neg': 0.0}
# {'neu': 0.629, 'compound': 0.3612, 'pos': 0.233, 'neg': 0.138}
# {'neu': 1.0, 'compound': 0.0, 'pos': 0.0, 'neg': 0.0}
# {'neu': 0.745, 'compound': 0.34, 'pos': 0.255, 'neg': 0.0}
# {'neu': 1.0, 'compound': 0.0, 'pos': 0.0, 'neg': 0.0}
# {'neu': 1.0, 'compound': 0.0, 'pos': 0.0, 'neg': 0.0}
# {'neu': 1.0, 'compound': 0.0, 'pos': 0.0, 'neg': 0.0}
# {'neu': 0.71, 'compound': -0.2656, 'pos': 0.12, 'neg': 0.17}
# {'neu': 0.654, 'compound': 0.7469, 'pos': 0.346, 'neg': 0.0}
# {'neu': 0.476, 'compound': -0.296, 'pos': 0.0, 'neg': 0.524}
# {'neu': 1.0, 'compound': 0.0, 'pos': 0.0, 'neg': 0.0}
# {'neu': 0.476, 'compound': -0.296, 'pos': 0.0, 'neg': 0.524}
# {'neu': 0.805, 'compound': 0.4404, 'pos': 0.195, 'neg': 0.0}
# {'neu': 0.854, 'compound': 0.4404, 'pos': 0.146, 'neg': 0.0}
# {'neu': 0.705, 'compound': 0.9898, 'pos': 0.166, 'neg': 0.128}
# {'neu': 1.0, 'compound': 0.0, 'pos': 0.0, 'neg': 0.0}
# {'neu': 0.93, 'compound': 0.596, 'pos': 0.07, 'neg': 0.0}
# {'neu': 0.412, 'compound': 0.875, 'pos': 0.588, 'neg': 0.0}
# {'neu': 0.788, 'compound': 0.5411, 'pos': 0.212, 'neg': 0.0}
# {'neu': 0.827, 'compound': 0.945, 'pos': 0.129, 'neg': 0.044}
# {'neu': 0.166, 'compound': 0.6166, 'pos': 0.834, 'neg': 0.0}
# {'neu': 1.0, 'compound': 0.0, 'pos': 0.0, 'neg': 0.0}
# {'neu': 0.476, 'compound': -0.296, 'pos': 0.0, 'neg': 0.524}
# {'neu': 0.861, 'compound': 0.6124, 'pos': 0.139, 'neg': 0.0}
# {'neu': 0.812, 'compound': -0.9879, 'pos': 0.071, 'neg': 0.117}
# {'neu': 0.827, 'compound': 0.8147, 'pos': 0.095, 'neg': 0.079}
# {'neu': 0.808, 'compound': 0.6124, 'pos': 0.192, 'neg': 0.0}
# {'neu': 1.0, 'compound': 0.0, 'pos': 0.0, 'neg': 0.0}
# {'neu': 0.925, 'compound': 0.3612, 'pos': 0.075, 'neg': 0.0}
# {'neu': 0.735, 'compound': 0.25, 'pos': 0.169, 'neg': 0.096}
# {'neu': 0.75, 'compound': 0.6289, 'pos': 0.187, 'neg': 0.063}
# {'neu': 0.799, 'compound': 0.3818, 'pos': 0.134, 'neg': 0.067}
# {'neu': 0.877, 'compound': 0.6369, 'pos': 0.123, 'neg': 0.0}
# {'neu': 0.667, 'compound': 0.6705, 'pos': 0.333, 'neg': 0.0}
# {'neu': 0.858, 'compound': 0.5106, 'pos': 0.142, 'neg': 0.0}
# {'neu': 1.0, 'compound': 0.0, 'pos': 0.0, 'neg': 0.0}
# {'neu': 0.633, 'compound': 0.4404, 'pos': 0.367, 'neg': 0.0}
# {'neu': 0.0, 'compound': 0.2023, 'pos': 1.0, 'neg': 0.0}
# {'neu': 0.476, 'compound': -0.296, 'pos': 0.0, 'neg': 0.524}
# {'neu': 0.476, 'compound': -0.296, 'pos': 0.0, 'neg': 0.524}
# {'neu': 0.476, 'compound': -0.296, 'pos': 0.0, 'neg': 0.524}
# {'neu': 1.0, 'compound': 0.0, 'pos': 0.0, 'neg': 0.0}
# {'neu': 0.679, 'compound': 0.8209, 'pos': 0.321, 'neg': 0.0}
# {'neu': 0.312, 'compound': 0.296, 'pos': 0.688, 'neg': 0.0}
# {'neu': 0.805, 'compound': 0.4404, 'pos': 0.195, 'neg': 0.0}
# {'neu': 1.0, 'compound': 0.0, 'pos': 0.0, 'neg': 0.0}
# {'neu': 0.476, 'compound': -0.296, 'pos': 0.0, 'neg': 0.524}
# {'neu': 1.0, 'compound': 0.0, 'pos': 0.0, 'neg': 0.0}
# {'neu': 0.476, 'compound': -0.296, 'pos': 0.0, 'neg': 0.524}
# {'neu': 0.629, 'compound': 0.7088, 'pos': 0.371, 'neg': 0.0}
# {'neu': 0.476, 'compound': -0.296, 'pos': 0.0, 'neg': 0.524}
# {'neu': 0.882, 'compound': 0.368, 'pos': 0.118, 'neg': 0.0}
# {'neu': 0.735, 'compound': 0.2023, 'pos': 0.265, 'neg': 0.0}
# {'neu': 0.773, 'compound': -0.9997, 'pos': 0.092, 'neg': 0.136}
# {'neu': 0.825, 'compound': 0.9992, 'pos': 0.138, 'neg': 0.037}
# {'neu': 0.921, 'compound': -0.2263, 'pos': 0.029, 'neg': 0.049}
# {'neu': 0.877, 'compound': 0.1655, 'pos': 0.08, 'neg': 0.043}
# {'neu': 0.792, 'compound': 0.8762, 'pos': 0.134, 'neg': 0.073}
# {'neu': 0.933, 'compound': 0.3182, 'pos': 0.067, 'neg': 0.0}
# {'neu': 0.777, 'compound': 0.765, 'pos': 0.223, 'neg': 0.0}
# {'neu': 0.917, 'compound': 0.4019, 'pos': 0.083, 'neg': 0.0}
# {'neu': 0.888, 'compound': 0.2263, 'pos': 0.112, 'neg': 0.0}
# {'neu': 1.0, 'compound': 0.0, 'pos': 0.0, 'neg': 0.0}
# {'neu': 0.915, 'compound': -0.4019, 'pos': 0.0, 'neg': 0.085}
# {'neu': 1.0, 'compound': 0.0, 'pos': 0.0, 'neg': 0.0}
# {'neu': 0.476, 'compound': -0.296, 'pos': 0.0, 'neg': 0.524}
# {'neu': 0.476, 'compound': -0.296, 'pos': 0.0, 'neg': 0.524}
# {'neu': 0.476, 'compound': -0.296, 'pos': 0.0, 'neg': 0.524}
# {'neu': 0.882, 'compound': 0.9753, 'pos': 0.104, 'neg': 0.015}
# {'neu': 0.476, 'compound': -0.296, 'pos': 0.0, 'neg': 0.524}
# {'neu': 0.476, 'compound': -0.296, 'pos': 0.0, 'neg': 0.524}

# %%
a
# Out:
# "Pls print.\nH <hrod17@clintonemail.com >\nSunday, October 11, 2009 5:03 PM\n'JilotyLC@state.gov'\nFw: Thanks so much for the talk"

# %%
analyzer = SentimentIntensityAnalyzer()

# %%
analyzer.polarity_scores(a)
# Out:
# {'compound': 0.4939, 'neg': 0.0, 'neu': 0.781, 'pos': 0.219}

# %% [markdown]
# ## 3.

# %% [markdown]
# ## 4. *BONUS*
